# %%
import openpyxl
import requests

def check_broken_links(excel_file):
    wb = openpyxl.load_workbook(excel_file)
    sheet = wb.active
    column_with_links = 'A'
    
    broken_links_report = []
    
    for cell in sheet[column_with_links]:
        print(cell)
        if cell.value:
            link = cell.value
            print(link)
            try:
                response = requests.get(link)
                if "HTTP 404" in response.text:  # Check if the page contains "HTTP 404"
                    broken_links_report.append(link)
                print(response)
            except requests.exceptions.RequestException:
                broken_links_report.append((link, 'Connection Error'))
        
    return broken_links_report

if __name__ == "__main__":
    excel_file_path = "example.xlsx"
    broken_links_report = check_broken_links(excel_file_path)

    if broken_links_report:
        print("Broken Links Report:")
        for link in broken_links_report:
            print(f"Broken Link: {link}")
    else:
        print("No broken links found.")
# Out:
# <Cell 'Sheet1'.A1>
# No broken links found.

# %%
import openpyxl
import requests

def check_broken_links(excel_file):
    try:
        wb = openpyxl.load_workbook(excel_file)
        sheet = wb.active
        column_with_links = 'A'
        
        broken_links_report = []
        
        for cell in sheet[column_with_links]:
            if cell.value:
                link = cell.value
                try:
                    response = requests.get(link)
                    if "HTTP 404" in response.text:  # Check if the page contains "HTTP 404"
                        broken_links_report.append(link)
                except requests.exceptions.RequestException:
                    broken_links_report.append((link, 'Connection Error'))

        return broken_links_report
    except openpyxl.utils.exceptions.InvalidFileException:
        print(f"Error: Unable to open the file '{excel_file}'. Please check if it's a valid Excel file.")
        return []
    except Exception as e:
        print(f"Error: An unexpected error occurred while processing the file '{excel_file}': {e}")
        return []

if __name__ == "__main__":
    excel_file_path = "example.xlsx"
    broken_links_report = check_broken_links(excel_file_path)

    if broken_links_report:
        print("Broken Links Report:")
        for link in broken_links_report:
            print(f"Broken Link: {link}")
    else:
        print("No broken links found.")
# Out:
# <tuple_iterator object at 0x0000021645274B80>
# No broken links found.

# %%
import openpyxl
import requests

def check_broken_links(excel_file):
    try:
        print(f"Opening file: {excel_file}...")
        wb = openpyxl.load_workbook(excel_file)
        sheet = wb.active
        column_with_links = 'A'
        
        broken_links_report = []
        total_links_checked = 0  # Variable to keep track of the total number of links checked
        
        print(f"Checking links inside {excel_file}...")
        for cell in sheet[column_with_links]:
            if cell.value:
                link = cell.value
                print(f"Checking link: {link}")
                total_links_checked += 1  # Increment the count for each link checked
                try:
                    response = requests.get(link)
                    if "HTTP 404" in response.text:  # Check if the page contains "HTTP 404"
                        broken_links_report.append(link)
                        print(f"Broken link found: {link}")
                    else:
                        print(f"Link is working fine: {link}")
                except requests.exceptions.RequestException:
                    broken_links_report.append(link)
                    print(f"Connection error occurred for link: {link}")

        print(f"Total links checked in {excel_file}: {total_links_checked}")
        print(f"Total broken links found in {excel_file}: {len(broken_links_report)}")
        return broken_links_report
    except openpyxl.utils.exceptions.InvalidFileException:
        print(f"Error: Unable to open the file '{excel_file}'. Please check if it's a valid Excel file.")
        return []
    except Exception as e:
        print(f"Error: An unexpected error occurred while processing the file '{excel_file}': {e}")
        return []

if __name__ == "__main__":
    excel_file_path = "example.xlsx"
    broken_links_report = check_broken_links(excel_file_path)

    if broken_links_report:
        print("Broken Links Report:")
        for link in broken_links_report:
            print(f"Broken Link: {link}")
    else:
        print("No broken links found.")
# Out:
# Opening file: example.xlsx...
# Checking links inside example.xlsx...
# Checking link: https://utep.edu/engineering/student-resources/feedback.html
# Link is working fine: https://utep.edu/engineering/student-resources/feedback.html
# Checking link: http://catalog.utep.edu/policies-regulations/student-life/
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# Checking link: https://www.utep.edu/programs/graduate/?utep-home
# Link is working fine: https://www.utep.edu/programs/graduate/?utep-home
# Checking link: https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Broken link found: https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Total links checked in example.xlsx: 4
# Total broken links found in example.xlsx: 1
# Broken Links Report:
# Broken Link: https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html

# %%
import openpyxl
import requests
from bs4 import BeautifulSoup

def get_links_from_page(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            links = [link.get('href') for link in soup.find_all('a', href=True)]
            return links
        else:
            return []
    except requests.exceptions.RequestException:
        return []

def check_broken_links(excel_file):
    try:
        print(f"Opening file: {excel_file}...")
        wb = openpyxl.load_workbook(excel_file)
        sheet = wb.active
        column_with_links = 'A'
        
        broken_links_report = []
        total_links_checked = 0
        
        print(f"Checking links inside {excel_file}...")
        for cell in sheet[column_with_links]:
            if cell.value:
                link = cell.value
                print(f"Checking page: {link}")
                total_links_checked += 1
                page_links = get_links_from_page(link)
                for page_link in page_links:
                    if page_link:
                        try:
                            response = requests.get(page_link)
                            if response.status_code != 200:
                                broken_links_report.append((link, page_link))
                                print(f"Broken link found on page '{link}': {page_link}")
                        except requests.exceptions.RequestException:
                            broken_links_report.append((link, page_link))
                            print(f"Connection error occurred for link on page '{link}': {page_link}")

        print(f"Total pages checked: {total_links_checked}")
        print(f"Total broken links found: {len(broken_links_report)}")
        return broken_links_report
    except openpyxl.utils.exceptions.InvalidFileException:
        print(f"Error: Unable to open the file '{excel_file}'. Please check if it's a valid Excel file.")
        return []
    except Exception as e:
        print(f"Error: An unexpected error occurred while processing the file '{excel_file}': {e}")
        return []

if __name__ == "__main__":
    excel_file_path = "example.xlsx"
    broken_links_report = check_broken_links(excel_file_path)

    if broken_links_report:
        print("Broken Links Report:")
        for link, page_link in broken_links_report:
            print(f"Broken Link on page '{link}': {page_link}")
    else:
        print("No broken links found.")
# Out:
# Opening file: example.xlsx...
# Checking links inside example.xlsx...
# Checking page: https://utep.edu/engineering/student-resources/feedback.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #mainContentArea
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../about-us/administration.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../fact-sheet/fact-sheet.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../about-us/accreditation.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../academic-programs/degrees-and-programs.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../academic-programs/undergraduate-programs/undergraduate.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../academic-programs/graduate-programs/graduate-programs.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../mechanical/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../civil/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../ece/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eel/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../imse/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../mmbme/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eec/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/awards-and-recognition.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/research-and-support.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': Student-Opportunities.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/newsfeed.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife-deans-list.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eec/honors/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-preprofessional-experiences.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': feedback.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': Student-Opportunities.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-women-in-engineering.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../e-newsletter/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/aspirations/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/discover-e/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/e-week/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/excites/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/robotics/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eweek/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../graduateceremony/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../orderoftheengineer/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../tcm/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /resources/students.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /resources/faculty-and-staff.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /resources/parents.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/vpba/parking-and-transportation/
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering/student-resources
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering/student-resources
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': mailto:eoaa@utep.edu
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife-deans-list.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eec/honors/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-preprofessional-experiences.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': feedback.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': Student-Opportunities.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-women-in-engineering.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../e-newsletter/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../business-center/business-center.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': mailto:engredge@utep.edu
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.youtube.com/user/UTEPengineering
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.instagram.com/engineeringutep/
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': http://sao.fraud.state.tx.us/
# Checking page: http://catalog.utep.edu/policies-regulations/student-life/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': #contentarea
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /azindex/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /degreeprograms/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /undergrad/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /grad/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /course-search/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /contactus/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/student-life/student-life.pdf
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /university/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /admissions/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /paying-college/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/attendance-grading/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/course-adds-drops/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/course-registration/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/graduation-requirements/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/immunization-requirement/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/online-student/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/degree-plans/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': #
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/student-travel-policy-/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/title-ix-compliance/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /student-services/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /degreeprograms/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /undergrad/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /grad/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /archive/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/
# Broken link found on page 'http://catalog.utep.edu/policies-regulations/student-life/': https://www.utep.edu/hoop/section-2/student-conduct-and-discipline.html
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': http://securityoncampus.org/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': mailto:eoaa@utep.edu
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': http://sao.fraud.state.tx.us/
# Connection error occurred for link on page 'http://catalog.utep.edu/policies-regulations/student-life/': #header
# Checking page: https://www.utep.edu/programs/graduate/?utep-home
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': #sidr
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': accountancy-macy.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': bilingual-education-med.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': bioinformatics-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': biological-sciences-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': biomedical-engineering-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': biomedical-engineering-phd.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': biosciences-phd.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': borderlands-history-phd.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': business-administration-mba.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': business-administration-phd.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': chemistry-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': chemistry-phd.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': civil-and-environmental-engineering-me.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': civil-engineering-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': civil-engineering-phd.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': clinical-psychology-ma.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': communication-ma.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': computational-science-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': computational-science-phd.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': computer-engineering-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': computer-science-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': computer-science-phd.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': construction-management-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': creative-writing-mfa.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': criminology-and-criminal-justice-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': curriculum-and-instruction-med.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': data-information-sciences-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': data-science-phd.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': defense-and-strategic-studies-mdss.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': early-childhood-education-med.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': ecology-and-evolutionary-biology-phd.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': economics-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': educational-administration-med.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': educational-diagnostician-med.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': educational-leadership-administration-edd.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': education-ma.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': electrical-and-computer-engineering-phd.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': electrical-engineering-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': engineering-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': english-and-american-literature-ma.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': english-mat.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': environmental-engineering-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': environmental-science-and-engineering-phd.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': environmental-science-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': general-experimental-psychology-ma.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': general-psychology-phd.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': geological-sciences-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': geological-sciences-phd.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': geophysics-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': history-ma.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': industrial-engineering-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': intelligence-and-national-security-studies-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': interdisciplinary-health-sciences-phd.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': interdisciplinary-studies-mais.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': kinesiology-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': latin-american-border-studies-ma.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': leadership-studies-ma.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': linguistics-ma.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': literacy-education-med.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': manufacturing-engineering-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': materials-science-and-engineering-phd.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': mathematics-mat.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': mathematics-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': mechanical-engineering-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': mechanical-engineering-phd.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': mental-health-counseling-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': metallurgical-and-materials-engineering-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': music-mm.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': nurse-practitioner-msn.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': nursing-admin-management-msn.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': nursing-education-msn.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': nursing-practice-dnp.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': occupational-therapy.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': pharmacy-pharmd.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': philosophy-ma.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': physical-therapy-dpt.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': physics-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': political-science-ma.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': professional-science-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': public-administration-mpa.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': public-health-mph.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': rehabilitation-counseling-mrc.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': rhetoric-and-composition-phd.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': rhetoric-and-writing-studies-ma.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': school-counseling-med.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': social-work-msw.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': sociology-ma.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': sociology-phd.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': software-engineering-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': spanish-ma.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': special-education-med.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': speech-language-pathology-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': statistics-and-data-science-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': systems-engineering-ms.html
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': teaching-learning-and-culture-phd.html
# Broken link found on page 'https://www.utep.edu/programs/graduate/?utep-home': https://www.linkedin.com/school/the-university-of-texas-at-el-paso/
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': http://sao.fraud.state.tx.us/
# Connection error occurred for link on page 'https://www.utep.edu/programs/graduate/?utep-home': #
# Broken link found on page 'https://www.utep.edu/programs/graduate/?utep-home': https://utepminers.com/?mc-program-menu
# Checking page: https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Total pages checked: 4
# Total broken links found: 209
# Broken Links Report:
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #mainContentArea
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../about-us/administration.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../fact-sheet/fact-sheet.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../about-us/accreditation.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../academic-programs/degrees-and-programs.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../academic-programs/undergraduate-programs/undergraduate.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../academic-programs/graduate-programs/graduate-programs.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../mechanical/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../civil/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../ece/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eel/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../imse/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../mmbme/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eec/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/awards-and-recognition.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/research-and-support.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': Student-Opportunities.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/newsfeed.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife-deans-list.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eec/honors/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-preprofessional-experiences.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': feedback.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': Student-Opportunities.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-women-in-engineering.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../e-newsletter/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/aspirations/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/discover-e/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/e-week/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/excites/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/robotics/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eweek/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../graduateceremony/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../orderoftheengineer/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../tcm/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /resources/students.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /resources/faculty-and-staff.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /resources/parents.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/vpba/parking-and-transportation/
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering/student-resources
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering/student-resources
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': mailto:eoaa@utep.edu
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife-deans-list.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eec/honors/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-preprofessional-experiences.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': feedback.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': Student-Opportunities.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-women-in-engineering.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../e-newsletter/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../business-center/business-center.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': mailto:engredge@utep.edu
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.youtube.com/user/UTEPengineering
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.instagram.com/engineeringutep/
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': http://sao.fraud.state.tx.us/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': #contentarea
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /azindex/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /degreeprograms/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /undergrad/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /grad/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /course-search/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /contactus/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/student-life/student-life.pdf
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /university/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /admissions/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /paying-college/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/attendance-grading/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/course-adds-drops/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/course-registration/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/graduation-requirements/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/immunization-requirement/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/online-student/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/degree-plans/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': #
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/student-travel-policy-/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/title-ix-compliance/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /student-services/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /degreeprograms/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /undergrad/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /grad/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /archive/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': /policies-regulations/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': https://www.utep.edu/hoop/section-2/student-conduct-and-discipline.html
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': http://securityoncampus.org/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': mailto:eoaa@utep.edu
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': http://sao.fraud.state.tx.us/
# Broken Link on page 'http://catalog.utep.edu/policies-regulations/student-life/': #header
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': #sidr
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': accountancy-macy.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': bilingual-education-med.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': bioinformatics-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': biological-sciences-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': biomedical-engineering-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': biomedical-engineering-phd.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': biosciences-phd.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': borderlands-history-phd.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': business-administration-mba.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': business-administration-phd.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': chemistry-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': chemistry-phd.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': civil-and-environmental-engineering-me.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': civil-engineering-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': civil-engineering-phd.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': clinical-psychology-ma.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': communication-ma.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': computational-science-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': computational-science-phd.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': computer-engineering-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': computer-science-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': computer-science-phd.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': construction-management-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': creative-writing-mfa.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': criminology-and-criminal-justice-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': curriculum-and-instruction-med.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': data-information-sciences-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': data-science-phd.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': defense-and-strategic-studies-mdss.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': early-childhood-education-med.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': ecology-and-evolutionary-biology-phd.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': economics-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': educational-administration-med.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': educational-diagnostician-med.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': educational-leadership-administration-edd.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': education-ma.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': electrical-and-computer-engineering-phd.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': electrical-engineering-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': engineering-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': english-and-american-literature-ma.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': english-mat.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': environmental-engineering-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': environmental-science-and-engineering-phd.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': environmental-science-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': general-experimental-psychology-ma.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': general-psychology-phd.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': geological-sciences-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': geological-sciences-phd.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': geophysics-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': history-ma.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': industrial-engineering-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': intelligence-and-national-security-studies-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': interdisciplinary-health-sciences-phd.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': interdisciplinary-studies-mais.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': kinesiology-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': latin-american-border-studies-ma.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': leadership-studies-ma.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': linguistics-ma.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': literacy-education-med.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': manufacturing-engineering-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': materials-science-and-engineering-phd.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': mathematics-mat.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': mathematics-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': mechanical-engineering-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': mechanical-engineering-phd.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': mental-health-counseling-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': metallurgical-and-materials-engineering-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': music-mm.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': nurse-practitioner-msn.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': nursing-admin-management-msn.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': nursing-education-msn.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': nursing-practice-dnp.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': occupational-therapy.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': pharmacy-pharmd.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': philosophy-ma.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': physical-therapy-dpt.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': physics-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': political-science-ma.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': professional-science-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': public-administration-mpa.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': public-health-mph.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': rehabilitation-counseling-mrc.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': rhetoric-and-composition-phd.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': rhetoric-and-writing-studies-ma.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': school-counseling-med.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': social-work-msw.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': sociology-ma.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': sociology-phd.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': software-engineering-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': spanish-ma.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': special-education-med.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': speech-language-pathology-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': statistics-and-data-science-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': systems-engineering-ms.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': teaching-learning-and-culture-phd.html
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': https://www.linkedin.com/school/the-university-of-texas-at-el-paso/
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': http://sao.fraud.state.tx.us/
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': #
# Broken Link on page 'https://www.utep.edu/programs/graduate/?utep-home': https://utepminers.com/?mc-program-menu

# %%
import openpyxl
import requests
from bs4 import BeautifulSoup

def get_links_from_page(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            links = [link.get('href') for link in soup.find_all('a', href=True)]
            return links
        else:
            return []
    except requests.exceptions.RequestException:
        return []

def check_broken_links(excel_file):
    try:
        print(f"Opening file: {excel_file}...")
        wb = openpyxl.load_workbook(excel_file)
        sheet = wb.active
        column_with_links = 'A'
        
        broken_links_report = []
        total_links_checked = 0
        
        print(f"Checking links inside {excel_file}...")
        for cell in sheet[column_with_links]:
            if cell.value:
                link = cell.value
                print(f"Checking page: {link}")
                total_links_checked += 1
                page_links = get_links_from_page(link)
                print(f"Links extracted from page: {page_links}")
                for page_link in page_links:
                    if page_link:
                        try:
                            response = requests.get(page_link)
                            if response.status_code != 200:
                                broken_links_report.append((link, page_link))
                                print(f"Broken link found on page '{link}': {page_link}")
                            else:
                                print(f"Link is working fine: {page_link}")
                        except requests.exceptions.RequestException:
                            broken_links_report.append((link, page_link))
                            print(f"Connection error occurred for link on page '{link}': {page_link}")

        print(f"Total pages checked: {total_links_checked}")
        print(f"Total broken links found: {len(broken_links_report)}")
        return broken_links_report
    except openpyxl.utils.exceptions.InvalidFileException:
        print(f"Error: Unable to open the file '{excel_file}'. Please check if it's a valid Excel file.")
        return []
    except Exception as e:
        print(f"Error: An unexpected error occurred while processing the file '{excel_file}': {e}")
        return []

if __name__ == "__main__":
    excel_file_path = "example.xlsx"
    broken_links_report = check_broken_links(excel_file_path)

    if broken_links_report:
        print("Broken Links Report:")
        for link, page_link in broken_links_report:
            print(f"Broken Link on page '{link}': {page_link}")
    else:
        print("No broken links found.")
# Out:
# Opening file: example.xlsx...
# Checking links inside example.xlsx...
# Checking page: https://utep.edu/engineering/student-resources/feedback.html
# Links extracted from page: ['#mainContentArea', 'https://www.utep.edu/', '#', '../about-us/administration.html', '../fact-sheet/fact-sheet.html', '../about-us/accreditation.html', 'https://www.utep.edu/engineering/Alumni/index.html', '#', '../academic-programs/degrees-and-programs.html', '../academic-programs/undergraduate-programs/undergraduate.html', 'http://catalog.utep.edu/undergrad/', '../academic-programs/graduate-programs/graduate-programs.html', 'http://catalog.utep.edu/grad/', '#', '../mechanical/index.html', '../civil/index.html', 'https://www.utep.edu/cs/', '../ece/index.html', '../eel/index.html', '../imse/index.html', '../mmbme/index.html', '../eec/index.html', '#', '../research/index.html', '../research/awards-and-recognition.html', '../research/research-and-support.html', 'Student-Opportunities.html', '../research/newsfeed.html', '#', 'https://www.utep.edu/engineering/eec/advisors/index.html', 'student-resources-studentlife-deans-list.html', '../eec/honors/index.html', 'student-resources-preprofessional-experiences.html', 'feedback.html', 'student-resources-studentlife.html', 'Student-Opportunities.html', 'http://etc.utep.edu', 'http://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html', 'student-resources-women-in-engineering.html', '../e-newsletter/index.html', 'https://www.utep.edu/engineering/miningyourpathtosuccess/index.html', '#', 'https://www.utep.edu/engineering/k12/', '../k12/aspirations/index.html', '../k12/discover-e/index.html', '../k12/e-week/index.html', '../k12/excites/index.html', '../k12/robotics/index.html', '#', '../eweek/index.html', 'https://www.utep.edu/engineering/homecoming/', '../graduateceremony/index.html', '../orderoftheengineer/index.html', '../tcm/index.html', '#', 'https://givingto.utep.edu/coeng', '#', 'http://my.utep.edu', '#', '/resources/students.html', '/resources/faculty-and-staff.html', 'http://alumni.utep.edu/', '/resources/parents.html', '#', 'https://www.utep.edu/library/', 'https://www.utep.edu/vpba/parking-and-transportation/ ', 'https://www.utep.edu/newsfeed/', 'https://events.utep.edu/', 'https://www.utep.edu/student-affairs/', 'https://www.utep.edu/vpba/', 'https://www.utep.edu/human-resources/services/employment/index.html', 'http://www.utepbookstore.com', 'https://www.utep.edu/technologysupport/', '/engineering ', 'https://www.utep.edu', '/engineering     ', '/engineering/student-resources     ', 'https://www.utep.edu', '/engineering     ', '/engineering/student-resources     ', 'https://utep.questionpro.com/t/AO6lJZvkI0', 'http://catalog.utep.edu/policies-regulations/student-life/', 'mailto:eoaa@utep.edu', 'https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html', 'https://www.utep.edu/student-affairs/dean-of-students-office/resources/grade-grievance.html', 'https://utep.questionpro.com/t/AO6lJZvkJW', 'http://catalog.utep.edu/policies-regulations/student-life/', 'https://www.utep.edu/titleix/', 'https://www.utep.edu/engineering/eec/advisors/index.html', 'student-resources-studentlife-deans-list.html', '../eec/honors/index.html', 'student-resources-preprofessional-experiences.html', 'feedback.html', 'student-resources-studentlife.html', 'Student-Opportunities.html', 'http://etc.utep.edu', 'https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html', 'student-resources-women-in-engineering.html', '../e-newsletter/index.html', 'https://www.utep.edu/engineering/miningyourpathtosuccess/index.html', 'https://www.utep.edu/student-affairs/admissions/', 'http://catalog.utep.edu/undergrad/', 'http://www.utep.edu/graduate/apply-now/apply-now.html', 'http://catalog.utep.edu/grad/', '../business-center/business-center.html', 'http://etc.utep.edu', 'https://events.utep.edu/calendar/upcoming?event_types%5B%5D=126310', 'https://www.utep.edu/engineering/student-resources/feedback.html?helpfullinks', 'mailto:engredge@utep.edu\xa0 ', 'https://www.facebook.com/utepengineering ', 'htt ...
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #mainContentArea
# Link is working fine: https://www.utep.edu/
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../about-us/administration.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../fact-sheet/fact-sheet.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../about-us/accreditation.html
# Link is working fine: https://www.utep.edu/engineering/Alumni/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../academic-programs/degrees-and-programs.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../academic-programs/undergraduate-programs/undergraduate.html
# Link is working fine: http://catalog.utep.edu/undergrad/
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../academic-programs/graduate-programs/graduate-programs.html
# Link is working fine: http://catalog.utep.edu/grad/
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../mechanical/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../civil/index.html
# Link is working fine: https://www.utep.edu/cs/
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../ece/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eel/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../imse/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../mmbme/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eec/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/awards-and-recognition.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/research-and-support.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': Student-Opportunities.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/newsfeed.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Link is working fine: https://www.utep.edu/engineering/eec/advisors/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife-deans-list.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eec/honors/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-preprofessional-experiences.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': feedback.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': Student-Opportunities.html
# Link is working fine: http://etc.utep.edu
# Link is working fine: http://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-women-in-engineering.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Link is working fine: https://www.utep.edu/engineering/k12/
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/aspirations/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/discover-e/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/e-week/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/excites/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/robotics/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eweek/index.html
# Link is working fine: https://www.utep.edu/engineering/homecoming/
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../graduateceremony/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../orderoftheengineer/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../tcm/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Link is working fine: https://givingto.utep.edu/coeng
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Link is working fine: http://my.utep.edu
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /resources/students.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /resources/faculty-and-staff.html
# Link is working fine: http://alumni.utep.edu/
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /resources/parents.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Link is working fine: https://www.utep.edu/library/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/vpba/parking-and-transportation/
# Link is working fine: https://www.utep.edu/newsfeed/
# Link is working fine: https://events.utep.edu/
# Link is working fine: https://www.utep.edu/student-affairs/
# Link is working fine: https://www.utep.edu/vpba/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: http://www.utepbookstore.com
# Link is working fine: https://www.utep.edu/technologysupport/
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering
# Link is working fine: https://www.utep.edu
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering/student-resources
# Link is working fine: https://www.utep.edu
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering/student-resources
# Link is working fine: https://utep.questionpro.com/t/AO6lJZvkI0
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': mailto:eoaa@utep.edu
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Link is working fine: https://www.utep.edu/student-affairs/dean-of-students-office/resources/grade-grievance.html
# Link is working fine: https://utep.questionpro.com/t/AO6lJZvkJW
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# Link is working fine: https://www.utep.edu/titleix/
# Link is working fine: https://www.utep.edu/engineering/eec/advisors/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife-deans-list.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eec/honors/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-preprofessional-experiences.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': feedback.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': Student-Opportunities.html
# Link is working fine: http://etc.utep.edu
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-women-in-engineering.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/student-affairs/admissions/
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: http://www.utep.edu/graduate/apply-now/apply-now.html
# Link is working fine: http://catalog.utep.edu/grad/
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../business-center/business-center.html
# Link is working fine: http://etc.utep.edu
# Link is working fine: https://events.utep.edu/calendar/upcoming?event_types%5B%5D=126310
# Link is working fine: https://www.utep.edu/engineering/student-resources/feedback.html?helpfullinks
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': mailto:engredge@utep.edu
# Link is working fine: https://www.facebook.com/utepengineering
# Link is working fine: https://twitter.com/utep
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.youtube.com/user/UTEPengineering
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.instagram.com/engineeringutep/
# Link is working fine: https://www.utep.edu/utepcares/cares-act-compliance/
# Link is working fine: https://www.utep.edu/clery/
# Link is working fine: https://www.utep.edu/emergency/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.utep.edu/student-affairs/resources/Mental-Health-Resources-for-UTEP-Students.html
# Link is working fine: https://www.utep.edu/resources/public-course-information.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': http://sao.fraud.state.tx.us/
# Link is working fine: https://www.utep.edu/required-links/
# Link is working fine: https://www.utep.edu/vpba/state-reports/
# Link is working fine: https://veterans.portal.texas.gov
# Link is working fine: https://www.utep.edu/titleix/Filing-a-Complaint.html
# Link is working fine: https://www.utep.edu/hoop/section-6/ch-3.html
# Link is working fine: http://www.utsystem.edu/
# Link is working fine: https://www.utep.edu/eoaa/policies/accessibility-policy.html
# Link is working fine: https://www.utep.edu/information-resources/iso/policies/web-privacy-policies.html
# Link is working fine: https://www.utep.edu/feedback
# Total pages checked: 1
# Total broken links found: 71
# Broken Links Report:
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #mainContentArea
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../about-us/administration.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../fact-sheet/fact-sheet.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../about-us/accreditation.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../academic-programs/degrees-and-programs.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../academic-programs/undergraduate-programs/undergraduate.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../academic-programs/graduate-programs/graduate-programs.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../mechanical/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../civil/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../ece/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eel/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../imse/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../mmbme/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eec/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/awards-and-recognition.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/research-and-support.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': Student-Opportunities.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/newsfeed.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife-deans-list.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eec/honors/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-preprofessional-experiences.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': feedback.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': Student-Opportunities.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-women-in-engineering.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../e-newsletter/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/aspirations/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/discover-e/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/e-week/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/excites/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/robotics/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eweek/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../graduateceremony/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../orderoftheengineer/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../tcm/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /resources/students.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /resources/faculty-and-staff.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /resources/parents.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': #
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/vpba/parking-and-transportation/
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering/student-resources
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering/student-resources
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': mailto:eoaa@utep.edu
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife-deans-list.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eec/honors/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-preprofessional-experiences.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': feedback.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': Student-Opportunities.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-women-in-engineering.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../e-newsletter/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../business-center/business-center.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': mailto:engredge@utep.edu
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.youtube.com/user/UTEPengineering
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.instagram.com/engineeringutep/
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': http://sao.fraud.state.tx.us/

# %%
import openpyxl
import requests
from bs4 import BeautifulSoup

def get_links_from_page(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            links = [link.get('href') for link in soup.find_all('a', href=True)]
            return links
        else:
            return []
    except requests.exceptions.RequestException:
        return []

def is_valid_link(link):
    if link and not link.startswith("mailto:") and not link.startswith("#"):
        return True
    return False

def check_broken_links(excel_file):
    try:
        print(f"Opening file: {excel_file}...")
        wb = openpyxl.load_workbook(excel_file)
        sheet = wb.active
        column_with_links = 'A'
        
        broken_links_report = []
        total_links_checked = 0
        
        print(f"Checking links inside {excel_file}...")
        for cell in sheet[column_with_links]:
            if cell.value:
                link = cell.value
                print(f"Checking page: {link}")
                total_links_checked += 1
                page_links = get_links_from_page(link)
                print(f"Links extracted from page: {page_links}")
                for page_link in page_links:
                    if is_valid_link(page_link):
                        try:
                            response = requests.get(page_link)
                            if response.status_code != 200:
                                broken_links_report.append((link, page_link))
                                print(f"Broken link found on page '{link}': {page_link}")
                            else:
                                print(f"Link is working fine: {page_link}")
                        except requests.exceptions.RequestException:
                            broken_links_report.append((link, page_link))
                            print(f"Connection error occurred for link on page '{link}': {page_link}")

        print(f"Total pages checked: {total_links_checked}")
        print(f"Total broken links found: {len(broken_links_report)}")
        return broken_links_report
    except openpyxl.utils.exceptions.InvalidFileException:
        print(f"Error: Unable to open the file '{excel_file}'. Please check if it's a valid Excel file.")
        return []
    except Exception as e:
        print(f"Error: An unexpected error occurred while processing the file '{excel_file}': {e}")
        return []

if __name__ == "__main__":
    excel_file_path = "example.xlsx"
    broken_links_report = check_broken_links(excel_file_path)

    if broken_links_report:
        print("Broken Links Report:")
        for link, page_link in broken_links_report:
            print(f"Broken Link on page '{link}': {page_link}")
    else:
        print("No broken links found.")
# Out:
# Opening file: example.xlsx...
# Checking links inside example.xlsx...
# Checking page: https://utep.edu/engineering/student-resources/feedback.html
# Links extracted from page: ['#mainContentArea', 'https://www.utep.edu/', '#', '../about-us/administration.html', '../fact-sheet/fact-sheet.html', '../about-us/accreditation.html', 'https://www.utep.edu/engineering/Alumni/index.html', '#', '../academic-programs/degrees-and-programs.html', '../academic-programs/undergraduate-programs/undergraduate.html', 'http://catalog.utep.edu/undergrad/', '../academic-programs/graduate-programs/graduate-programs.html', 'http://catalog.utep.edu/grad/', '#', '../mechanical/index.html', '../civil/index.html', 'https://www.utep.edu/cs/', '../ece/index.html', '../eel/index.html', '../imse/index.html', '../mmbme/index.html', '../eec/index.html', '#', '../research/index.html', '../research/awards-and-recognition.html', '../research/research-and-support.html', 'Student-Opportunities.html', '../research/newsfeed.html', '#', 'https://www.utep.edu/engineering/eec/advisors/index.html', 'student-resources-studentlife-deans-list.html', '../eec/honors/index.html', 'student-resources-preprofessional-experiences.html', 'feedback.html', 'student-resources-studentlife.html', 'Student-Opportunities.html', 'http://etc.utep.edu', 'http://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html', 'student-resources-women-in-engineering.html', '../e-newsletter/index.html', 'https://www.utep.edu/engineering/miningyourpathtosuccess/index.html', '#', 'https://www.utep.edu/engineering/k12/', '../k12/aspirations/index.html', '../k12/discover-e/index.html', '../k12/e-week/index.html', '../k12/excites/index.html', '../k12/robotics/index.html', '#', '../eweek/index.html', 'https://www.utep.edu/engineering/homecoming/', '../graduateceremony/index.html', '../orderoftheengineer/index.html', '../tcm/index.html', '#', 'https://givingto.utep.edu/coeng', '#', 'http://my.utep.edu', '#', '/resources/students.html', '/resources/faculty-and-staff.html', 'http://alumni.utep.edu/', '/resources/parents.html', '#', 'https://www.utep.edu/library/', 'https://www.utep.edu/vpba/parking-and-transportation/ ', 'https://www.utep.edu/newsfeed/', 'https://events.utep.edu/', 'https://www.utep.edu/student-affairs/', 'https://www.utep.edu/vpba/', 'https://www.utep.edu/human-resources/services/employment/index.html', 'http://www.utepbookstore.com', 'https://www.utep.edu/technologysupport/', '/engineering ', 'https://www.utep.edu', '/engineering     ', '/engineering/student-resources     ', 'https://www.utep.edu', '/engineering     ', '/engineering/student-resources     ', 'https://utep.questionpro.com/t/AO6lJZvkI0', 'http://catalog.utep.edu/policies-regulations/student-life/', 'mailto:eoaa@utep.edu', 'https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html', 'https://www.utep.edu/student-affairs/dean-of-students-office/resources/grade-grievance.html', 'https://utep.questionpro.com/t/AO6lJZvkJW', 'http://catalog.utep.edu/policies-regulations/student-life/', 'https://www.utep.edu/titleix/', 'https://www.utep.edu/engineering/eec/advisors/index.html', 'student-resources-studentlife-deans-list.html', '../eec/honors/index.html', 'student-resources-preprofessional-experiences.html', 'feedback.html', 'student-resources-studentlife.html', 'Student-Opportunities.html', 'http://etc.utep.edu', 'https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html', 'student-resources-women-in-engineering.html', '../e-newsletter/index.html', 'https://www.utep.edu/engineering/miningyourpathtosuccess/index.html', 'https://www.utep.edu/student-affairs/admissions/', 'http://catalog.utep.edu/undergrad/', 'http://www.utep.edu/graduate/apply-now/apply-now.html', 'http://catalog.utep.edu/grad/', '../business-center/business-center.html', 'http://etc.utep.edu', 'https://events.utep.edu/calendar/upcoming?event_types%5B%5D=126310', 'https://www.utep.edu/engineering/student-resources/feedback.html?helpfullinks', 'mailto:engredge@utep.edu\xa0 ', 'https://www.facebook.com/utepengineering ', 'htt ...
# Link is working fine: https://www.utep.edu/
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../about-us/administration.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../fact-sheet/fact-sheet.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../about-us/accreditation.html
# Link is working fine: https://www.utep.edu/engineering/Alumni/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../academic-programs/degrees-and-programs.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../academic-programs/undergraduate-programs/undergraduate.html
# Link is working fine: http://catalog.utep.edu/undergrad/
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../academic-programs/graduate-programs/graduate-programs.html
# Link is working fine: http://catalog.utep.edu/grad/
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../mechanical/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../civil/index.html
# Link is working fine: https://www.utep.edu/cs/
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../ece/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eel/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../imse/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../mmbme/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eec/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/awards-and-recognition.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/research-and-support.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': Student-Opportunities.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/newsfeed.html
# Link is working fine: https://www.utep.edu/engineering/eec/advisors/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife-deans-list.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eec/honors/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-preprofessional-experiences.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': feedback.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': Student-Opportunities.html
# Link is working fine: http://etc.utep.edu
# Link is working fine: http://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-women-in-engineering.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/engineering/k12/
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/aspirations/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/discover-e/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/e-week/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/excites/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/robotics/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eweek/index.html
# Link is working fine: https://www.utep.edu/engineering/homecoming/
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../graduateceremony/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../orderoftheengineer/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../tcm/index.html
# Link is working fine: https://givingto.utep.edu/coeng
# Link is working fine: http://my.utep.edu
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /resources/students.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /resources/faculty-and-staff.html
# Link is working fine: http://alumni.utep.edu/
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /resources/parents.html
# Link is working fine: https://www.utep.edu/library/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/vpba/parking-and-transportation/
# Link is working fine: https://www.utep.edu/newsfeed/
# Link is working fine: https://events.utep.edu/
# Link is working fine: https://www.utep.edu/student-affairs/
# Link is working fine: https://www.utep.edu/vpba/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': http://www.utepbookstore.com
# Link is working fine: https://www.utep.edu/technologysupport/
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering
# Link is working fine: https://www.utep.edu
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering/student-resources
# Link is working fine: https://www.utep.edu
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering/student-resources
# Link is working fine: https://utep.questionpro.com/t/AO6lJZvkI0
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Link is working fine: https://www.utep.edu/student-affairs/dean-of-students-office/resources/grade-grievance.html
# Link is working fine: https://utep.questionpro.com/t/AO6lJZvkJW
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# Link is working fine: https://www.utep.edu/titleix/
# Link is working fine: https://www.utep.edu/engineering/eec/advisors/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife-deans-list.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eec/honors/index.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-preprofessional-experiences.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': feedback.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': Student-Opportunities.html
# Link is working fine: http://etc.utep.edu
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-women-in-engineering.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/student-affairs/admissions/
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: http://www.utep.edu/graduate/apply-now/apply-now.html
# Link is working fine: http://catalog.utep.edu/grad/
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../business-center/business-center.html
# Link is working fine: http://etc.utep.edu
# Link is working fine: https://events.utep.edu/calendar/upcoming?event_types%5B%5D=126310
# Link is working fine: https://www.utep.edu/engineering/student-resources/feedback.html?helpfullinks
# Link is working fine: https://www.facebook.com/utepengineering
# Link is working fine: https://twitter.com/utep
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.youtube.com/user/UTEPengineering
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.instagram.com/engineeringutep/
# Link is working fine: https://www.utep.edu/utepcares/cares-act-compliance/
# Link is working fine: https://www.utep.edu/clery/
# Link is working fine: https://www.utep.edu/emergency/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.utep.edu/student-affairs/resources/Mental-Health-Resources-for-UTEP-Students.html
# Link is working fine: https://www.utep.edu/resources/public-course-information.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': http://sao.fraud.state.tx.us/
# Link is working fine: https://www.utep.edu/required-links/
# Link is working fine: https://www.utep.edu/vpba/state-reports/
# Link is working fine: https://veterans.portal.texas.gov
# Link is working fine: https://www.utep.edu/titleix/Filing-a-Complaint.html
# Link is working fine: https://www.utep.edu/hoop/section-6/ch-3.html
# Link is working fine: http://www.utsystem.edu/
# Link is working fine: https://www.utep.edu/eoaa/policies/accessibility-policy.html
# Link is working fine: https://www.utep.edu/information-resources/iso/policies/web-privacy-policies.html
# Link is working fine: https://www.utep.edu/feedback
# Total pages checked: 1
# Total broken links found: 58
# Broken Links Report:
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../about-us/administration.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../fact-sheet/fact-sheet.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../about-us/accreditation.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../academic-programs/degrees-and-programs.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../academic-programs/undergraduate-programs/undergraduate.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../academic-programs/graduate-programs/graduate-programs.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../mechanical/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../civil/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../ece/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eel/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../imse/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../mmbme/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eec/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/awards-and-recognition.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/research-and-support.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': Student-Opportunities.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../research/newsfeed.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife-deans-list.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eec/honors/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-preprofessional-experiences.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': feedback.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': Student-Opportunities.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-women-in-engineering.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../e-newsletter/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/aspirations/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/discover-e/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/e-week/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/excites/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../k12/robotics/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eweek/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../graduateceremony/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../orderoftheengineer/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../tcm/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /resources/students.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /resources/faculty-and-staff.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /resources/parents.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/vpba/parking-and-transportation/
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': http://www.utepbookstore.com
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering/student-resources
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': /engineering/student-resources
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife-deans-list.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../eec/honors/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-preprofessional-experiences.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': feedback.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-studentlife.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': Student-Opportunities.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': student-resources-women-in-engineering.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../e-newsletter/index.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': ../business-center/business-center.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.youtube.com/user/UTEPengineering
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.instagram.com/engineeringutep/
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': http://sao.fraud.state.tx.us/

# %%
import openpyxl
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

def get_links_from_page(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            links = [link.get('href') for link in soup.find_all('a', href=True)]
            return links
        else:
            return []
    except requests.exceptions.RequestException:
        return []

def is_valid_link(link):
    if link and not link.startswith("mailto:") and not link.startswith("#"):
        return True
    return False

def check_broken_links(excel_file):
    try:
        print(f"Opening file: {excel_file}...")
        wb = openpyxl.load_workbook(excel_file)
        sheet = wb.active
        column_with_links = 'A'
        
        broken_links_report = []
        total_links_checked = 0
        
        print(f"Checking links inside {excel_file}...")
        for cell in sheet[column_with_links]:
            if cell.value:
                link = cell.value
                print(f"Checking page: {link}")
                total_links_checked += 1
                page_links = get_links_from_page(link)
                #print(f"Links extracted from page: {page_links}")
                for page_link in page_links:
                    if is_valid_link(page_link):
                        absolute_link = urljoin(link, page_link)
                        try:
                            response = requests.get(absolute_link)
                            if response.status_code != 200:
                                broken_links_report.append((link, absolute_link))
                                print(f"Broken link found on page '{link}': {absolute_link}")
                            else:
                                print(f"Link is working fine: {absolute_link}")
                        except requests.exceptions.RequestException:
                            broken_links_report.append((link, absolute_link))
                            print(f"Connection error occurred for link on page '{link}': {absolute_link}")

        print(f"Total pages checked: {total_links_checked}")
        print(f"Total broken links found: {len(broken_links_report)}")
        return broken_links_report
    except openpyxl.utils.exceptions.InvalidFileException:
        print(f"Error: Unable to open the file '{excel_file}'. Please check if it's a valid Excel file.")
        return []
    except Exception as e:
        print(f"Error: An unexpected error occurred while processing the file '{excel_file}': {e}")
        return []

if __name__ == "__main__":
    excel_file_path = "example.xlsx"
    broken_links_report = check_broken_links(excel_file_path)

    if broken_links_report:
        print("Broken Links Report:")
        for link, page_link in broken_links_report:
            print(f"Broken Link on page '{link}': {page_link}")
    else:
        print("No broken links found.")
# Out:
# Opening file: example.xlsx...
# Checking links inside example.xlsx...
# Checking page: https://utep.edu/engineering/student-resources/feedback.html
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://utep.edu/engineering/about-us/administration.html
# Link is working fine: https://utep.edu/engineering/fact-sheet/fact-sheet.html
# Link is working fine: https://utep.edu/engineering/about-us/accreditation.html
# Link is working fine: https://www.utep.edu/engineering/Alumni/index.html
# Link is working fine: https://utep.edu/engineering/academic-programs/degrees-and-programs.html
# Link is working fine: https://utep.edu/engineering/academic-programs/undergraduate-programs/undergraduate.html
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: https://utep.edu/engineering/academic-programs/graduate-programs/graduate-programs.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://utep.edu/engineering/mechanical/index.html
# Link is working fine: https://utep.edu/engineering/civil/index.html
# Link is working fine: https://www.utep.edu/cs/
# Link is working fine: https://utep.edu/engineering/ece/index.html
# Link is working fine: https://utep.edu/engineering/eel/index.html
# Link is working fine: https://utep.edu/engineering/imse/index.html
# Link is working fine: https://utep.edu/engineering/mmbme/index.html
# Link is working fine: https://utep.edu/engineering/eec/index.html
# Link is working fine: https://utep.edu/engineering/research/index.html
# Link is working fine: https://utep.edu/engineering/research/awards-and-recognition.html
# Link is working fine: https://utep.edu/engineering/research/research-and-support.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: https://utep.edu/engineering/research/newsfeed.html
# Link is working fine: https://www.utep.edu/engineering/eec/advisors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Link is working fine: https://utep.edu/engineering/eec/honors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://utep.edu/engineering/student-resources/feedback.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: http://etc.utep.edu
# Link is working fine: http://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/engineering/k12/
# Link is working fine: https://utep.edu/engineering/k12/aspirations/index.html
# Link is working fine: https://utep.edu/engineering/k12/discover-e/index.html
# Link is working fine: https://utep.edu/engineering/k12/e-week/index.html
# Link is working fine: https://utep.edu/engineering/k12/excites/index.html
# Link is working fine: https://utep.edu/engineering/k12/robotics/index.html
# Link is working fine: https://utep.edu/engineering/eweek/index.html
# Link is working fine: https://www.utep.edu/engineering/homecoming/
# Link is working fine: https://utep.edu/engineering/graduateceremony/index.html
# Link is working fine: https://utep.edu/engineering/orderoftheengineer/index.html
# Link is working fine: https://utep.edu/engineering/tcm/index.html
# Link is working fine: https://givingto.utep.edu/coeng
# Link is working fine: http://my.utep.edu
# Link is working fine: https://utep.edu/resources/students.html
# Link is working fine: https://utep.edu/resources/faculty-and-staff.html
# Link is working fine: http://alumni.utep.edu/
# Link is working fine: https://utep.edu/resources/parents.html
# Link is working fine: https://www.utep.edu/library/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/vpba/parking-and-transportation/
# Link is working fine: https://www.utep.edu/newsfeed/
# Link is working fine: https://events.utep.edu/
# Link is working fine: https://www.utep.edu/student-affairs/
# Link is working fine: https://www.utep.edu/vpba/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: http://www.utepbookstore.com
# Link is working fine: https://www.utep.edu/technologysupport/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering
# Link is working fine: https://www.utep.edu
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering/student-resources
# Link is working fine: https://www.utep.edu
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering/student-resources
# Link is working fine: https://utep.questionpro.com/t/AO6lJZvkI0
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Link is working fine: https://www.utep.edu/student-affairs/dean-of-students-office/resources/grade-grievance.html
# Link is working fine: https://utep.questionpro.com/t/AO6lJZvkJW
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# Link is working fine: https://www.utep.edu/titleix/
# Link is working fine: https://www.utep.edu/engineering/eec/advisors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Link is working fine: https://utep.edu/engineering/eec/honors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://utep.edu/engineering/student-resources/feedback.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: http://etc.utep.edu
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/student-affairs/admissions/
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: http://www.utep.edu/graduate/apply-now/apply-now.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://utep.edu/engineering/business-center/business-center.html
# Link is working fine: http://etc.utep.edu
# Link is working fine: https://events.utep.edu/calendar/upcoming?event_types%5B%5D=126310
# Link is working fine: https://www.utep.edu/engineering/student-resources/feedback.html?helpfullinks
# Link is working fine: https://www.facebook.com/utepengineering
# Link is working fine: https://twitter.com/utep
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.youtube.com/user/UTEPengineering
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.instagram.com/engineeringutep/
# Link is working fine: https://www.utep.edu/utepcares/cares-act-compliance/
# Link is working fine: https://www.utep.edu/clery/
# Link is working fine: https://www.utep.edu/emergency/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.utep.edu/student-affairs/resources/Mental-Health-Resources-for-UTEP-Students.html
# Link is working fine: https://www.utep.edu/resources/public-course-information.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': http://sao.fraud.state.tx.us/
# Link is working fine: https://www.utep.edu/required-links/
# Link is working fine: https://www.utep.edu/vpba/state-reports/
# Link is working fine: https://veterans.portal.texas.gov
# Link is working fine: https://www.utep.edu/titleix/Filing-a-Complaint.html
# Link is working fine: https://www.utep.edu/hoop/section-6/ch-3.html
# Link is working fine: http://www.utsystem.edu/
# Link is working fine: https://www.utep.edu/eoaa/policies/accessibility-policy.html
# Link is working fine: https://www.utep.edu/information-resources/iso/policies/web-privacy-policies.html
# Link is working fine: https://www.utep.edu/feedback
# Total pages checked: 1
# Total broken links found: 10
# Broken Links Report:
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/vpba/parking-and-transportation/
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering/student-resources
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering/student-resources
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.youtube.com/user/UTEPengineering
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.instagram.com/engineeringutep/
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': http://sao.fraud.state.tx.us/

# %%
import openpyxl
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

def get_links_from_page(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            links = [link.get('href') for link in soup.find_all('a', href=True)]
            return links
        else:
            return []
    except requests.exceptions.RequestException:
        return []

def is_valid_link(link):
    if link and not link.startswith("mailto:") and not link.startswith("#"):
        return True
    return False

def check_broken_links(excel_file):
    try:
        print(f"Opening file: {excel_file}...")
        wb = openpyxl.load_workbook(excel_file)
        sheet = wb.active
        column_with_links = 'A'
        
        broken_links_report = []
        total_links_checked = 0
        
        print(f"Checking links inside {excel_file}...")
        for cell in sheet[column_with_links]:
            if cell.value:
                link = cell.value
                print(f"Checking page: {link}")
                total_links_checked += 1
                page_links = get_links_from_page(link)
                #print(f"Links extracted from page: {page_links}")
                for page_link in page_links:
                    if is_valid_link(page_link):
                        absolute_link = urljoin(link, page_link)
                        try:
                            response = requests.get(absolute_link)
                            if response.status_code != 200:
                                if (link, absolute_link) not in broken_links_report:  # Check if link is not already in the list
                                    broken_links_report.append((link, absolute_link))
                                    print(f"Broken link found on page '{link}': {absolute_link}")
                                else:
                                    print(f"Duplicate broken link found on page '{link}': {absolute_link}")
                            else:
                                print(f"Link is working fine: {absolute_link}")
                        except requests.exceptions.RequestException:
                            if (link, absolute_link) not in broken_links_report:  # Check if link is not already in the list
                                broken_links_report.append((link, absolute_link))
                                print(f"Connection error occurred for link on page '{link}': {absolute_link}")
                            else:
                                print(f"Duplicate connection error occurred for link on page '{link}': {absolute_link}")

        print(f"Total pages checked: {total_links_checked}")
        print(f"Total broken links found: {len(broken_links_report)}")
        return broken_links_report
    except openpyxl.utils.exceptions.InvalidFileException:
        print(f"Error: Unable to open the file '{excel_file}'. Please check if it's a valid Excel file.")
        return []
    except Exception as e:
        print(f"Error: An unexpected error occurred while processing the file '{excel_file}': {e}")
        return []

if __name__ == "__main__":
    excel_file_path = "example.xlsx"
    broken_links_report = check_broken_links(excel_file_path)

    if broken_links_report:
        print("Broken Links Report:")
        for link, page_link in broken_links_report:
            print(f"Broken Link on page '{link}': {page_link}")
    else:
        print("No broken links found.")
# Out:
# Opening file: example.xlsx...
# Checking links inside example.xlsx...
# Checking page: https://utep.edu/engineering/student-resources/feedback.html
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://utep.edu/engineering/about-us/administration.html
# Link is working fine: https://utep.edu/engineering/fact-sheet/fact-sheet.html
# Link is working fine: https://utep.edu/engineering/about-us/accreditation.html
# Link is working fine: https://www.utep.edu/engineering/Alumni/index.html
# Link is working fine: https://utep.edu/engineering/academic-programs/degrees-and-programs.html
# Link is working fine: https://utep.edu/engineering/academic-programs/undergraduate-programs/undergraduate.html
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: https://utep.edu/engineering/academic-programs/graduate-programs/graduate-programs.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://utep.edu/engineering/mechanical/index.html
# Link is working fine: https://utep.edu/engineering/civil/index.html
# Link is working fine: https://www.utep.edu/cs/
# Link is working fine: https://utep.edu/engineering/ece/index.html
# Link is working fine: https://utep.edu/engineering/eel/index.html
# Link is working fine: https://utep.edu/engineering/imse/index.html
# Link is working fine: https://utep.edu/engineering/mmbme/index.html
# Link is working fine: https://utep.edu/engineering/eec/index.html
# Link is working fine: https://utep.edu/engineering/research/index.html
# Link is working fine: https://utep.edu/engineering/research/awards-and-recognition.html
# Link is working fine: https://utep.edu/engineering/research/research-and-support.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: https://utep.edu/engineering/research/newsfeed.html
# Link is working fine: https://www.utep.edu/engineering/eec/advisors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Link is working fine: https://utep.edu/engineering/eec/honors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://utep.edu/engineering/student-resources/feedback.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: http://etc.utep.edu
# Link is working fine: http://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/engineering/k12/
# Link is working fine: https://utep.edu/engineering/k12/aspirations/index.html
# Link is working fine: https://utep.edu/engineering/k12/discover-e/index.html
# Link is working fine: https://utep.edu/engineering/k12/e-week/index.html
# Link is working fine: https://utep.edu/engineering/k12/excites/index.html
# Link is working fine: https://utep.edu/engineering/k12/robotics/index.html
# Link is working fine: https://utep.edu/engineering/eweek/index.html
# Link is working fine: https://www.utep.edu/engineering/homecoming/
# Link is working fine: https://utep.edu/engineering/graduateceremony/index.html
# Link is working fine: https://utep.edu/engineering/orderoftheengineer/index.html
# Link is working fine: https://utep.edu/engineering/tcm/index.html
# Link is working fine: https://givingto.utep.edu/coeng
# Link is working fine: http://my.utep.edu
# Link is working fine: https://utep.edu/resources/students.html
# Link is working fine: https://utep.edu/resources/faculty-and-staff.html
# Link is working fine: http://alumni.utep.edu/
# Link is working fine: https://utep.edu/resources/parents.html
# Link is working fine: https://www.utep.edu/library/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/vpba/parking-and-transportation/
# Link is working fine: https://www.utep.edu/newsfeed/
# Link is working fine: https://events.utep.edu/
# Link is working fine: https://www.utep.edu/student-affairs/
# Link is working fine: https://www.utep.edu/vpba/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: http://www.utepbookstore.com
# Link is working fine: https://www.utep.edu/technologysupport/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering
# Link is working fine: https://www.utep.edu
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering/student-resources
# Link is working fine: https://www.utep.edu
# Duplicate broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering
# Duplicate broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering/student-resources
# Link is working fine: https://utep.questionpro.com/t/AO6lJZvkI0
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Link is working fine: https://www.utep.edu/student-affairs/dean-of-students-office/resources/grade-grievance.html
# Link is working fine: https://utep.questionpro.com/t/AO6lJZvkJW
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# Link is working fine: https://www.utep.edu/titleix/
# Link is working fine: https://www.utep.edu/engineering/eec/advisors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Link is working fine: https://utep.edu/engineering/eec/honors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://utep.edu/engineering/student-resources/feedback.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: http://etc.utep.edu
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/student-affairs/admissions/
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: http://www.utep.edu/graduate/apply-now/apply-now.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://utep.edu/engineering/business-center/business-center.html
# Link is working fine: http://etc.utep.edu
# Link is working fine: https://events.utep.edu/calendar/upcoming?event_types%5B%5D=126310
# Link is working fine: https://www.utep.edu/engineering/student-resources/feedback.html?helpfullinks
# Link is working fine: https://www.facebook.com/utepengineering
# Link is working fine: https://twitter.com/utep
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.youtube.com/user/UTEPengineering
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.instagram.com/engineeringutep/
# Link is working fine: https://www.utep.edu/utepcares/cares-act-compliance/
# Link is working fine: https://www.utep.edu/clery/
# Link is working fine: https://www.utep.edu/emergency/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.utep.edu/student-affairs/resources/Mental-Health-Resources-for-UTEP-Students.html
# Link is working fine: https://www.utep.edu/resources/public-course-information.html
# Connection error occurred for link on page 'https://utep.edu/engineering/student-resources/feedback.html': http://sao.fraud.state.tx.us/
# Link is working fine: https://www.utep.edu/required-links/
# Link is working fine: https://www.utep.edu/vpba/state-reports/
# Link is working fine: https://veterans.portal.texas.gov
# Link is working fine: https://www.utep.edu/titleix/Filing-a-Complaint.html
# Link is working fine: https://www.utep.edu/hoop/section-6/ch-3.html
# Link is working fine: http://www.utsystem.edu/
# Link is working fine: https://www.utep.edu/eoaa/policies/accessibility-policy.html
# Link is working fine: https://www.utep.edu/information-resources/iso/policies/web-privacy-policies.html
# Link is working fine: https://www.utep.edu/feedback
# Total pages checked: 1
# Total broken links found: 8
# Broken Links Report:
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/vpba/parking-and-transportation/
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering/student-resources
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.youtube.com/user/UTEPengineering
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.instagram.com/engineeringutep/
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': http://sao.fraud.state.tx.us/

# %%
import openpyxl
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

def get_final_url(url):
    try:
        response = requests.get(url, allow_redirects=True)
        return response.url
    except requests.exceptions.RequestException:
        return None

def get_links_from_page(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            links = [link.get('href') for link in soup.find_all('a', href=True)]
            return links
        else:
            return []
    except requests.exceptions.RequestException:
        return []

def is_valid_link(link):
    if link and not link.startswith("mailto:") and not link.startswith("#"):
        return True
    return False

def check_broken_links(excel_file):
    try:
        print(f"Opening file: {excel_file}...")
        wb = openpyxl.load_workbook(excel_file)
        sheet = wb.active
        column_with_links = 'A'
        
        broken_links_report = []
        total_links_checked = 0
        
        print(f"Checking links inside {excel_file}...")
        for cell in sheet[column_with_links]:
            if cell.value:
                link = cell.value
                print(f"Checking page: {link}")
                total_links_checked += 1
                page_links = get_links_from_page(link)
                #print(f"Links extracted from page: {page_links}")
                for page_link in page_links:
                    if is_valid_link(page_link):
                        absolute_link = urljoin(link, page_link)
                        final_url = get_final_url(absolute_link)
                        if final_url is not None:
                            try:
                                response = requests.get(final_url)
                                if response.status_code != 200:
                                    if (link, final_url) not in broken_links_report:
                                        broken_links_report.append((link, final_url))
                                        print(f"Broken link found on page '{link}': {final_url}")
                                    else:
                                        print(f"Duplicate broken link found on page '{link}': {final_url}")
                                else:
                                    print(f"Link is working fine: {final_url}")
                            except requests.exceptions.RequestException:
                                if (link, final_url) not in broken_links_report:
                                    broken_links_report.append((link, final_url))
                                    print(f"Connection error occurred for link on page '{link}': {final_url}")
                                else:
                                    print(f"Duplicate connection error occurred for link on page '{link}': {final_url}")
                        else:
                            print(f"Invalid URL: {absolute_link}")

        print(f"Total pages checked: {total_links_checked}")
        print(f"Total broken links found: {len(broken_links_report)}")
        return broken_links_report
    except openpyxl.utils.exceptions.InvalidFileException:
        print(f"Error: Unable to open the file '{excel_file}'. Please check if it's a valid Excel file.")
        return []
    except Exception as e:
        print(f"Error: An unexpected error occurred while processing the file '{excel_file}': {e}")
        return []

if __name__ == "__main__":
    excel_file_path = "example.xlsx"
    broken_links_report = check_broken_links(excel_file_path)

    if broken_links_report:
        print("Broken Links Report:")
        for link, page_link in broken_links_report:
            print(f"Broken Link on page '{link}': {page_link}")
    else:
        print("No broken links found.")
# Out:
# Opening file: example.xlsx...
# Checking links inside example.xlsx...
# Checking page: https://utep.edu/engineering/student-resources/feedback.html
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://utep.edu/engineering/about-us/administration.html
# Link is working fine: https://utep.edu/engineering/fact-sheet/fact-sheet.html
# Link is working fine: https://utep.edu/engineering/about-us/accreditation.html
# Link is working fine: https://www.utep.edu/engineering/Alumni/index.html
# Link is working fine: https://utep.edu/engineering/academic-programs/degrees-and-programs.html
# Link is working fine: https://utep.edu/engineering/academic-programs/undergraduate-programs/undergraduate.html
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: https://utep.edu/engineering/academic-programs/graduate-programs/graduate-programs.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://utep.edu/engineering/mechanical/index.html
# Link is working fine: https://utep.edu/engineering/civil/index.html
# Link is working fine: https://www.utep.edu/cs/
# Link is working fine: https://utep.edu/engineering/ece/index.html
# Link is working fine: https://utep.edu/engineering/eel/index.html
# Link is working fine: https://utep.edu/engineering/imse/index.html
# Link is working fine: https://utep.edu/engineering/mmbme/index.html
# Link is working fine: https://utep.edu/engineering/eec/index.html
# Link is working fine: https://utep.edu/engineering/research/index.html
# Link is working fine: https://utep.edu/engineering/research/awards-and-recognition.html
# Link is working fine: https://utep.edu/engineering/research/research-and-support.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: https://utep.edu/engineering/research/newsfeed.html
# Link is working fine: https://www.utep.edu/engineering/eec/advisors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Link is working fine: https://utep.edu/engineering/eec/honors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://utep.edu/engineering/student-resources/feedback.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/engineering/k12/
# Link is working fine: https://utep.edu/engineering/k12/aspirations/index.html
# Link is working fine: https://utep.edu/engineering/k12/discover-e/index.html
# Link is working fine: https://utep.edu/engineering/k12/e-week/index.html
# Link is working fine: https://utep.edu/engineering/k12/excites/index.html
# Link is working fine: https://utep.edu/engineering/k12/robotics/index.html
# Link is working fine: https://utep.edu/engineering/eweek/index.html
# Link is working fine: https://www.utep.edu/engineering/homecoming/
# Link is working fine: https://utep.edu/engineering/graduateceremony/index.html
# Link is working fine: https://utep.edu/engineering/orderoftheengineer/index.html
# Link is working fine: https://utep.edu/engineering/tcm/index.html
# Link is working fine: https://givingto.utep.edu/coeng
# Link is working fine: https://my.utep.edu/My
# Link is working fine: https://utep.edu/resources/students.html
# Link is working fine: https://utep.edu/resources/faculty-and-staff.html
# Link is working fine: https://alumni.utep.edu/
# Link is working fine: https://utep.edu/resources/parents.html
# Link is working fine: https://www.utep.edu/library/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/vpba/parking-and-transportation/%20
# Link is working fine: https://www.utep.edu/newsfeed/
# Link is working fine: https://minetracker.utep.edu/events
# Link is working fine: https://www.utep.edu/student-affairs/
# Link is working fine: https://www.utep.edu/vpba/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.bkstr.com/texaselpasostore/home
# Link is working fine: https://www.utep.edu/technologysupport/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering%20
# Link is working fine: https://www.utep.edu/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering%20%20%20%20%20
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering/student-resources%20%20%20%20%20
# Link is working fine: https://www.utep.edu/
# Duplicate broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering%20%20%20%20%20
# Duplicate broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering/student-resources%20%20%20%20%20
# Link is working fine: https://utep.questionpro.com/a/TakeSurvey?tt=tPyVABFtWSsECHrPeIW9eQ%3D%3D
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Link is working fine: https://www.utep.edu/student-affairs/dean-of-students-office/resources/grade-grievance.html
# Link is working fine: https://utep.questionpro.com/a/TakeSurvey?tt=eB7GJW%2BsGVQECHrPeIW9eQ%3D%3D
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# Link is working fine: https://www.utep.edu/titleix/
# Link is working fine: https://www.utep.edu/engineering/eec/advisors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Link is working fine: https://utep.edu/engineering/eec/honors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://utep.edu/engineering/student-resources/feedback.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/student-affairs/admissions/
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: https://www.utep.edu/graduate/apply-now/apply-now.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://utep.edu/engineering/business-center/business-center.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://minetracker.utep.edu/events
# Link is working fine: https://www.utep.edu/engineering/student-resources/feedback.html?helpfullinks
# Link is working fine: https://www.facebook.com/utepengineering/
# Link is working fine: https://twitter.com/utep%20
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.youtube.com/user/UTEPengineering%20
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.instagram.com/engineeringutep/%20
# Link is working fine: https://www.utep.edu/utepcares/cares-act-compliance/
# Link is working fine: https://www.utep.edu/police/annual-security-and-fire-safety-report/
# Link is working fine: https://www.utep.edu/emergency/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.utep.edu/student-affairs/resources/Mental-Health-Resources-for-UTEP-Students.html
# Link is working fine: https://www.utep.edu/resources/public-course-information.html
# Invalid URL: http://sao.fraud.state.tx.us/
# Link is working fine: https://www.utep.edu/required-links/
# Link is working fine: https://www.utep.edu/vpba/state-reports/
# Link is working fine: https://veterans.portal.texas.gov/
# Link is working fine: https://www.utep.edu/titleix/Filing-a-Complaint.html
# Link is working fine: https://www.utep.edu/hoop/section-6/ch-3.html
# Link is working fine: https://www.utsystem.edu/
# Link is working fine: https://www.utep.edu/eoaa/policies/accessibility-policy.html
# Link is working fine: https://www.utep.edu/information-resources/iso/policies/web-privacy-policies.html
# Link is working fine: https://adminapps.utep.edu/feedback
# Total pages checked: 1
# Total broken links found: 7
# Broken Links Report:
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/vpba/parking-and-transportation/%20
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering%20
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering%20%20%20%20%20
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://utep.edu/engineering/student-resources%20%20%20%20%20
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.youtube.com/user/UTEPengineering%20
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.instagram.com/engineeringutep/%20

# %%
import openpyxl
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse, unquote

def get_final_url(url):
    try:
        response = requests.get(url, allow_redirects=True)
        return response.url
    except requests.exceptions.RequestException:
        return None

def clean_link(link):
    if link and not link.startswith("mailto:") and not link.startswith("#"):
        link = unquote(link).strip()
        if link.endswith("%20"):
            link = link[:-3]  # Remove trailing %20 if it exists
        return link
    return None

def get_links_from_page(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            links = [clean_link(link.get('href')) for link in soup.find_all('a', href=True)]
            return [link for link in links if link is not None]  # Filter out None values
        else:
            return []
    except requests.exceptions.RequestException:
        return []

def check_broken_links(excel_file):
    try:
        print(f"Opening file: {excel_file}...")
        wb = openpyxl.load_workbook(excel_file)
        sheet = wb.active
        column_with_links = 'A'
        
        broken_links_report = []
        total_links_checked = 0
        
        print(f"Checking links inside {excel_file}...")
        for cell in sheet[column_with_links]:
            if cell.value:
                link = cell.value
                print(f"Checking page: {link}")
                total_links_checked += 1
                page_links = get_links_from_page(link)
                print(f"Links extracted from page: {page_links}")
                for page_link in page_links:
                    if is_valid_link(page_link):
                        absolute_link = urljoin(link, page_link)
                        final_url = get_final_url(absolute_link)
                        if final_url is not None:
                            try:
                                response = requests.get(final_url)
                                if response.status_code != 200:
                                    if (link, final_url) not in broken_links_report:
                                        broken_links_report.append((link, final_url))
                                        print(f"Broken link found on page '{link}': {final_url}")
                                    else:
                                        print(f"Duplicate broken link found on page '{link}': {final_url}")
                                else:
                                    print(f"Link is working fine: {final_url}")
                            except requests.exceptions.RequestException:
                                if (link, final_url) not in broken_links_report:
                                    broken_links_report.append((link, final_url))
                                    print(f"Connection error occurred for link on page '{link}': {final_url}")
                                else:
                                    print(f"Duplicate connection error occurred for link on page '{link}': {final_url}")
                        else:
                            print(f"Invalid URL: {absolute_link}")

        print(f"Total pages checked: {total_links_checked}")
        print(f"Total broken links found: {len(broken_links_report)}")
        return broken_links_report
    except openpyxl.utils.exceptions.InvalidFileException:
        print(f"Error: Unable to open the file '{excel_file}'. Please check if it's a valid Excel file.")
        return []
    except Exception as e:
        print(f"Error: An unexpected error occurred while processing the file '{excel_file}': {e}")
        return []

if __name__ == "__main__":
    excel_file_path = "example.xlsx"
    broken_links_report = check_broken_links(excel_file_path)

    if broken_links_report:
        print("Broken Links Report:")
        for link, page_link in broken_links_report:
            print(f"Broken Link on page '{link}': {page_link}")
    else:
        print("No broken links found.")
# Out:
# Opening file: example.xlsx...
# Checking links inside example.xlsx...
# Checking page: https://utep.edu/engineering/student-resources/feedback.html
# Links extracted from page: ['https://www.utep.edu/', '../about-us/administration.html', '../fact-sheet/fact-sheet.html', '../about-us/accreditation.html', 'https://www.utep.edu/engineering/Alumni/index.html', '../academic-programs/degrees-and-programs.html', '../academic-programs/undergraduate-programs/undergraduate.html', 'http://catalog.utep.edu/undergrad/', '../academic-programs/graduate-programs/graduate-programs.html', 'http://catalog.utep.edu/grad/', '../mechanical/index.html', '../civil/index.html', 'https://www.utep.edu/cs/', '../ece/index.html', '../eel/index.html', '../imse/index.html', '../mmbme/index.html', '../eec/index.html', '../research/index.html', '../research/awards-and-recognition.html', '../research/research-and-support.html', 'Student-Opportunities.html', '../research/newsfeed.html', 'https://www.utep.edu/engineering/eec/advisors/index.html', 'student-resources-studentlife-deans-list.html', '../eec/honors/index.html', 'student-resources-preprofessional-experiences.html', 'feedback.html', 'student-resources-studentlife.html', 'Student-Opportunities.html', 'http://etc.utep.edu', 'http://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html', 'student-resources-women-in-engineering.html', '../e-newsletter/index.html', 'https://www.utep.edu/engineering/miningyourpathtosuccess/index.html', 'https://www.utep.edu/engineering/k12/', '../k12/aspirations/index.html', '../k12/discover-e/index.html', '../k12/e-week/index.html', '../k12/excites/index.html', '../k12/robotics/index.html', '../eweek/index.html', 'https://www.utep.edu/engineering/homecoming/', '../graduateceremony/index.html', '../orderoftheengineer/index.html', '../tcm/index.html', 'https://givingto.utep.edu/coeng', 'http://my.utep.edu', '/resources/students.html', '/resources/faculty-and-staff.html', 'http://alumni.utep.edu/', '/resources/parents.html', 'https://www.utep.edu/library/', 'https://www.utep.edu/vpba/parking-and-transportation/', 'https://www.utep.edu/newsfeed/', 'https://events.utep.edu/', 'https://www.utep.edu/student-affairs/', 'https://www.utep.edu/vpba/', 'https://www.utep.edu/human-resources/services/employment/index.html', 'http://www.utepbookstore.com', 'https://www.utep.edu/technologysupport/', '/engineering', 'https://www.utep.edu', '/engineering', '/engineering/student-resources', 'https://www.utep.edu', '/engineering', '/engineering/student-resources', 'https://utep.questionpro.com/t/AO6lJZvkI0', 'http://catalog.utep.edu/policies-regulations/student-life/', 'https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html', 'https://www.utep.edu/student-affairs/dean-of-students-office/resources/grade-grievance.html', 'https://utep.questionpro.com/t/AO6lJZvkJW', 'http://catalog.utep.edu/policies-regulations/student-life/', 'https://www.utep.edu/titleix/', 'https://www.utep.edu/engineering/eec/advisors/index.html', 'student-resources-studentlife-deans-list.html', '../eec/honors/index.html', 'student-resources-preprofessional-experiences.html', 'feedback.html', 'student-resources-studentlife.html', 'Student-Opportunities.html', 'http://etc.utep.edu', 'https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html', 'student-resources-women-in-engineering.html', '../e-newsletter/index.html', 'https://www.utep.edu/engineering/miningyourpathtosuccess/index.html', 'https://www.utep.edu/student-affairs/admissions/', 'http://catalog.utep.edu/undergrad/', 'http://www.utep.edu/graduate/apply-now/apply-now.html', 'http://catalog.utep.edu/grad/', '../business-center/business-center.html', 'http://etc.utep.edu', 'https://events.utep.edu/calendar/upcoming?event_types[]=126310', 'https://www.utep.edu/engineering/student-resources/feedback.html?helpfullinks', 'https://www.facebook.com/utepengineering', 'https://twitter.com/utep', 'https://www.youtube.com/user/UTEPengineering', 'https://www.instagram.com/engineeringutep/', 'https://www.utep.edu/utepcares/cares-act ...
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://utep.edu/engineering/about-us/administration.html
# Link is working fine: https://utep.edu/engineering/fact-sheet/fact-sheet.html
# Link is working fine: https://utep.edu/engineering/about-us/accreditation.html
# Link is working fine: https://www.utep.edu/engineering/Alumni/index.html
# Link is working fine: https://utep.edu/engineering/academic-programs/degrees-and-programs.html
# Link is working fine: https://utep.edu/engineering/academic-programs/undergraduate-programs/undergraduate.html
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: https://utep.edu/engineering/academic-programs/graduate-programs/graduate-programs.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://utep.edu/engineering/mechanical/index.html
# Link is working fine: https://utep.edu/engineering/civil/index.html
# Link is working fine: https://www.utep.edu/cs/
# Link is working fine: https://utep.edu/engineering/ece/index.html
# Link is working fine: https://utep.edu/engineering/eel/index.html
# Link is working fine: https://utep.edu/engineering/imse/index.html
# Link is working fine: https://utep.edu/engineering/mmbme/index.html
# Link is working fine: https://utep.edu/engineering/eec/index.html
# Link is working fine: https://utep.edu/engineering/research/index.html
# Link is working fine: https://utep.edu/engineering/research/awards-and-recognition.html
# Link is working fine: https://utep.edu/engineering/research/research-and-support.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: https://utep.edu/engineering/research/newsfeed.html
# Link is working fine: https://www.utep.edu/engineering/eec/advisors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Link is working fine: https://utep.edu/engineering/eec/honors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://utep.edu/engineering/student-resources/feedback.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/engineering/k12/
# Link is working fine: https://utep.edu/engineering/k12/aspirations/index.html
# Link is working fine: https://utep.edu/engineering/k12/discover-e/index.html
# Link is working fine: https://utep.edu/engineering/k12/e-week/index.html
# Link is working fine: https://utep.edu/engineering/k12/excites/index.html
# Link is working fine: https://utep.edu/engineering/k12/robotics/index.html
# Link is working fine: https://utep.edu/engineering/eweek/index.html
# Link is working fine: https://www.utep.edu/engineering/homecoming/
# Link is working fine: https://utep.edu/engineering/graduateceremony/index.html
# Link is working fine: https://utep.edu/engineering/orderoftheengineer/index.html
# Link is working fine: https://utep.edu/engineering/tcm/index.html
# Link is working fine: https://givingto.utep.edu/coeng
# Link is working fine: https://my.utep.edu/My
# Link is working fine: https://utep.edu/resources/students.html
# Link is working fine: https://utep.edu/resources/faculty-and-staff.html
# Link is working fine: https://alumni.utep.edu/
# Link is working fine: https://utep.edu/resources/parents.html
# Link is working fine: https://www.utep.edu/library/
# Link is working fine: https://www.utep.edu/parking-and-transportation/
# Link is working fine: https://www.utep.edu/newsfeed/
# Link is working fine: https://minetracker.utep.edu/events
# Link is working fine: https://www.utep.edu/student-affairs/
# Link is working fine: https://www.utep.edu/vpba/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.bkstr.com/texaselpasostore/home
# Link is working fine: https://www.utep.edu/technologysupport/
# Link is working fine: https://www.utep.edu/engineering/
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/engineering/student-resources/
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/
# Duplicate broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/engineering/student-resources/
# Link is working fine: https://utep.questionpro.com/a/TakeSurvey?tt=tPyVABFtWSsECHrPeIW9eQ%3D%3D
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Link is working fine: https://www.utep.edu/student-affairs/dean-of-students-office/resources/grade-grievance.html
# Link is working fine: https://utep.questionpro.com/a/TakeSurvey?tt=eB7GJW%2BsGVQECHrPeIW9eQ%3D%3D
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# Link is working fine: https://www.utep.edu/titleix/
# Link is working fine: https://www.utep.edu/engineering/eec/advisors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Link is working fine: https://utep.edu/engineering/eec/honors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://utep.edu/engineering/student-resources/feedback.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/student-affairs/admissions/
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: https://www.utep.edu/graduate/apply-now/apply-now.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://utep.edu/engineering/business-center/business-center.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://minetracker.utep.edu/events
# Link is working fine: https://www.utep.edu/engineering/student-resources/feedback.html?helpfullinks
# Link is working fine: https://www.facebook.com/utepengineering
# Link is working fine: https://twitter.com/utep
# Link is working fine: https://www.youtube.com/user/UTEPengineering
# Link is working fine: https://www.instagram.com/engineeringutep/
# Link is working fine: https://www.utep.edu/utepcares/cares-act-compliance/
# Link is working fine: https://www.utep.edu/police/annual-security-and-fire-safety-report/
# Link is working fine: https://www.utep.edu/emergency/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.utep.edu/student-affairs/resources/Mental-Health-Resources-for-UTEP-Students.html
# Link is working fine: https://www.utep.edu/resources/public-course-information.html
# Invalid URL: http://sao.fraud.state.tx.us/
# Link is working fine: https://www.utep.edu/required-links/
# Link is working fine: https://www.utep.edu/vpba/state-reports/
# Link is working fine: https://veterans.portal.texas.gov/
# Link is working fine: https://www.utep.edu/titleix/Filing-a-Complaint.html
# Link is working fine: https://www.utep.edu/hoop/section-6/ch-3.html
# Link is working fine: https://www.utsystem.edu/
# Link is working fine: https://www.utep.edu/eoaa/policies/accessibility-policy.html
# Link is working fine: https://www.utep.edu/information-resources/iso/policies/web-privacy-policies.html
# Link is working fine: https://adminapps.utep.edu/feedback
# Total pages checked: 1
# Total broken links found: 2
# Broken Links Report:
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/engineering/student-resources/
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html

# %%
import openpyxl
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse, unquote
import csv

def get_final_url(url):
    try:
        response = requests.get(url, allow_redirects=True)
        return response.url
    except requests.exceptions.RequestException:
        return None

def clean_link(link):
    if link and not link.startswith("mailto:") and not link.startswith("#"):
        link = unquote(link).strip()
        if link.endswith("%20"):
            link = link[:-3]  # Remove trailing %20 if it exists
        return link
    return None

def get_links_from_page(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            links = [clean_link(link.get('href')) for link in soup.find_all('a', href=True)]
            return [link for link in links if link is not None]  # Filter out None values
        else:
            return []
    except requests.exceptions.RequestException:
        return []

def check_broken_links(excel_file):
    try:
        print(f"Opening file: {excel_file}...")
        wb = openpyxl.load_workbook(excel_file)
        sheet = wb.active
        column_with_links = 'A'
        
        broken_links_report = []
        invalid_links_report = []
        total_links_checked = 0
        
        print(f"Checking links inside {excel_file}...")
        for cell in sheet[column_with_links]:
            if cell.value:
                link = cell.value
                print(f"Checking page: {link}")
                total_links_checked += 1
                page_links = get_links_from_page(link)
                print(f"Links extracted from page: {page_links}")
                for page_link in page_links:
                    if is_valid_link(page_link):
                        absolute_link = urljoin(link, page_link)
                        final_url = get_final_url(absolute_link)
                        if final_url is not None:
                            try:
                                response = requests.get(final_url)
                                if response.status_code != 200:
                                    if (link, final_url) not in broken_links_report:
                                        broken_links_report.append((link, final_url))
                                        print(f"Broken link found on page '{link}': {final_url}")
                                    else:
                                        print(f"Duplicate broken link found on page '{link}': {final_url}")
                                else:
                                    print(f"Link is working fine: {final_url}")
                            except requests.exceptions.RequestException:
                                if (link, final_url) not in broken_links_report:
                                    broken_links_report.append((link, final_url))
                                    print(f"Connection error occurred for link on page '{link}': {final_url}")
                                else:
                                    print(f"Duplicate connection error occurred for link on page '{link}': {final_url}")
                        else:
                            invalid_links_report.append((link, absolute_link))
                            print(f"Invalid URL: {absolute_link}")

        print(f"Total pages checked: {total_links_checked}")
        print(f"Total broken links found: {len(broken_links_report)}")
        print(f"Total invalid links found: {len(invalid_links_report)}")
        return broken_links_report, invalid_links_report
    except openpyxl.utils.exceptions.InvalidFileException:
        print(f"Error: Unable to open the file '{excel_file}'. Please check if it's a valid Excel file.")
        return [], []
    except Exception as e:
        print(f"Error: An unexpected error occurred while processing the file '{excel_file}': {e}")
        return [], []
    
def save_to_csv(file_path, data, header):
    with open(file_path, 'w', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(header)
        csv_writer.writerows(data)
        
        
if __name__ == "__main__":
    excel_file_path = "example.xlsx"
    broken_links_report, invalid_links_report = check_broken_links(excel_file_path)

    if broken_links_report:
        print("Broken Links Report:")
        for link, page_link in broken_links_report:
            print(f"Broken Link on page '{link}': {page_link}")

        # Save broken links report to CSV
        csv_file_path = "broken_links_report.csv"
        header = ["Page", "Broken Link"]
        save_to_csv(csv_file_path, broken_links_report, header)
        print(f"Broken links report saved to '{csv_file_path}'")
    else:
        print("No broken links found.")

    if invalid_links_report:
        print("Invalid Links Report:")
        for link, page_link in invalid_links_report:
            print(f"Invalid Link on page '{link}': {page_link}")

        # Save invalid links report to CSV
        csv_file_path = "invalid_links_report.csv"
        header = ["Page", "Invalid Link"]
        save_to_csv(csv_file_path, invalid_links_report, header)
        print(f"Invalid links report saved to '{csv_file_path}'")
    else:
        print("No invalid links found.")
# Out:
# Opening file: example.xlsx...
# Checking links inside example.xlsx...
# Checking page: https://utep.edu/engineering/student-resources/feedback.html
# Links extracted from page: ['https://www.utep.edu/', '../about-us/administration.html', '../fact-sheet/fact-sheet.html', '../about-us/accreditation.html', 'https://www.utep.edu/engineering/Alumni/index.html', '../academic-programs/degrees-and-programs.html', '../academic-programs/undergraduate-programs/undergraduate.html', 'http://catalog.utep.edu/undergrad/', '../academic-programs/graduate-programs/graduate-programs.html', 'http://catalog.utep.edu/grad/', '../mechanical/index.html', '../civil/index.html', 'https://www.utep.edu/cs/', '../ece/index.html', '../eel/index.html', '../imse/index.html', '../mmbme/index.html', '../eec/index.html', '../research/index.html', '../research/awards-and-recognition.html', '../research/research-and-support.html', 'Student-Opportunities.html', '../research/newsfeed.html', 'https://www.utep.edu/engineering/eec/advisors/index.html', 'student-resources-studentlife-deans-list.html', '../eec/honors/index.html', 'student-resources-preprofessional-experiences.html', 'feedback.html', 'student-resources-studentlife.html', 'Student-Opportunities.html', 'http://etc.utep.edu', 'http://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html', 'student-resources-women-in-engineering.html', '../e-newsletter/index.html', 'https://www.utep.edu/engineering/miningyourpathtosuccess/index.html', 'https://www.utep.edu/engineering/k12/', '../k12/aspirations/index.html', '../k12/discover-e/index.html', '../k12/e-week/index.html', '../k12/excites/index.html', '../k12/robotics/index.html', '../eweek/index.html', 'https://www.utep.edu/engineering/homecoming/', '../graduateceremony/index.html', '../orderoftheengineer/index.html', '../tcm/index.html', 'https://givingto.utep.edu/coeng', 'http://my.utep.edu', '/resources/students.html', '/resources/faculty-and-staff.html', 'http://alumni.utep.edu/', '/resources/parents.html', 'https://www.utep.edu/library/', 'https://www.utep.edu/vpba/parking-and-transportation/', 'https://www.utep.edu/newsfeed/', 'https://events.utep.edu/', 'https://www.utep.edu/student-affairs/', 'https://www.utep.edu/vpba/', 'https://www.utep.edu/human-resources/services/employment/index.html', 'http://www.utepbookstore.com', 'https://www.utep.edu/technologysupport/', '/engineering', 'https://www.utep.edu', '/engineering', '/engineering/student-resources', 'https://www.utep.edu', '/engineering', '/engineering/student-resources', 'https://utep.questionpro.com/t/AO6lJZvkI0', 'http://catalog.utep.edu/policies-regulations/student-life/', 'https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html', 'https://www.utep.edu/student-affairs/dean-of-students-office/resources/grade-grievance.html', 'https://utep.questionpro.com/t/AO6lJZvkJW', 'http://catalog.utep.edu/policies-regulations/student-life/', 'https://www.utep.edu/titleix/', 'https://www.utep.edu/engineering/eec/advisors/index.html', 'student-resources-studentlife-deans-list.html', '../eec/honors/index.html', 'student-resources-preprofessional-experiences.html', 'feedback.html', 'student-resources-studentlife.html', 'Student-Opportunities.html', 'http://etc.utep.edu', 'https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html', 'student-resources-women-in-engineering.html', '../e-newsletter/index.html', 'https://www.utep.edu/engineering/miningyourpathtosuccess/index.html', 'https://www.utep.edu/student-affairs/admissions/', 'http://catalog.utep.edu/undergrad/', 'http://www.utep.edu/graduate/apply-now/apply-now.html', 'http://catalog.utep.edu/grad/', '../business-center/business-center.html', 'http://etc.utep.edu', 'https://events.utep.edu/calendar/upcoming?event_types[]=126310', 'https://www.utep.edu/engineering/student-resources/feedback.html?helpfullinks', 'https://www.facebook.com/utepengineering', 'https://twitter.com/utep', 'https://www.youtube.com/user/UTEPengineering', 'https://www.instagram.com/engineeringutep/', 'https://www.utep.edu/utepcares/cares-act ...
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://utep.edu/engineering/about-us/administration.html
# Link is working fine: https://utep.edu/engineering/fact-sheet/fact-sheet.html
# Link is working fine: https://utep.edu/engineering/about-us/accreditation.html
# Link is working fine: https://www.utep.edu/engineering/Alumni/index.html
# Link is working fine: https://utep.edu/engineering/academic-programs/degrees-and-programs.html
# Link is working fine: https://utep.edu/engineering/academic-programs/undergraduate-programs/undergraduate.html
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: https://utep.edu/engineering/academic-programs/graduate-programs/graduate-programs.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://utep.edu/engineering/mechanical/index.html
# Link is working fine: https://utep.edu/engineering/civil/index.html
# Link is working fine: https://www.utep.edu/cs/
# Link is working fine: https://utep.edu/engineering/ece/index.html
# Link is working fine: https://utep.edu/engineering/eel/index.html
# Link is working fine: https://utep.edu/engineering/imse/index.html
# Link is working fine: https://utep.edu/engineering/mmbme/index.html
# Link is working fine: https://utep.edu/engineering/eec/index.html
# Link is working fine: https://utep.edu/engineering/research/index.html
# Link is working fine: https://utep.edu/engineering/research/awards-and-recognition.html
# Link is working fine: https://utep.edu/engineering/research/research-and-support.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: https://utep.edu/engineering/research/newsfeed.html
# Link is working fine: https://www.utep.edu/engineering/eec/advisors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Link is working fine: https://utep.edu/engineering/eec/honors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://utep.edu/engineering/student-resources/feedback.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/engineering/k12/
# Link is working fine: https://utep.edu/engineering/k12/aspirations/index.html
# Link is working fine: https://utep.edu/engineering/k12/discover-e/index.html
# Link is working fine: https://utep.edu/engineering/k12/e-week/index.html
# Link is working fine: https://utep.edu/engineering/k12/excites/index.html
# Link is working fine: https://utep.edu/engineering/k12/robotics/index.html
# Link is working fine: https://utep.edu/engineering/eweek/index.html
# Link is working fine: https://www.utep.edu/engineering/homecoming/
# Link is working fine: https://utep.edu/engineering/graduateceremony/index.html
# Link is working fine: https://utep.edu/engineering/orderoftheengineer/index.html
# Link is working fine: https://utep.edu/engineering/tcm/index.html
# Link is working fine: https://givingto.utep.edu/coeng
# Link is working fine: https://my.utep.edu/My
# Link is working fine: https://utep.edu/resources/students.html
# Link is working fine: https://utep.edu/resources/faculty-and-staff.html
# Link is working fine: https://alumni.utep.edu/
# Link is working fine: https://utep.edu/resources/parents.html
# Link is working fine: https://www.utep.edu/library/
# Link is working fine: https://www.utep.edu/parking-and-transportation/
# Link is working fine: https://www.utep.edu/newsfeed/
# Link is working fine: https://minetracker.utep.edu/events
# Link is working fine: https://www.utep.edu/student-affairs/
# Link is working fine: https://www.utep.edu/vpba/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.bkstr.com/texaselpasostore/home
# Link is working fine: https://www.utep.edu/technologysupport/
# Link is working fine: https://www.utep.edu/engineering/
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/engineering/student-resources/
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/
# Duplicate broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/engineering/student-resources/
# Link is working fine: https://utep.questionpro.com/a/TakeSurvey?tt=tPyVABFtWSsECHrPeIW9eQ%3D%3D
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Link is working fine: https://www.utep.edu/student-affairs/dean-of-students-office/resources/grade-grievance.html
# Link is working fine: https://utep.questionpro.com/a/TakeSurvey?tt=eB7GJW%2BsGVQECHrPeIW9eQ%3D%3D
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# Link is working fine: https://www.utep.edu/titleix/
# Link is working fine: https://www.utep.edu/engineering/eec/advisors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Link is working fine: https://utep.edu/engineering/eec/honors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://utep.edu/engineering/student-resources/feedback.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/student-affairs/admissions/
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: https://www.utep.edu/graduate/apply-now/apply-now.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://utep.edu/engineering/business-center/business-center.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://minetracker.utep.edu/events
# Link is working fine: https://www.utep.edu/engineering/student-resources/feedback.html?helpfullinks
# Link is working fine: https://www.facebook.com/utepengineering
# Link is working fine: https://twitter.com/utep
# Link is working fine: https://www.youtube.com/user/UTEPengineering
# Link is working fine: https://www.instagram.com/engineeringutep/
# Link is working fine: https://www.utep.edu/utepcares/cares-act-compliance/
# Link is working fine: https://www.utep.edu/police/annual-security-and-fire-safety-report/
# Link is working fine: https://www.utep.edu/emergency/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.utep.edu/student-affairs/resources/Mental-Health-Resources-for-UTEP-Students.html
# Link is working fine: https://www.utep.edu/resources/public-course-information.html
# Invalid URL: http://sao.fraud.state.tx.us/
# Link is working fine: https://www.utep.edu/required-links/
# Link is working fine: https://www.utep.edu/vpba/state-reports/
# Link is working fine: https://veterans.portal.texas.gov/
# Link is working fine: https://www.utep.edu/titleix/Filing-a-Complaint.html
# Link is working fine: https://www.utep.edu/hoop/section-6/ch-3.html
# Link is working fine: https://www.utsystem.edu/
# Link is working fine: https://www.utep.edu/eoaa/policies/accessibility-policy.html
# Link is working fine: https://www.utep.edu/information-resources/iso/policies/web-privacy-policies.html
# Link is working fine: https://adminapps.utep.edu/feedback
# Total pages checked: 1
# Total broken links found: 2
# Total invalid links found: 1
# Broken Links Report:
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/engineering/student-resources/
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Broken links report saved to 'broken_links_report.csv'
# Invalid Links Report:
# Invalid Link on page 'https://utep.edu/engineering/student-resources/feedback.html': http://sao.fraud.state.tx.us/
# Invalid links report saved to 'invalid_links_report.csv'

# %%
##WORKIIIIIIIIIIING

# %%
import openpyxl
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse, unquote
import csv
from concurrent.futures import ThreadPoolExecutor

def get_final_url(url):
    try:
        response = requests.get(url, allow_redirects=True)
        return response.url
    except requests.exceptions.RequestException:
        return None

def clean_link(link):
    if link and not link.startswith("mailto:") and not link.startswith("#"):
        link = unquote(link).strip()
        if link.endswith("%20"):
            link = link[:-3]  # Remove trailing %20 if it exists
        return link
    return None

def get_links_from_page(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            links = [clean_link(link.get('href')) for link in soup.find_all('a', href=True)]
            return [link for link in links if link is not None]  # Filter out None values
        else:
            return []
    except requests.exceptions.RequestException:
        return []

def identify_section(page_url, page_source):
    soup = BeautifulSoup(page_source, 'html.parser')
    # Assuming your website has specific classes or IDs for these sections, you can modify these accordingly.
    main_nav_links = [link for link in soup.select('.main-navigation a[href]')]
    main_content_links = [link for link in soup.select('.main-content a[href]')]
    footer_links = [link for link in soup.select('.footer a[href]')]

    if page_url in main_nav_links:
        return "Main Navigation"
    elif page_url in main_content_links:
        return "Main Content"
    elif page_url in footer_links:
        return "Footer"
    else:
        return "Unknown"
    
def check_single_link(link_data, base_url):
    link, _ = link_data  # Remove the page_source from link_data

    broken_links_report = []
    invalid_links_report = []

    if not is_valid_link(link):
        invalid_links_report.append((None, link))
        return broken_links_report, invalid_links_report, []

    try:
        absolute_link = urljoin(base_url, link)
        response = requests.get(absolute_link)  # Fetch the page source using requests
        if response.status_code == 200:
            final_url = response.url  # Use the final URL from the response
            try:
                if response.status_code != 200:
                    section = identify_section(base_url, response.text)  # Pass page source here
                    broken_links_report.append((base_url, final_url, section))
                    print(f"Broken link found on page '{base_url}' in '{section}' section: {final_url}")
                else:
                    print(f"Link is working fine: {final_url}")
            except requests.exceptions.RequestException:
                section = identify_section(base_url, response.text)  # Pass page source here
                broken_links_report.append((base_url, final_url, section))
                print(f"Connection error occurred for link on page '{base_url}' in '{section}' section: {final_url}")
        else:
            invalid_links_report.append((base_url, absolute_link))
            print(f"Invalid URL: {absolute_link}")

    except ValueError:
        invalid_links_report.append((base_url, link))
        print(f"Invalid URL: {link}")
    except requests.exceptions.RequestException as e:
        # Handle the connection error gracefully
        broken_links_report.append((base_url, absolute_link, "Connection Error"))
        print(f"Connection error occurred for link on page '{base_url}': {absolute_link}")
        print(f"Error message: {e}")

    return broken_links_report, invalid_links_report, []



def check_broken_links(excel_file):
    try:
        print(f"Opening file: {excel_file}...")
        wb = openpyxl.load_workbook(excel_file)
        sheet = wb.active
        column_with_links = 'A'
        
        broken_links_report = []
        invalid_links_report = []
        total_links_checked = 0
        
        print(f"Checking links inside {excel_file}...")
        for cell in sheet[column_with_links]:
            if cell.value:
                link = cell.value
                print(f"Checking page: {link}")
                total_links_checked += 1
                page_links = get_links_from_page(link)
                for page_link in page_links:
                    link_data = (page_link, None)  # Second element None as we don't have the page source yet
                    base_url = link
                    broken_links, invalid_links, page_sources = check_single_link(link_data, base_url)
                    broken_links_report.extend(broken_links)
                    invalid_links_report.extend(invalid_links)

                    # Append the page URL and source for each broken link to get the section information later
                    for i, (broken_link, _) in enumerate(broken_links):
                        page_sources[i] = (link, page_sources[i])

        print("Checking links in parallel...")
        link_chunks = [broken_links_report[i:i + 10] for i in range(0, len(broken_links_report), 10)]
        all_broken_links_report = []
        all_invalid_links_report = []

        with ThreadPoolExecutor() as executor:
            for chunk in link_chunks:
                results = list(executor.map(check_single_link, chunk, [base_url] * len(chunk)))
                for result in results:
                    broken_links_report, invalid_links_report, page_sources = result
                    all_broken_links_report.extend(broken_links_report)
                    all_invalid_links_report.extend(invalid_links_report)

                    # Append the page URL and source for each broken link to get the section information later
                    for broken_link, (_, page_url, page_source) in zip(all_broken_links_report, page_sources):
                        section = identify_section(page_url, page_source)
                        broken_link.append(section)


        print(f"Total pages checked: {total_links_checked}")
        print(f"Total broken links found: {len(all_broken_links_report)}")
        print(f"Total invalid links found: {len(all_invalid_links_report)}")
        return all_broken_links_report, all_invalid_links_report
    except openpyxl.utils.exceptions.InvalidFileException:
        print(f"Error: Unable to open the file '{excel_file}'. Please check if it's a valid Excel file.")
        return [], []
    except Exception as e:
        print(f"Error: An unexpected error occurred while processing the file '{excel_file}': {e}")
        return [], []
    
def save_to_csv(file_path, data, header):
    with open(file_path, 'w', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(header)
        csv_writer.writerows(data)
        
        
if __name__ == "__main__":
    excel_file_path = "example.xlsx"
    broken_links_report, invalid_links_report = check_broken_links(excel_file_path)

    if broken_links_report:
        print("Broken Links Report:")
        for link, page_link, section in broken_links_report:
            print(f"Broken Link on page '{link}' in '{section}' section: {page_link}")

        # Save broken links report to CSV
        csv_file_path = "broken_links_report.csv"
        header = ["Page", "Broken Link", "Section"]
        save_to_csv(csv_file_path, broken_links_report, header)
        print(f"Broken links report saved to '{csv_file_path}'")
    else:
        print("No broken links found.")

    if invalid_links_report:
        print("Invalid Links Report:")
        for link, page_link in invalid_links_report:
            print(f"Invalid Link on page '{link}': {page_link}")

        # Save invalid links report to CSV
        csv_file_path = "invalid_links_report.csv"
        header = ["Page", "Invalid Link"]
        save_to_csv(csv_file_path, invalid_links_report, header)
        print(f"Invalid links report saved to '{csv_file_path}'")
    else:
        print("No invalid links found.")
# Out:
# Opening file: example.xlsx...
# Checking links inside example.xlsx...
# Checking page: https://utep.edu/engineering/student-resources/feedback.html
# Links extracted from page: ['https://www.utep.edu/', '../about-us/administration.html', '../fact-sheet/fact-sheet.html', '../about-us/accreditation.html', 'https://www.utep.edu/engineering/Alumni/index.html', '../academic-programs/degrees-and-programs.html', '../academic-programs/undergraduate-programs/undergraduate.html', 'http://catalog.utep.edu/undergrad/', '../academic-programs/graduate-programs/graduate-programs.html', 'http://catalog.utep.edu/grad/', '../mechanical/index.html', '../civil/index.html', 'https://www.utep.edu/cs/', '../ece/index.html', '../eel/index.html', '../imse/index.html', '../mmbme/index.html', '../eec/index.html', '../research/index.html', '../research/awards-and-recognition.html', '../research/research-and-support.html', 'Student-Opportunities.html', '../research/newsfeed.html', 'https://www.utep.edu/engineering/eec/advisors/index.html', 'student-resources-studentlife-deans-list.html', '../eec/honors/index.html', 'student-resources-preprofessional-experiences.html', 'feedback.html', 'student-resources-studentlife.html', 'Student-Opportunities.html', 'http://etc.utep.edu', 'http://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html', 'student-resources-women-in-engineering.html', '../e-newsletter/index.html', 'https://www.utep.edu/engineering/miningyourpathtosuccess/index.html', 'https://www.utep.edu/engineering/k12/', '../k12/aspirations/index.html', '../k12/discover-e/index.html', '../k12/e-week/index.html', '../k12/excites/index.html', '../k12/robotics/index.html', '../eweek/index.html', 'https://www.utep.edu/engineering/homecoming/', '../graduateceremony/index.html', '../orderoftheengineer/index.html', '../tcm/index.html', 'https://givingto.utep.edu/coeng', 'http://my.utep.edu', '/resources/students.html', '/resources/faculty-and-staff.html', 'http://alumni.utep.edu/', '/resources/parents.html', 'https://www.utep.edu/library/', 'https://www.utep.edu/vpba/parking-and-transportation/', 'https://www.utep.edu/newsfeed/', 'https://events.utep.edu/', 'https://www.utep.edu/student-affairs/', 'https://www.utep.edu/vpba/', 'https://www.utep.edu/human-resources/services/employment/index.html', 'http://www.utepbookstore.com', 'https://www.utep.edu/technologysupport/', '/engineering', 'https://www.utep.edu', '/engineering', '/engineering/student-resources', 'https://www.utep.edu', '/engineering', '/engineering/student-resources', 'https://utep.questionpro.com/t/AO6lJZvkI0', 'http://catalog.utep.edu/policies-regulations/student-life/', 'https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html', 'https://www.utep.edu/student-affairs/dean-of-students-office/resources/grade-grievance.html', 'https://utep.questionpro.com/t/AO6lJZvkJW', 'http://catalog.utep.edu/policies-regulations/student-life/', 'https://www.utep.edu/titleix/', 'https://www.utep.edu/engineering/eec/advisors/index.html', 'student-resources-studentlife-deans-list.html', '../eec/honors/index.html', 'student-resources-preprofessional-experiences.html', 'feedback.html', 'student-resources-studentlife.html', 'Student-Opportunities.html', 'http://etc.utep.edu', 'https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html', 'student-resources-women-in-engineering.html', '../e-newsletter/index.html', 'https://www.utep.edu/engineering/miningyourpathtosuccess/index.html', 'https://www.utep.edu/student-affairs/admissions/', 'http://catalog.utep.edu/undergrad/', 'http://www.utep.edu/graduate/apply-now/apply-now.html', 'http://catalog.utep.edu/grad/', '../business-center/business-center.html', 'http://etc.utep.edu', 'https://events.utep.edu/calendar/upcoming?event_types[]=126310', 'https://www.utep.edu/engineering/student-resources/feedback.html?helpfullinks', 'https://www.facebook.com/utepengineering', 'https://twitter.com/utep', 'https://www.youtube.com/user/UTEPengineering', 'https://www.instagram.com/engineeringutep/', 'https://www.utep.edu/utepcares/cares-act ...
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://utep.edu/engineering/about-us/administration.html
# Link is working fine: https://utep.edu/engineering/fact-sheet/fact-sheet.html
# Link is working fine: https://utep.edu/engineering/about-us/accreditation.html
# Link is working fine: https://www.utep.edu/engineering/Alumni/index.html
# Link is working fine: https://utep.edu/engineering/academic-programs/degrees-and-programs.html
# Link is working fine: https://utep.edu/engineering/academic-programs/undergraduate-programs/undergraduate.html
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: https://utep.edu/engineering/academic-programs/graduate-programs/graduate-programs.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://utep.edu/engineering/mechanical/index.html
# Link is working fine: https://utep.edu/engineering/civil/index.html
# Link is working fine: https://www.utep.edu/cs/
# Link is working fine: https://utep.edu/engineering/ece/index.html
# Link is working fine: https://utep.edu/engineering/eel/index.html
# Link is working fine: https://utep.edu/engineering/imse/index.html
# Link is working fine: https://utep.edu/engineering/mmbme/index.html
# Link is working fine: https://utep.edu/engineering/eec/index.html
# Link is working fine: https://utep.edu/engineering/research/index.html
# Link is working fine: https://utep.edu/engineering/research/awards-and-recognition.html
# Link is working fine: https://utep.edu/engineering/research/research-and-support.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: https://utep.edu/engineering/research/newsfeed.html
# Link is working fine: https://www.utep.edu/engineering/eec/advisors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Link is working fine: https://utep.edu/engineering/eec/honors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://utep.edu/engineering/student-resources/feedback.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/engineering/k12/
# Link is working fine: https://utep.edu/engineering/k12/aspirations/index.html
# Link is working fine: https://utep.edu/engineering/k12/discover-e/index.html
# Link is working fine: https://utep.edu/engineering/k12/e-week/index.html
# Link is working fine: https://utep.edu/engineering/k12/excites/index.html
# Link is working fine: https://utep.edu/engineering/k12/robotics/index.html
# Link is working fine: https://utep.edu/engineering/eweek/index.html
# Link is working fine: https://www.utep.edu/engineering/homecoming/
# Link is working fine: https://utep.edu/engineering/graduateceremony/index.html
# Link is working fine: https://utep.edu/engineering/orderoftheengineer/index.html
# Link is working fine: https://utep.edu/engineering/tcm/index.html
# Link is working fine: https://givingto.utep.edu/coeng
# Link is working fine: https://my.utep.edu/My
# Link is working fine: https://utep.edu/resources/students.html
# Link is working fine: https://utep.edu/resources/faculty-and-staff.html
# Link is working fine: https://alumni.utep.edu/
# Link is working fine: https://utep.edu/resources/parents.html
# Link is working fine: https://www.utep.edu/library/
# Link is working fine: https://www.utep.edu/parking-and-transportation/
# Link is working fine: https://www.utep.edu/newsfeed/
# Link is working fine: https://minetracker.utep.edu/events
# Link is working fine: https://www.utep.edu/student-affairs/
# Link is working fine: https://www.utep.edu/vpba/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.bkstr.com/texaselpasostore/home
# Link is working fine: https://www.utep.edu/technologysupport/
# Link is working fine: https://www.utep.edu/engineering/
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/
# Duplicate broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/engineering/student-resources/
# Link is working fine: https://utep.questionpro.com/a/TakeSurvey?tt=tPyVABFtWSsECHrPeIW9eQ%3D%3D
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html' in 'Unknown' section: https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Link is working fine: https://www.utep.edu/student-affairs/dean-of-students-office/resources/grade-grievance.html
# Link is working fine: https://utep.questionpro.com/a/TakeSurvey?tt=eB7GJW%2BsGVQECHrPeIW9eQ%3D%3D
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# Link is working fine: https://www.utep.edu/titleix/
# Link is working fine: https://www.utep.edu/engineering/eec/advisors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Link is working fine: https://utep.edu/engineering/eec/honors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://utep.edu/engineering/student-resources/feedback.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/student-affairs/admissions/
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: https://www.utep.edu/graduate/apply-now/apply-now.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://utep.edu/engineering/business-center/business-center.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://minetracker.utep.edu/events
# Link is working fine: https://www.utep.edu/engineering/student-resources/feedback.html?helpfullinks
# Link is working fine: https://www.facebook.com/utepengineering
# Link is working fine: https://twitter.com/utep
# Link is working fine: https://www.youtube.com/user/UTEPengineering
# Link is working fine: https://www.instagram.com/engineeringutep/
# Link is working fine: https://www.utep.edu/utepcares/cares-act-compliance/
# Link is working fine: https://www.utep.edu/police/annual-security-and-fire-safety-report/
# Link is working fine: https://www.utep.edu/emergency/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.utep.edu/student-affairs/resources/Mental-Health-Resources-for-UTEP-Students.html
# Link is working fine: https://www.utep.edu/resources/public-course-information.html
# Invalid URL: http://sao.fraud.state.tx.us/
# Link is working fine: https://www.utep.edu/required-links/
# Link is working fine: https://www.utep.edu/vpba/state-reports/
# Link is working fine: https://veterans.portal.texas.gov/
# Link is working fine: https://www.utep.edu/titleix/Filing-a-Complaint.html
# Link is working fine: https://www.utep.edu/hoop/section-6/ch-3.html
# Link is working fine: https://www.utsystem.edu/
# Link is working fine: https://www.utep.edu/eoaa/policies/accessibility-policy.html
# Link is working fine: https://www.utep.edu/information-resources/iso/policies/web-privacy-policies.html
# Link is working fine: https://adminapps.utep.edu/feedback
# Checking page: https://www.utep.edu/engineering/student-resources/student-resources.html
# Links extracted from page: ['https://www.utep.edu/', '../about-us/administration.html', '../fact-sheet/fact-sheet.html', '../about-us/accreditation.html', '../academic-programs/degrees-and-programs.html', '../academic-programs/undergraduate-programs/undergraduate.html', 'http://catalog.utep.edu/undergrad/', '../academic-programs/graduate-programs/graduate-programs.html', 'http://catalog.utep.edu/grad/', '../civil/index.html', 'http://www.cs.utep.edu/', '../ece/index.html', '../eel/index.html', '../imse/index.html', '../mechanical/index.html', '../mmbme/index.html', '../eec/index.html', '../research/research-centers.html', '../research/awards-and-recognition.html', '../research/research-and-support.html', 'Student-Opportunities.html', 'student-resources-advising.html', 'student-resources-studentlife-deans-list.html', 'student-resources-preprofessional-experiences.html', 'student-resources-studentlife.html', 'Student-Opportunities.html', 'http://etc.utep.edu', 'http://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html', 'student-resources-women-in-engineering.html', '../e-newsletter/index.html', 'https://www.utep.edu/engineering/miningyourpathtosuccess/index.html', '../academic-programs/k12-outreach/k12-outreach.html', '../academic-programs/k12-outreach/ambassadors.html', '../academic-programs/k12-outreach/aspiration-in-computing.html', '../academic-programs/k12-outreach/e-week.html', '../academic-programs/k12-outreach/excites.html', '../academic-programs/k12-outreach/more-outreach.html', '../academic-programs/k12-outreach/nexus.html', '../academic-programs/k12-outreach/robotics.html', '../alumni/index.html', '../alumni/membership-levels.html', '../alumni/distinguished-alumni.html', '../alumni/Gold-Nuggets.html', '../alumni/Alumni-Spotlight.html', 'https://givingto.utep.edu/coeng', 'http://my.utep.edu', '/resources/students.html', '/resources/faculty-and-staff.html', 'http://alumni.utep.edu/', '/resources/parents.html', 'https://www.utep.edu/library/', 'https://www.utep.edu/vpba/parking-and-transportation/', 'https://www.utep.edu/newsfeed/', 'https://events.utep.edu/', 'https://www.utep.edu/student-affairs/', 'https://www.utep.edu/vpba/', 'https://www.utep.edu/human-resources/services/employment/index.html', 'http://www.utepbookstore.com', 'https://www.utep.edu/technologysupport/', '/engineering', 'https://www.utep.edu', '/engineering', '/engineering/student-resources', 'https://www.utep.edu', '/engineering', '/engineering/student-resources', '../_Files/docs/student-resources/2016 SHP Cyber Student Volunteer Initiative_Flyer.pdf', 'http://www.ll.mit.edu/', 'http://www.ll.mit.edu/college/summerprogram.html.', 'http://www.colorado.edu/law/academics/degrees/msl-degree-program', 'http://youtu.be/eusBjFrWAIg', 'http://sa.utep.edu/careers/employers-on-campus', 'http://www.pathwaystoscience.org/engineering.aspx', 'http://youtu.be/5gb1LNP0u1E', '../_Files/images/student-resources/ucslogo.png', 'http://www.utsystem.edu/seekut/Terms.htm', '../_Files/docs/student-resources/Career Development.pdf', 'http://mashable.com/2009/07/27/linkedin-personal-brand/#ecmNz.vC3Zqc', 'http://sa.utep.edu/careers/students/sample-documents', '/engineering/student-resources/student-employment', 'http://engineering.utep.edu/plaza/flyers/UnCoRe_flyer.pdf', 'http://engineeringinpractice.utep.edu/howtojointheprogram.html', 'http://science.utep.edu/nsf-prem/', 'http://couri.utep.edu/index.php/opportunities', 'http://engineering.utep.edu/graduate-researchopp.htm', 'http://engineering.utep.edu/plaza/circles/degree.htm', '../_Files/images/student-resources/e_resume.jpg', 'http://etc.utep.edu/index.htm', 'http://studentaffairs.utep.edu/Default.aspx?tabid=73328', 'http://engineering.utep.edu/plaza/tutoring/aces.htm', 'student-resources-advising.html', 'student-resources-studentlife-deans-list.html', 'student-resources-advising-orientation.html', 'student-resources-ug-admissions-faqs.html', 'student-resources-ug-admissions-advisors.html', 's ...
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/about-us/administration.html
# Link is working fine: https://www.utep.edu/engineering/fact-sheet/fact-sheet.html
# Link is working fine: https://www.utep.edu/engineering/about-us/accreditation.html
# Link is working fine: https://www.utep.edu/engineering/academic-programs/degrees-and-programs.html
# Link is working fine: https://www.utep.edu/engineering/academic-programs/undergraduate-programs/undergraduate.html
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: https://www.utep.edu/engineering/academic-programs/graduate-programs/graduate-programs.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://www.utep.edu/engineering/civil/index.html
# Link is working fine: http://www.cs.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/ece/index.html
# Link is working fine: https://www.utep.edu/engineering/eel/index.html
# Link is working fine: https://www.utep.edu/engineering/imse/index.html
# Link is working fine: https://www.utep.edu/engineering/mechanical/index.html
# Link is working fine: https://www.utep.edu/engineering/mmbme/index.html
# Link is working fine: https://www.utep.edu/engineering/eec/index.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/research/research-centers.html
# Link is working fine: https://www.utep.edu/engineering/research/awards-and-recognition.html
# Link is working fine: https://www.utep.edu/engineering/research/research-and-support.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/Student-Opportunities.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/student-resources-advising.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-studentlife.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://www.utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/k12-outreach.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/ambassadors.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/aspiration-in-computing.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/e-week.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/excites.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/more-outreach.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/nexus.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/robotics.html
# Link is working fine: https://www.utep.edu/engineering/alumni/index.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/alumni/membership-levels.html
# Link is working fine: https://www.utep.edu/engineering/alumni/distinguished-alumni.html
# Link is working fine: https://www.utep.edu/engineering/alumni/Gold-Nuggets.html
# Link is working fine: https://www.utep.edu/engineering/alumni/Alumni-Spotlight.html
# Link is working fine: https://givingto.utep.edu/coeng
# Link is working fine: https://my.utep.edu/My
# Link is working fine: https://www.utep.edu/resources/students.html
# Link is working fine: https://www.utep.edu/resources/faculty-and-staff.html
# Link is working fine: https://alumni.utep.edu/
# Link is working fine: https://www.utep.edu/resources/parents.html
# Link is working fine: https://www.utep.edu/library/
# Link is working fine: https://www.utep.edu/parking-and-transportation/
# Link is working fine: https://www.utep.edu/newsfeed/
# Link is working fine: https://minetracker.utep.edu/events
# Link is working fine: https://www.utep.edu/student-affairs/
# Link is working fine: https://www.utep.edu/vpba/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.bkstr.com/texaselpasostore/home
# Link is working fine: https://www.utep.edu/technologysupport/
# Link is working fine: https://www.utep.edu/engineering/
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/
# Duplicate broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html': https://www.utep.edu/engineering/student-resources/
# Link is working fine: https://www.utep.edu/engineering/_Files/docs/student-resources/2016%20SHP%20Cyber%20Student%20Volunteer%20Initiative_Flyer.pdf
# Link is working fine: https://www.ll.mit.edu/
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: http://www.ll.mit.edu/college/summerprogram.html.
# Link is working fine: https://www.colorado.edu/law/academics/degrees/msl-ethics-and-compliance
# Link is working fine: https://www.youtube.com/watch?v=eusBjFrWAIg&feature=youtu.be
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: http://sa.utep.edu/careers/employers-on-campus
# Link is working fine: https://www.pathwaystoscience.org/engineering.aspx
# Link is working fine: https://www.youtube.com/watch?v=5gb1LNP0u1E&feature=youtu.be
# Link is working fine: https://www.utep.edu/engineering/_Files/images/student-resources/ucslogo.png
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utsystem.edu/seekut/Terms.htm
# Link is working fine: https://www.utep.edu/engineering/_Files/docs/student-resources/Career%20Development.pdf
# Link is working fine: https://mashable.com/archive/linkedin-personal-brand#ecmNz.vC3Zqc
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: http://sa.utep.edu/careers/students/sample-documents
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/student-employment
# Link is working fine: http://engineering.utep.edu/plaza/flyers/UnCoRe_flyer.pdf
# Link is working fine: http://engineeringinpractice.utep.edu/howtojointheprogram.html
# Invalid URL: http://science.utep.edu/nsf-prem/
# Link is working fine: https://www.utep.edu/couri/
# Link is working fine: http://engineering.utep.edu/graduate-researchopp.htm
# Link is working fine: http://engineering.utep.edu/plaza/circles/degree.htm
# Link is working fine: https://www.utep.edu/engineering/_Files/images/student-resources/e_resume.jpg
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: http://etc.utep.edu/index.htm
# Link is working fine: https://www.utep.edu/student-affairs/
# Link is working fine: http://engineering.utep.edu/plaza/tutoring/aces.htm
# Duplicate broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html': https://www.utep.edu/engineering/student-resources/student-resources-advising.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/student-resources-advising-orientation.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/student-resources-ug-admissions-faqs.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-ug-admissions-advisors.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-studentlife.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/student-resources-tutoring.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://www.utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/student-affairs/admissions/
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: https://www.utep.edu/graduate/apply-now/apply-now.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://www.utep.edu/engineering/business-center/business-center.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://minetracker.utep.edu/events
# Link is working fine: https://www.facebook.com/utepengineering
# Link is working fine: https://twitter.com/engineeringutep
# Link is working fine: https://www.youtube.com/user/UTEPengineering
# Link is working fine: https://www.instagram.com/engineeringutep/
# Link is working fine: https://www.utep.edu/utepcares/cares-act-compliance/
# Link is working fine: https://www.utep.edu/police/annual-security-and-fire-safety-report/
# Link is working fine: https://www.utep.edu/emergency/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.utep.edu/student-affairs/resources/Mental-Health-Resources-for-UTEP-Students.html
# Link is working fine: https://www.utep.edu/resources/public-course-information.html
# Invalid URL: http://sao.fraud.state.tx.us/
# Link is working fine: https://www.utep.edu/required-links/
# Link is working fine: https://www.utep.edu/vpba/state-reports/
# Link is working fine: https://veterans.portal.texas.gov/
# Link is working fine: https://www.utep.edu/titleix/Filing-a-Complaint.html
# Link is working fine: https://www.utep.edu/hoop/section-6/ch-3.html
# Link is working fine: https://www.utsystem.edu/
# Link is working fine: https://www.utep.edu/eoaa/policies/accessibility-policy.html
# Link is working fine: https://www.utep.edu/information-resources/iso/policies/web-privacy-policies.html
# Link is working fine: https://adminapps.utep.edu/feedback
# Total pages checked: 2
# Total broken links found: 23
# Total invalid links found: 3
# Broken Links Report:
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html' in 'Unknown' section: https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/research/research-centers.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/student-resources-advising.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/k12-outreach.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/ambassadors.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/aspiration-in-computing.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/e-week.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/excites.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/more-outreach.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/nexus.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/robotics.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/alumni/membership-levels.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: http://www.ll.mit.edu/college/summerprogram.html.
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: http://sa.utep.edu/careers/employers-on-campus
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utsystem.edu/seekut/Terms.htm
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: http://sa.utep.edu/careers/students/sample-documents
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/student-employment
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: http://etc.utep.edu/index.htm
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/student-resources-advising-orientation.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/student-resources-ug-admissions-faqs.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/student-resources-tutoring.html
# Broken links report saved to 'broken_links_report.csv'
# Invalid Links Report:
# Invalid Link on page 'https://utep.edu/engineering/student-resources/feedback.html': http://sao.fraud.state.tx.us/
# Invalid Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html': http://science.utep.edu/nsf-prem/
# Invalid Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html': http://sao.fraud.state.tx.us/
# Invalid links report saved to 'invalid_links_report.csv'

# %%
import openpyxl
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, unquote
import csv

def get_final_url(url):
    try:
        response = requests.get(url, allow_redirects=True)
        return response.url
    except requests.exceptions.RequestException:
        return None

def clean_link(link):
    if link and not link.startswith("mailto:") and not link.startswith("#"):
        link = unquote(link).strip()
        if link.endswith("%20"):
            link = link[:-3]  # Remove trailing %20 if it exists
        return link
    return None

def get_links_from_page(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            links = [clean_link(link.get('href')) for link in soup.find_all('a', href=True)]
            return [link for link in links if link is not None]  # Filter out None values
        else:
            return []
    except requests.exceptions.RequestException:
        return []

def identify_section(link, page_link):
    try:
        absolute_page_link = urljoin(link, page_link)
        response = requests.get(link)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            element = soup.find('a', {'href': absolute_page_link})
            if element:
                # Search for the outer elements to determine the section
                nav_element = element.find_parent('nav')
                if nav_element:
                    return "Navigation"
                
                footer_element = element.find_parent('footer')
                if footer_element:
                    return "Footer"
                
                sidr_container_element = element.find_parent('div', id='sidr-container')
                if sidr_container_element:
                    return "Main Content"

            return "Unknown"  # If the element is not found in any of the relevant outer elements
        else:
            return "Unknown"  # If there was an issue fetching the page
    except requests.exceptions.RequestException:
        return "Unknown"  # If there was a connection error or other issues






def check_broken_links(excel_file):
    try:
        print(f"Opening file: {excel_file}...")
        wb = openpyxl.load_workbook(excel_file)
        sheet = wb.active
        column_with_links = 'A'
        
        broken_links_report = []
        invalid_links_report = []
        total_links_checked = 0
        
        #print(f"Checking links inside {excel_file}...")
        for cell in sheet[column_with_links]:
            if cell.value:
                link = cell.value
                print(f"Checking page: {link}")
                total_links_checked += 1
                page_links = get_links_from_page(link)
                print(f"Links extracted from page: {page_links}")
                for page_link in page_links:
                    if is_valid_link(page_link):
                        absolute_link = urljoin(link, page_link)
                        final_url = get_final_url(absolute_link)
                        if final_url is not None:
                            try:
                                response = requests.get(final_url)
                                if response.status_code != 200:
                                    section = identify_section(link, page_link)  # Pass both link and page_link
                                    if (link, final_url, section, page_link) not in broken_links_report:  # Check for duplicates
                                        broken_links_report.append((link, final_url, section, page_link))
                                        print(f"Broken link found on page '{link}' in '{section}' section: {final_url}")
                                    else:
                                        print(f"Duplicate broken link found on page '{link}': {final_url}")
                                else:
                                    print(f"Link is working fine: {final_url}")
                            except requests.exceptions.RequestException:
                                section = identify_section(link, page_link)  # Pass both link and page_link
                                if (link, final_url, section, page_link) not in broken_links_report:  # Check for duplicates
                                    broken_links_report.append((link, final_url, section, page_link))
                                    print(f"Connection error occurred for link on page '{link}' in '{section}' section: {final_url}")
                                else:
                                    print(f"Duplicate connection error occurred for link on page '{link}': {final_url}")
                        else:
                            invalid_links_report.append((link, absolute_link))
                            print(f"Invalid URL: {absolute_link}")



        print(f"Total pages checked: {total_links_checked}")
        print(f"Total broken links found: {len(broken_links_report)}")
        print(f"Total invalid links found: {len(invalid_links_report)}")
        return broken_links_report, invalid_links_report
    except openpyxl.utils.exceptions.InvalidFileException:
        print(f"Error: Unable to open the file '{excel_file}'. Please check if it's a valid Excel file.")
        return [], []
    except Exception as e:
        print(f"Error: An unexpected error occurred while processing the file '{excel_file}': {e}")
        return [], []


def save_to_csv(file_path, data, header):
    with open(file_path, 'w', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(header)
        csv_writer.writerows(data)

if __name__ == "__main__":
    excel_file_path = "example.xlsx"
    broken_links_report, invalid_links_report = check_broken_links(excel_file_path)

    if broken_links_report:
        print("Broken Links Report:")
        for link, page_link, section, relative in broken_links_report:
            print(f"Broken Link on page '{link}' in '{section}' section: {page_link}, relative: {relative}")

        # Save broken links report to CSV
        csv_file_path = "broken_links_report.csv"
        header = ["Page", "Broken Link", "Section"]
        save_to_csv(csv_file_path, broken_links_report, header)
        print(f"Broken links report saved to '{csv_file_path}'")
    else:
        print("No broken links found.")

    if invalid_links_report:
        print("Invalid Links Report:")
        for link, page_link in invalid_links_report:
            print(f"Invalid Link on page '{link}': {page_link}")

        # Save invalid links report to CSV
        csv_file_path = "invalid_links_report.csv"
        header = ["Page", "Invalid Link"]
        save_to_csv(csv_file_path, invalid_links_report, header)
        print(f"Invalid links report saved to '{csv_file_path}'")
    else:
        print("No invalid links found.")
# Out:
# Opening file: example.xlsx...
# Checking page: https://utep.edu/engineering/student-resources/feedback.html
# Links extracted from page: ['https://www.utep.edu/', '../about-us/administration.html', '../fact-sheet/fact-sheet.html', '../about-us/accreditation.html', 'https://www.utep.edu/engineering/Alumni/index.html', '../academic-programs/degrees-and-programs.html', '../academic-programs/undergraduate-programs/undergraduate.html', 'http://catalog.utep.edu/undergrad/', '../academic-programs/graduate-programs/graduate-programs.html', 'http://catalog.utep.edu/grad/', '../mechanical/index.html', '../civil/index.html', 'https://www.utep.edu/cs/', '../ece/index.html', '../eel/index.html', '../imse/index.html', '../mmbme/index.html', '../eec/index.html', '../research/index.html', '../research/awards-and-recognition.html', '../research/research-and-support.html', 'Student-Opportunities.html', '../research/newsfeed.html', 'https://www.utep.edu/engineering/eec/advisors/index.html', 'student-resources-studentlife-deans-list.html', '../eec/honors/index.html', 'student-resources-preprofessional-experiences.html', 'feedback.html', 'student-resources-studentlife.html', 'Student-Opportunities.html', 'http://etc.utep.edu', 'http://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html', 'student-resources-women-in-engineering.html', '../e-newsletter/index.html', 'https://www.utep.edu/engineering/miningyourpathtosuccess/index.html', 'https://www.utep.edu/engineering/k12/', '../k12/aspirations/index.html', '../k12/discover-e/index.html', '../k12/e-week/index.html', '../k12/excites/index.html', '../k12/robotics/index.html', '../eweek/index.html', 'https://www.utep.edu/engineering/homecoming/', '../graduateceremony/index.html', '../orderoftheengineer/index.html', '../tcm/index.html', 'https://givingto.utep.edu/coeng', 'http://my.utep.edu', '/resources/students.html', '/resources/faculty-and-staff.html', 'http://alumni.utep.edu/', '/resources/parents.html', 'https://www.utep.edu/library/', 'https://www.utep.edu/vpba/parking-and-transportation/', 'https://www.utep.edu/newsfeed/', 'https://events.utep.edu/', 'https://www.utep.edu/student-affairs/', 'https://www.utep.edu/vpba/', 'https://www.utep.edu/human-resources/services/employment/index.html', 'http://www.utepbookstore.com', 'https://www.utep.edu/technologysupport/', '/engineering', 'https://www.utep.edu', '/engineering', '/engineering/student-resources', 'https://www.utep.edu', '/engineering', '/engineering/student-resources', 'https://utep.questionpro.com/t/AO6lJZvkI0', 'http://catalog.utep.edu/policies-regulations/student-life/', 'https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html', 'https://www.utep.edu/student-affairs/dean-of-students-office/resources/grade-grievance.html', 'https://utep.questionpro.com/t/AO6lJZvkJW', 'http://catalog.utep.edu/policies-regulations/student-life/', 'https://www.utep.edu/titleix/', 'https://www.utep.edu/engineering/eec/advisors/index.html', 'student-resources-studentlife-deans-list.html', '../eec/honors/index.html', 'student-resources-preprofessional-experiences.html', 'feedback.html', 'student-resources-studentlife.html', 'Student-Opportunities.html', 'http://etc.utep.edu', 'https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html', 'student-resources-women-in-engineering.html', '../e-newsletter/index.html', 'https://www.utep.edu/engineering/miningyourpathtosuccess/index.html', 'https://www.utep.edu/student-affairs/admissions/', 'http://catalog.utep.edu/undergrad/', 'http://www.utep.edu/graduate/apply-now/apply-now.html', 'http://catalog.utep.edu/grad/', '../business-center/business-center.html', 'http://etc.utep.edu', 'https://events.utep.edu/calendar/upcoming?event_types[]=126310', 'https://www.utep.edu/engineering/student-resources/feedback.html?helpfullinks', 'https://www.facebook.com/utepengineering', 'https://twitter.com/utep', 'https://www.youtube.com/user/UTEPengineering', 'https://www.instagram.com/engineeringutep/', 'https://www.utep.edu/utepcares/cares-act ...
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://utep.edu/engineering/about-us/administration.html
# Link is working fine: https://utep.edu/engineering/fact-sheet/fact-sheet.html
# Link is working fine: https://utep.edu/engineering/about-us/accreditation.html
# Link is working fine: https://www.utep.edu/engineering/Alumni/index.html
# Link is working fine: https://utep.edu/engineering/academic-programs/degrees-and-programs.html
# Link is working fine: https://utep.edu/engineering/academic-programs/undergraduate-programs/undergraduate.html
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: https://utep.edu/engineering/academic-programs/graduate-programs/graduate-programs.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://utep.edu/engineering/mechanical/index.html
# Link is working fine: https://utep.edu/engineering/civil/index.html
# Link is working fine: https://www.utep.edu/cs/
# Link is working fine: https://utep.edu/engineering/ece/index.html
# Link is working fine: https://utep.edu/engineering/eel/index.html
# Link is working fine: https://utep.edu/engineering/imse/index.html
# Link is working fine: https://utep.edu/engineering/mmbme/index.html
# Link is working fine: https://utep.edu/engineering/eec/index.html
# Link is working fine: https://utep.edu/engineering/research/index.html
# Link is working fine: https://utep.edu/engineering/research/awards-and-recognition.html
# Link is working fine: https://utep.edu/engineering/research/research-and-support.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: https://utep.edu/engineering/research/newsfeed.html
# Link is working fine: https://www.utep.edu/engineering/eec/advisors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Link is working fine: https://utep.edu/engineering/eec/honors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://utep.edu/engineering/student-resources/feedback.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/engineering/k12/
# Link is working fine: https://utep.edu/engineering/k12/aspirations/index.html
# Link is working fine: https://utep.edu/engineering/k12/discover-e/index.html
# Link is working fine: https://utep.edu/engineering/k12/e-week/index.html
# Link is working fine: https://utep.edu/engineering/k12/excites/index.html
# Link is working fine: https://utep.edu/engineering/k12/robotics/index.html
# Link is working fine: https://utep.edu/engineering/eweek/index.html
# Link is working fine: https://www.utep.edu/engineering/homecoming/
# Link is working fine: https://utep.edu/engineering/graduateceremony/index.html
# Link is working fine: https://utep.edu/engineering/orderoftheengineer/index.html
# Link is working fine: https://utep.edu/engineering/tcm/index.html
# Link is working fine: https://givingto.utep.edu/coeng
# Link is working fine: https://my.utep.edu/My
# Link is working fine: https://utep.edu/resources/students.html
# Link is working fine: https://utep.edu/resources/faculty-and-staff.html
# Link is working fine: https://alumni.utep.edu/
# Link is working fine: https://utep.edu/resources/parents.html
# Link is working fine: https://www.utep.edu/library/
# Link is working fine: https://www.utep.edu/parking-and-transportation/
# Link is working fine: https://www.utep.edu/newsfeed/
# Link is working fine: https://minetracker.utep.edu/events
# Link is working fine: https://www.utep.edu/student-affairs/
# Link is working fine: https://www.utep.edu/vpba/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.bkstr.com/texaselpasostore/home
# Link is working fine: https://www.utep.edu/technologysupport/
# Link is working fine: https://www.utep.edu/engineering/
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/
# Duplicate broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/engineering/student-resources/
# Link is working fine: https://utep.questionpro.com/a/TakeSurvey?tt=tPyVABFtWSsECHrPeIW9eQ%3D%3D
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html' in 'Main Content' section: https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Link is working fine: https://www.utep.edu/student-affairs/dean-of-students-office/resources/grade-grievance.html
# Link is working fine: https://utep.questionpro.com/a/TakeSurvey?tt=eB7GJW%2BsGVQECHrPeIW9eQ%3D%3D
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# Link is working fine: https://www.utep.edu/titleix/
# Link is working fine: https://www.utep.edu/engineering/eec/advisors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Link is working fine: https://utep.edu/engineering/eec/honors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://utep.edu/engineering/student-resources/feedback.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/student-affairs/admissions/
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: https://www.utep.edu/graduate/apply-now/apply-now.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://utep.edu/engineering/business-center/business-center.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://minetracker.utep.edu/events
# Link is working fine: https://www.utep.edu/engineering/student-resources/feedback.html?helpfullinks
# Link is working fine: https://www.facebook.com/utepengineering
# Link is working fine: https://twitter.com/utep
# Link is working fine: https://www.youtube.com/user/UTEPengineering
# Link is working fine: https://www.instagram.com/engineeringutep/
# Link is working fine: https://www.utep.edu/utepcares/cares-act-compliance/
# Link is working fine: https://www.utep.edu/police/annual-security-and-fire-safety-report/
# Link is working fine: https://www.utep.edu/emergency/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.utep.edu/student-affairs/resources/Mental-Health-Resources-for-UTEP-Students.html
# Link is working fine: https://www.utep.edu/resources/public-course-information.html
# Invalid URL: http://sao.fraud.state.tx.us/
# Link is working fine: https://www.utep.edu/required-links/
# Link is working fine: https://www.utep.edu/vpba/state-reports/
# Link is working fine: https://veterans.portal.texas.gov/
# Link is working fine: https://www.utep.edu/titleix/Filing-a-Complaint.html
# Link is working fine: https://www.utep.edu/hoop/section-6/ch-3.html
# Link is working fine: https://www.utsystem.edu/
# Link is working fine: https://www.utep.edu/eoaa/policies/accessibility-policy.html
# Link is working fine: https://www.utep.edu/information-resources/iso/policies/web-privacy-policies.html
# Link is working fine: https://adminapps.utep.edu/feedback
# Checking page: https://www.utep.edu/engineering/student-resources/student-resources.html
# Links extracted from page: ['https://www.utep.edu/', '../about-us/administration.html', '../fact-sheet/fact-sheet.html', '../about-us/accreditation.html', '../academic-programs/degrees-and-programs.html', '../academic-programs/undergraduate-programs/undergraduate.html', 'http://catalog.utep.edu/undergrad/', '../academic-programs/graduate-programs/graduate-programs.html', 'http://catalog.utep.edu/grad/', '../civil/index.html', 'http://www.cs.utep.edu/', '../ece/index.html', '../eel/index.html', '../imse/index.html', '../mechanical/index.html', '../mmbme/index.html', '../eec/index.html', '../research/research-centers.html', '../research/awards-and-recognition.html', '../research/research-and-support.html', 'Student-Opportunities.html', 'student-resources-advising.html', 'student-resources-studentlife-deans-list.html', 'student-resources-preprofessional-experiences.html', 'student-resources-studentlife.html', 'Student-Opportunities.html', 'http://etc.utep.edu', 'http://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html', 'student-resources-women-in-engineering.html', '../e-newsletter/index.html', 'https://www.utep.edu/engineering/miningyourpathtosuccess/index.html', '../academic-programs/k12-outreach/k12-outreach.html', '../academic-programs/k12-outreach/ambassadors.html', '../academic-programs/k12-outreach/aspiration-in-computing.html', '../academic-programs/k12-outreach/e-week.html', '../academic-programs/k12-outreach/excites.html', '../academic-programs/k12-outreach/more-outreach.html', '../academic-programs/k12-outreach/nexus.html', '../academic-programs/k12-outreach/robotics.html', '../alumni/index.html', '../alumni/membership-levels.html', '../alumni/distinguished-alumni.html', '../alumni/Gold-Nuggets.html', '../alumni/Alumni-Spotlight.html', 'https://givingto.utep.edu/coeng', 'http://my.utep.edu', '/resources/students.html', '/resources/faculty-and-staff.html', 'http://alumni.utep.edu/', '/resources/parents.html', 'https://www.utep.edu/library/', 'https://www.utep.edu/vpba/parking-and-transportation/', 'https://www.utep.edu/newsfeed/', 'https://events.utep.edu/', 'https://www.utep.edu/student-affairs/', 'https://www.utep.edu/vpba/', 'https://www.utep.edu/human-resources/services/employment/index.html', 'http://www.utepbookstore.com', 'https://www.utep.edu/technologysupport/', '/engineering', 'https://www.utep.edu', '/engineering', '/engineering/student-resources', 'https://www.utep.edu', '/engineering', '/engineering/student-resources', '../_Files/docs/student-resources/2016 SHP Cyber Student Volunteer Initiative_Flyer.pdf', 'http://www.ll.mit.edu/', 'http://www.ll.mit.edu/college/summerprogram.html.', 'http://www.colorado.edu/law/academics/degrees/msl-degree-program', 'http://youtu.be/eusBjFrWAIg', 'http://sa.utep.edu/careers/employers-on-campus', 'http://www.pathwaystoscience.org/engineering.aspx', 'http://youtu.be/5gb1LNP0u1E', '../_Files/images/student-resources/ucslogo.png', 'http://www.utsystem.edu/seekut/Terms.htm', '../_Files/docs/student-resources/Career Development.pdf', 'http://mashable.com/2009/07/27/linkedin-personal-brand/#ecmNz.vC3Zqc', 'http://sa.utep.edu/careers/students/sample-documents', '/engineering/student-resources/student-employment', 'http://engineering.utep.edu/plaza/flyers/UnCoRe_flyer.pdf', 'http://engineeringinpractice.utep.edu/howtojointheprogram.html', 'http://science.utep.edu/nsf-prem/', 'http://couri.utep.edu/index.php/opportunities', 'http://engineering.utep.edu/graduate-researchopp.htm', 'http://engineering.utep.edu/plaza/circles/degree.htm', '../_Files/images/student-resources/e_resume.jpg', 'http://etc.utep.edu/index.htm', 'http://studentaffairs.utep.edu/Default.aspx?tabid=73328', 'http://engineering.utep.edu/plaza/tutoring/aces.htm', 'student-resources-advising.html', 'student-resources-studentlife-deans-list.html', 'student-resources-advising-orientation.html', 'student-resources-ug-admissions-faqs.html', 'student-resources-ug-admissions-advisors.html', 's ...
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/about-us/administration.html
# Link is working fine: https://www.utep.edu/engineering/fact-sheet/fact-sheet.html
# Link is working fine: https://www.utep.edu/engineering/about-us/accreditation.html
# Link is working fine: https://www.utep.edu/engineering/academic-programs/degrees-and-programs.html
# Link is working fine: https://www.utep.edu/engineering/academic-programs/undergraduate-programs/undergraduate.html
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: https://www.utep.edu/engineering/academic-programs/graduate-programs/graduate-programs.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://www.utep.edu/engineering/civil/index.html
# Link is working fine: http://www.cs.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/ece/index.html
# Link is working fine: https://www.utep.edu/engineering/eel/index.html
# Link is working fine: https://www.utep.edu/engineering/imse/index.html
# Link is working fine: https://www.utep.edu/engineering/mechanical/index.html
# Link is working fine: https://www.utep.edu/engineering/mmbme/index.html
# Link is working fine: https://www.utep.edu/engineering/eec/index.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/research/research-centers.html
# Link is working fine: https://www.utep.edu/engineering/research/awards-and-recognition.html
# Link is working fine: https://www.utep.edu/engineering/research/research-and-support.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/Student-Opportunities.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/student-resources-advising.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-studentlife.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://www.utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/k12-outreach.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/ambassadors.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/aspiration-in-computing.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/e-week.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/excites.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/more-outreach.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/nexus.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/robotics.html
# Link is working fine: https://www.utep.edu/engineering/alumni/index.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/alumni/membership-levels.html
# Link is working fine: https://www.utep.edu/engineering/alumni/distinguished-alumni.html
# Link is working fine: https://www.utep.edu/engineering/alumni/Gold-Nuggets.html
# Link is working fine: https://www.utep.edu/engineering/alumni/Alumni-Spotlight.html
# Link is working fine: https://givingto.utep.edu/coeng
# Link is working fine: https://my.utep.edu/My
# Link is working fine: https://www.utep.edu/resources/students.html
# Link is working fine: https://www.utep.edu/resources/faculty-and-staff.html
# Link is working fine: https://alumni.utep.edu/
# Link is working fine: https://www.utep.edu/resources/parents.html
# Link is working fine: https://www.utep.edu/library/
# Link is working fine: https://www.utep.edu/parking-and-transportation/
# Link is working fine: https://www.utep.edu/newsfeed/
# Link is working fine: https://minetracker.utep.edu/events
# Link is working fine: https://www.utep.edu/student-affairs/
# Link is working fine: https://www.utep.edu/vpba/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.bkstr.com/texaselpasostore/home
# Link is working fine: https://www.utep.edu/technologysupport/
# Link is working fine: https://www.utep.edu/engineering/
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/
# Duplicate broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html': https://www.utep.edu/engineering/student-resources/
# Link is working fine: https://www.utep.edu/engineering/_Files/docs/student-resources/2016%20SHP%20Cyber%20Student%20Volunteer%20Initiative_Flyer.pdf
# Link is working fine: https://www.ll.mit.edu/
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: http://www.ll.mit.edu/college/summerprogram.html.
# Link is working fine: https://www.colorado.edu/law/academics/degrees/msl-ethics-and-compliance
# Link is working fine: https://www.youtube.com/watch?v=eusBjFrWAIg&feature=youtu.be
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: http://sa.utep.edu/careers/employers-on-campus
# Link is working fine: https://www.pathwaystoscience.org/engineering.aspx
# Link is working fine: https://www.youtube.com/watch?v=5gb1LNP0u1E&feature=youtu.be
# Link is working fine: https://www.utep.edu/engineering/_Files/images/student-resources/ucslogo.png
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: https://www.utsystem.edu/seekut/Terms.htm
# Link is working fine: https://www.utep.edu/engineering/_Files/docs/student-resources/Career%20Development.pdf
# Link is working fine: https://mashable.com/archive/linkedin-personal-brand#ecmNz.vC3Zqc
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: http://sa.utep.edu/careers/students/sample-documents
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/student-employment
# Link is working fine: http://engineering.utep.edu/plaza/flyers/UnCoRe_flyer.pdf
# Link is working fine: http://engineeringinpractice.utep.edu/howtojointheprogram.html
# Invalid URL: http://science.utep.edu/nsf-prem/
# Link is working fine: https://www.utep.edu/couri/
# Link is working fine: http://engineering.utep.edu/graduate-researchopp.htm
# Link is working fine: http://engineering.utep.edu/plaza/circles/degree.htm
# Link is working fine: https://www.utep.edu/engineering/_Files/images/student-resources/e_resume.jpg
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: http://etc.utep.edu/index.htm
# Link is working fine: https://www.utep.edu/student-affairs/
# Link is working fine: http://engineering.utep.edu/plaza/tutoring/aces.htm
# Duplicate broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html': https://www.utep.edu/engineering/student-resources/student-resources-advising.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/student-resources-advising-orientation.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/student-resources-ug-admissions-faqs.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-ug-admissions-advisors.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-studentlife.html
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/student-resources-tutoring.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://www.utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/student-affairs/admissions/
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: https://www.utep.edu/graduate/apply-now/apply-now.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://www.utep.edu/engineering/business-center/business-center.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://minetracker.utep.edu/events
# Link is working fine: https://www.facebook.com/utepengineering
# Link is working fine: https://twitter.com/engineeringutep
# Link is working fine: https://www.youtube.com/user/UTEPengineering
# Link is working fine: https://www.instagram.com/engineeringutep/
# Link is working fine: https://www.utep.edu/utepcares/cares-act-compliance/
# Link is working fine: https://www.utep.edu/police/annual-security-and-fire-safety-report/
# Link is working fine: https://www.utep.edu/emergency/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.utep.edu/student-affairs/resources/Mental-Health-Resources-for-UTEP-Students.html
# Link is working fine: https://www.utep.edu/resources/public-course-information.html
# Invalid URL: http://sao.fraud.state.tx.us/
# Link is working fine: https://www.utep.edu/required-links/
# Link is working fine: https://www.utep.edu/vpba/state-reports/
# Link is working fine: https://veterans.portal.texas.gov/
# Link is working fine: https://www.utep.edu/titleix/Filing-a-Complaint.html
# Link is working fine: https://www.utep.edu/hoop/section-6/ch-3.html
# Link is working fine: https://www.utsystem.edu/
# Link is working fine: https://www.utep.edu/eoaa/policies/accessibility-policy.html
# Link is working fine: https://www.utep.edu/information-resources/iso/policies/web-privacy-policies.html
# Link is working fine: https://adminapps.utep.edu/feedback
# Total pages checked: 2
# Total broken links found: 23
# Total invalid links found: 3
# Broken Links Report:
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/, relative: /engineering/student-resources
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html' in 'Main Content' section: https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html, relative: https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/research/research-centers.html, relative: ../research/research-centers.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/student-resources-advising.html, relative: student-resources-advising.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/k12-outreach.html, relative: ../academic-programs/k12-outreach/k12-outreach.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/ambassadors.html, relative: ../academic-programs/k12-outreach/ambassadors.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/aspiration-in-computing.html, relative: ../academic-programs/k12-outreach/aspiration-in-computing.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/e-week.html, relative: ../academic-programs/k12-outreach/e-week.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/excites.html, relative: ../academic-programs/k12-outreach/excites.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/more-outreach.html, relative: ../academic-programs/k12-outreach/more-outreach.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/nexus.html, relative: ../academic-programs/k12-outreach/nexus.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/robotics.html, relative: ../academic-programs/k12-outreach/robotics.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/alumni/membership-levels.html, relative: ../alumni/membership-levels.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/, relative: /engineering/student-resources
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: http://www.ll.mit.edu/college/summerprogram.html., relative: http://www.ll.mit.edu/college/summerprogram.html.
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: http://sa.utep.edu/careers/employers-on-campus, relative: http://sa.utep.edu/careers/employers-on-campus
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: https://www.utsystem.edu/seekut/Terms.htm, relative: http://www.utsystem.edu/seekut/Terms.htm
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: http://sa.utep.edu/careers/students/sample-documents, relative: http://sa.utep.edu/careers/students/sample-documents
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/student-employment, relative: /engineering/student-resources/student-employment
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: http://etc.utep.edu/index.htm, relative: http://etc.utep.edu/index.htm
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/student-resources-advising-orientation.html, relative: student-resources-advising-orientation.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/student-resources-ug-admissions-faqs.html, relative: student-resources-ug-admissions-faqs.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/student-resources-tutoring.html, relative: student-resources-tutoring.html
# Broken links report saved to 'broken_links_report.csv'
# Invalid Links Report:
# Invalid Link on page 'https://utep.edu/engineering/student-resources/feedback.html': http://sao.fraud.state.tx.us/
# Invalid Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html': http://science.utep.edu/nsf-prem/
# Invalid Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html': http://sao.fraud.state.tx.us/
# Invalid links report saved to 'invalid_links_report.csv'

# %%
import openpyxl
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, unquote
import csv

def get_final_url(url):
    try:
        response = requests.get(url, allow_redirects=True)
        return response.url
    except requests.exceptions.RequestException:
        return None

def clean_link(link):
    if link and not link.startswith("mailto:") and not link.startswith("#"):
        link = unquote(link).strip()
        if link.endswith("%20"):
            link = link[:-3]  # Remove trailing %20 if it exists
        return link
    return None

def get_links_from_page(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            links = [clean_link(link.get('href')) for link in soup.find_all('a', href=True)]
            return [link for link in links if link is not None]  # Filter out None values
        else:
            return []
    except requests.exceptions.RequestException:
        return []

def identify_section(link, page_link):
    try:
        absolute_page_link = urljoin(link, page_link)
        response = requests.get(link)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            element = soup.find('a', {'href': absolute_page_link})
            if element:
                # Search for the outer elements to determine the section
                nav_element = element.find_parent('nav')
                if nav_element:
                    section = "Navigation"
                else:
                    section = "Unknown"  # Default value
                    # Check for specific keywords in the page_link
                    if "nav" in page_link:
                        section = "Navigation"
                    elif "/nav" in page_link:
                        section = "Main Content"

                footer_element = element.find_parent('footer')
                if footer_element:
                    section = "Footer"
                else:
                    # Check for specific keywords in the page_link
                    if "footer" in page_link:
                        section = "Footer"
                    elif "/footer" in page_link:
                        section = "Main Content"

                sidr_container_element = element.find_parent('div', id='sidr-container')
                if sidr_container_element:
                    section = "Main Content"

                return section

            return "Unknown"  # If the element is not found in any of the relevant outer elements
        else:
            return "Unknown"  # If there was an issue fetching the page
    except requests.exceptions.RequestException:
        return "Unknown"  # If there was a connection error or other issues









def check_broken_links(excel_file):
    try:
        print(f"Opening file: {excel_file}...")
        wb = openpyxl.load_workbook(excel_file)
        sheet = wb.active
        column_with_links = 'A'
        
        broken_links_report = []
        invalid_links_report = []
        total_links_checked = 0
        
        #print(f"Checking links inside {excel_file}...")
        for cell in sheet[column_with_links]:
            if cell.value:
                link = cell.value
                print(f"Checking page: {link}")
                total_links_checked += 1
                page_links = get_links_from_page(link)
                print(f"Links extracted from page: {page_links}")
                for page_link in page_links:
                    if is_valid_link(page_link):
                        absolute_link = urljoin(link, page_link)
                        final_url = get_final_url(absolute_link)
                        if final_url is not None:
                            try:
                                response = requests.get(final_url)
                                if response.status_code != 200:
                                    section = identify_section(link, page_link)  # Pass both link and page_link
                                    if (link, final_url, section, page_link) not in broken_links_report:  # Check for duplicates
                                        broken_links_report.append((link, final_url, section, page_link))
                                        print(f"Broken link found on page '{link}' in '{section}' section: {final_url}")
                                    else:
                                        print(f"Duplicate broken link found on page '{link}': {final_url}")
                                else:
                                    print(f"Link is working fine: {final_url}")
                            except requests.exceptions.RequestException:
                                section = identify_section(link, page_link)  # Pass both link and page_link
                                if (link, final_url, section, page_link) not in broken_links_report:  # Check for duplicates
                                    broken_links_report.append((link, final_url, section, page_link))
                                    print(f"Connection error occurred for link on page '{link}' in '{section}' section: {final_url}")
                                else:
                                    print(f"Duplicate connection error occurred for link on page '{link}': {final_url}")
                        else:
                            invalid_links_report.append((link, absolute_link))
                            print(f"Invalid URL: {absolute_link}")



        print(f"Total pages checked: {total_links_checked}")
        print(f"Total broken links found: {len(broken_links_report)}")
        print(f"Total invalid links found: {len(invalid_links_report)}")
        return broken_links_report, invalid_links_report
    except openpyxl.utils.exceptions.InvalidFileException:
        print(f"Error: Unable to open the file '{excel_file}'. Please check if it's a valid Excel file.")
        return [], []
    except Exception as e:
        print(f"Error: An unexpected error occurred while processing the file '{excel_file}': {e}")
        return [], []


def save_to_csv(file_path, data, header):
    with open(file_path, 'w', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(header)
        csv_writer.writerows(data)

if __name__ == "__main__":
    excel_file_path = "example.xlsx"
    broken_links_report, invalid_links_report = check_broken_links(excel_file_path)

    if broken_links_report:
        print("Broken Links Report:")
        for link, page_link, section, relative in broken_links_report:
            print(f"Broken Link on page '{link}' in '{section}' section: {page_link}, relative: {relative}")

        # Save broken links report to CSV
        csv_file_path = "broken_links_report.csv"
        header = ["Page", "Broken Link", "Section"]
        save_to_csv(csv_file_path, broken_links_report, header)
        print(f"Broken links report saved to '{csv_file_path}'")
    else:
        print("No broken links found.")

    if invalid_links_report:
        print("Invalid Links Report:")
        for link, page_link in invalid_links_report:
            print(f"Invalid Link on page '{link}': {page_link}")

        # Save invalid links report to CSV
        csv_file_path = "invalid_links_report.csv"
        header = ["Page", "Invalid Link"]
        save_to_csv(csv_file_path, invalid_links_report, header)
        print(f"Invalid links report saved to '{csv_file_path}'")
    else:
        print("No invalid links found.")
# Out:
# Opening file: example.xlsx...
# Checking page: https://utep.edu/engineering/student-resources/feedback.html
# Links extracted from page: ['https://www.utep.edu/', '../about-us/administration.html', '../fact-sheet/fact-sheet.html', '../about-us/accreditation.html', 'https://www.utep.edu/engineering/Alumni/index.html', '../academic-programs/degrees-and-programs.html', '../academic-programs/undergraduate-programs/undergraduate.html', 'http://catalog.utep.edu/undergrad/', '../academic-programs/graduate-programs/graduate-programs.html', 'http://catalog.utep.edu/grad/', '../mechanical/index.html', '../civil/index.html', 'https://www.utep.edu/cs/', '../ece/index.html', '../eel/index.html', '../imse/index.html', '../mmbme/index.html', '../eec/index.html', '../research/index.html', '../research/awards-and-recognition.html', '../research/research-and-support.html', 'Student-Opportunities.html', '../research/newsfeed.html', 'https://www.utep.edu/engineering/eec/advisors/index.html', 'student-resources-studentlife-deans-list.html', '../eec/honors/index.html', 'student-resources-preprofessional-experiences.html', 'feedback.html', 'student-resources-studentlife.html', 'Student-Opportunities.html', 'http://etc.utep.edu', 'http://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html', 'student-resources-women-in-engineering.html', '../e-newsletter/index.html', 'https://www.utep.edu/engineering/miningyourpathtosuccess/index.html', 'https://www.utep.edu/engineering/k12/', '../k12/aspirations/index.html', '../k12/discover-e/index.html', '../k12/e-week/index.html', '../k12/excites/index.html', '../k12/robotics/index.html', '../eweek/index.html', 'https://www.utep.edu/engineering/homecoming/', '../graduateceremony/index.html', '../orderoftheengineer/index.html', '../tcm/index.html', 'https://givingto.utep.edu/coeng', 'http://my.utep.edu', '/resources/students.html', '/resources/faculty-and-staff.html', 'http://alumni.utep.edu/', '/resources/parents.html', 'https://www.utep.edu/library/', 'https://www.utep.edu/vpba/parking-and-transportation/', 'https://www.utep.edu/newsfeed/', 'https://events.utep.edu/', 'https://www.utep.edu/student-affairs/', 'https://www.utep.edu/vpba/', 'https://www.utep.edu/human-resources/services/employment/index.html', 'http://www.utepbookstore.com', 'https://www.utep.edu/technologysupport/', '/engineering', 'https://www.utep.edu', '/engineering', '/engineering/student-resources', 'https://www.utep.edu', '/engineering', '/engineering/student-resources', 'https://utep.questionpro.com/t/AO6lJZvkI0', 'http://catalog.utep.edu/policies-regulations/student-life/', 'https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html', 'https://www.utep.edu/student-affairs/dean-of-students-office/resources/grade-grievance.html', 'https://utep.questionpro.com/t/AO6lJZvkJW', 'http://catalog.utep.edu/policies-regulations/student-life/', 'https://www.utep.edu/titleix/', 'https://www.utep.edu/engineering/eec/advisors/index.html', 'student-resources-studentlife-deans-list.html', '../eec/honors/index.html', 'student-resources-preprofessional-experiences.html', 'feedback.html', 'student-resources-studentlife.html', 'Student-Opportunities.html', 'http://etc.utep.edu', 'https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html', 'student-resources-women-in-engineering.html', '../e-newsletter/index.html', 'https://www.utep.edu/engineering/miningyourpathtosuccess/index.html', 'https://www.utep.edu/student-affairs/admissions/', 'http://catalog.utep.edu/undergrad/', 'http://www.utep.edu/graduate/apply-now/apply-now.html', 'http://catalog.utep.edu/grad/', '../business-center/business-center.html', 'http://etc.utep.edu', 'https://events.utep.edu/calendar/upcoming?event_types[]=126310', 'https://www.utep.edu/engineering/student-resources/feedback.html?helpfullinks', 'https://www.facebook.com/utepengineering', 'https://twitter.com/utep', 'https://www.youtube.com/user/UTEPengineering', 'https://www.instagram.com/engineeringutep/', 'https://www.utep.edu/utepcares/cares-act ...
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://utep.edu/engineering/about-us/administration.html
# Link is working fine: https://utep.edu/engineering/fact-sheet/fact-sheet.html
# Link is working fine: https://utep.edu/engineering/about-us/accreditation.html
# Link is working fine: https://www.utep.edu/engineering/Alumni/index.html
# Link is working fine: https://utep.edu/engineering/academic-programs/degrees-and-programs.html
# Link is working fine: https://utep.edu/engineering/academic-programs/undergraduate-programs/undergraduate.html
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: https://utep.edu/engineering/academic-programs/graduate-programs/graduate-programs.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://utep.edu/engineering/mechanical/index.html
# Link is working fine: https://utep.edu/engineering/civil/index.html
# Link is working fine: https://www.utep.edu/cs/
# Link is working fine: https://utep.edu/engineering/ece/index.html
# Link is working fine: https://utep.edu/engineering/eel/index.html
# Link is working fine: https://utep.edu/engineering/imse/index.html
# Link is working fine: https://utep.edu/engineering/mmbme/index.html
# Link is working fine: https://utep.edu/engineering/eec/index.html
# Link is working fine: https://utep.edu/engineering/research/index.html
# Link is working fine: https://utep.edu/engineering/research/awards-and-recognition.html
# Link is working fine: https://utep.edu/engineering/research/research-and-support.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: https://utep.edu/engineering/research/newsfeed.html
# Link is working fine: https://www.utep.edu/engineering/eec/advisors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Link is working fine: https://utep.edu/engineering/eec/honors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://utep.edu/engineering/student-resources/feedback.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/engineering/k12/
# Link is working fine: https://utep.edu/engineering/k12/aspirations/index.html
# Link is working fine: https://utep.edu/engineering/k12/discover-e/index.html
# Link is working fine: https://utep.edu/engineering/k12/e-week/index.html
# Link is working fine: https://utep.edu/engineering/k12/excites/index.html
# Link is working fine: https://utep.edu/engineering/k12/robotics/index.html
# Link is working fine: https://utep.edu/engineering/eweek/index.html
# Link is working fine: https://www.utep.edu/engineering/homecoming/
# Link is working fine: https://utep.edu/engineering/graduateceremony/index.html
# Link is working fine: https://utep.edu/engineering/orderoftheengineer/index.html
# Link is working fine: https://utep.edu/engineering/tcm/index.html
# Link is working fine: https://givingto.utep.edu/coeng
# Link is working fine: https://my.utep.edu/My
# Link is working fine: https://utep.edu/resources/students.html
# Link is working fine: https://utep.edu/resources/faculty-and-staff.html
# Link is working fine: https://alumni.utep.edu/
# Link is working fine: https://utep.edu/resources/parents.html
# Link is working fine: https://www.utep.edu/library/
# Link is working fine: https://www.utep.edu/parking-and-transportation/
# Link is working fine: https://www.utep.edu/newsfeed/
# Link is working fine: https://minetracker.utep.edu/events
# Link is working fine: https://www.utep.edu/student-affairs/
# Link is working fine: https://www.utep.edu/vpba/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.bkstr.com/texaselpasostore/home
# Link is working fine: https://www.utep.edu/technologysupport/
# Link is working fine: https://www.utep.edu/engineering/
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/
# Duplicate broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/engineering/student-resources/
# Link is working fine: https://utep.questionpro.com/a/TakeSurvey?tt=tPyVABFtWSsECHrPeIW9eQ%3D%3D
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html' in 'Main Content' section: https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Link is working fine: https://www.utep.edu/student-affairs/dean-of-students-office/resources/grade-grievance.html
# Link is working fine: https://utep.questionpro.com/a/TakeSurvey?tt=eB7GJW%2BsGVQECHrPeIW9eQ%3D%3D
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# Link is working fine: https://www.utep.edu/titleix/
# Link is working fine: https://www.utep.edu/engineering/eec/advisors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Link is working fine: https://utep.edu/engineering/eec/honors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://utep.edu/engineering/student-resources/feedback.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/student-affairs/admissions/
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: https://www.utep.edu/graduate/apply-now/apply-now.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://utep.edu/engineering/business-center/business-center.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://minetracker.utep.edu/events
# Link is working fine: https://www.utep.edu/engineering/student-resources/feedback.html?helpfullinks
# Link is working fine: https://www.facebook.com/utepengineering
# Link is working fine: https://twitter.com/utep
# Link is working fine: https://www.youtube.com/user/UTEPengineering
# Link is working fine: https://www.instagram.com/engineeringutep/
# Link is working fine: https://www.utep.edu/utepcares/cares-act-compliance/
# Link is working fine: https://www.utep.edu/police/annual-security-and-fire-safety-report/
# Link is working fine: https://www.utep.edu/emergency/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.utep.edu/student-affairs/resources/Mental-Health-Resources-for-UTEP-Students.html
# Link is working fine: https://www.utep.edu/resources/public-course-information.html
# Invalid URL: http://sao.fraud.state.tx.us/
# Link is working fine: https://www.utep.edu/required-links/
# Link is working fine: https://www.utep.edu/vpba/state-reports/
# Link is working fine: https://veterans.portal.texas.gov/
# Link is working fine: https://www.utep.edu/titleix/Filing-a-Complaint.html
# Link is working fine: https://www.utep.edu/hoop/section-6/ch-3.html
# Link is working fine: https://www.utsystem.edu/
# Link is working fine: https://www.utep.edu/eoaa/policies/accessibility-policy.html
# Link is working fine: https://www.utep.edu/information-resources/iso/policies/web-privacy-policies.html
# Link is working fine: https://adminapps.utep.edu/feedback
# Total pages checked: 1
# Total broken links found: 2
# Total invalid links found: 1
# Broken Links Report:
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html' in 'Unknown' section: https://www.utep.edu/engineering/student-resources/, relative: /engineering/student-resources
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html' in 'Main Content' section: https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html, relative: https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Broken links report saved to 'broken_links_report.csv'
# Invalid Links Report:
# Invalid Link on page 'https://utep.edu/engineering/student-resources/feedback.html': http://sao.fraud.state.tx.us/
# Invalid links report saved to 'invalid_links_report.csv'

# %%
import openpyxl
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, unquote
import csv

def get_final_url(url):
    try:
        response = requests.get(url, allow_redirects=True)
        return response.url
    except requests.exceptions.RequestException:
        return None

def clean_link(link):
    if link and not link.startswith("mailto:") and not link.startswith("#"):
        link = unquote(link).strip()
        if link.endswith("%20"):
            link = link[:-3]  # Remove trailing %20 if it exists
        return link
    return None

def get_links_from_page(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            links = [clean_link(link.get('href')) for link in soup.find_all('a', href=True)]
            return [link for link in links if link is not None]  # Filter out None values
        else:
            return []
    except requests.exceptions.RequestException:
        return []

def identify_section(link, page_link):
    try:
        absolute_page_link = urljoin(link, page_link)
        response = requests.get(link)
        print(page_link)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            # Search for partial matches of the href attribute with page_link
            element = soup.find('a', href=lambda href: page_link in href)
            print(element)
            if element:
                # Search for the outer elements to determine the section
                nav_element = element.find_parent('nav')
                if nav_element:
                    return "Navigation"
                
                footer_element = element.find_parent('footer')
                if footer_element:
                    return "Footer"
                
                sidr_container_element = element.find_parent('div', id='sidr-container')
                if sidr_container_element:
                    return "Main Content"
            return "Unknown"  # If the element is not found in any of the relevant outer elements
        else:
            return "Unknown"  # If there was an issue fetching the page
    except requests.exceptions.RequestException:
        return "Unknown"  # If there was a connection error or other issues







def check_broken_links(excel_file):
    try:
        print(f"Opening file: {excel_file}...")
        wb = openpyxl.load_workbook(excel_file)
        sheet = wb.active
        column_with_links = 'A'
        
        broken_links_report = []
        invalid_links_report = []
        total_links_checked = 0
        
        #print(f"Checking links inside {excel_file}...")
        for cell in sheet[column_with_links]:
            if cell.value:
                link = cell.value
                print(f"Checking page: {link}")
                total_links_checked += 1
                page_links = get_links_from_page(link)
                print(f"Links extracted from page: {page_links}")
                for page_link in page_links:
                    if is_valid_link(page_link):
                        absolute_link = urljoin(link, page_link)
                        final_url = get_final_url(absolute_link)
                        if final_url is not None:
                            try:
                                response = requests.get(final_url)
                                if response.status_code != 200:
                                    section = identify_section(link, page_link)  # Pass both link and page_link
                                    if (link, final_url, section, page_link) not in broken_links_report:  # Check for duplicates
                                        broken_links_report.append((link, final_url, section, page_link))
                                        print(f"Broken link found on page '{link}' in '{section}' section: {final_url}")
                                    else:
                                        print(f"Duplicate broken link found on page '{link}': {final_url}")
                                else:
                                    print(f"Link is working fine: {final_url}")
                            except requests.exceptions.RequestException:
                                section = identify_section(link, page_link)  # Pass both link and page_link
                                if (link, final_url, section, page_link) not in broken_links_report:  # Check for duplicates
                                    broken_links_report.append((link, final_url, section, page_link))
                                    print(f"Connection error occurred for link on page '{link}' in '{section}' section: {final_url}")
                                else:
                                    print(f"Duplicate connection error occurred for link on page '{link}': {final_url}")
                        else:
                            invalid_links_report.append((link, absolute_link))
                            print(f"Invalid URL: {absolute_link}")



        print(f"Total pages checked: {total_links_checked}")
        print(f"Total broken links found: {len(broken_links_report)}")
        print(f"Total invalid links found: {len(invalid_links_report)}")
        return broken_links_report, invalid_links_report
    except openpyxl.utils.exceptions.InvalidFileException:
        print(f"Error: Unable to open the file '{excel_file}'. Please check if it's a valid Excel file.")
        return [], []
    except Exception as e:
        print(f"Error: An unexpected error occurred while processing the file '{excel_file}': {e}")
        return [], []


def save_to_csv(file_path, data, header):
    with open(file_path, 'w', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(header)
        csv_writer.writerows(data)

if __name__ == "__main__":
    excel_file_path = "example.xlsx"
    broken_links_report, invalid_links_report = check_broken_links(excel_file_path)

    if broken_links_report:
        print("Broken Links Report:")
        for link, page_link, section, relative in broken_links_report:
            print(f"Broken Link on page '{link}' in '{section}' section: {page_link}, relative: {relative}")

        # Save broken links report to CSV
        csv_file_path = "broken_links_report.csv"
        header = ["Page", "Broken Link", "Section"]
        save_to_csv(csv_file_path, broken_links_report, header)
        print(f"Broken links report saved to '{csv_file_path}'")
    else:
        print("No broken links found.")

    if invalid_links_report:
        print("Invalid Links Report:")
        for link, page_link in invalid_links_report:
            print(f"Invalid Link on page '{link}': {page_link}")

        # Save invalid links report to CSV
        csv_file_path = "invalid_links_report.csv"
        header = ["Page", "Invalid Link"]
        save_to_csv(csv_file_path, invalid_links_report, header)
        print(f"Invalid links report saved to '{csv_file_path}'")
    else:
        print("No invalid links found.")
# Out:
# Opening file: example.xlsx...
# Checking page: https://utep.edu/engineering/student-resources/feedback.html
# Links extracted from page: ['https://www.utep.edu/', '../about-us/administration.html', '../fact-sheet/fact-sheet.html', '../about-us/accreditation.html', 'https://www.utep.edu/engineering/Alumni/index.html', '../academic-programs/degrees-and-programs.html', '../academic-programs/undergraduate-programs/undergraduate.html', 'http://catalog.utep.edu/undergrad/', '../academic-programs/graduate-programs/graduate-programs.html', 'http://catalog.utep.edu/grad/', '../mechanical/index.html', '../civil/index.html', 'https://www.utep.edu/cs/', '../ece/index.html', '../eel/index.html', '../imse/index.html', '../mmbme/index.html', '../eec/index.html', '../research/index.html', '../research/awards-and-recognition.html', '../research/research-and-support.html', 'Student-Opportunities.html', '../research/newsfeed.html', 'https://www.utep.edu/engineering/eec/advisors/index.html', 'student-resources-studentlife-deans-list.html', '../eec/honors/index.html', 'student-resources-preprofessional-experiences.html', 'feedback.html', 'student-resources-studentlife.html', 'Student-Opportunities.html', 'http://etc.utep.edu', 'http://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html', 'student-resources-women-in-engineering.html', '../e-newsletter/index.html', 'https://www.utep.edu/engineering/miningyourpathtosuccess/index.html', 'https://www.utep.edu/engineering/k12/', '../k12/aspirations/index.html', '../k12/discover-e/index.html', '../k12/e-week/index.html', '../k12/excites/index.html', '../k12/robotics/index.html', '../eweek/index.html', 'https://www.utep.edu/engineering/homecoming/', '../graduateceremony/index.html', '../orderoftheengineer/index.html', '../tcm/index.html', 'https://givingto.utep.edu/coeng', 'http://my.utep.edu', '/resources/students.html', '/resources/faculty-and-staff.html', 'http://alumni.utep.edu/', '/resources/parents.html', 'https://www.utep.edu/library/', 'https://www.utep.edu/vpba/parking-and-transportation/', 'https://www.utep.edu/newsfeed/', 'https://events.utep.edu/', 'https://www.utep.edu/student-affairs/', 'https://www.utep.edu/vpba/', 'https://www.utep.edu/human-resources/services/employment/index.html', 'http://www.utepbookstore.com', 'https://www.utep.edu/technologysupport/', '/engineering', 'https://www.utep.edu', '/engineering', '/engineering/student-resources', 'https://www.utep.edu', '/engineering', '/engineering/student-resources', 'https://utep.questionpro.com/t/AO6lJZvkI0', 'http://catalog.utep.edu/policies-regulations/student-life/', 'https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html', 'https://www.utep.edu/student-affairs/dean-of-students-office/resources/grade-grievance.html', 'https://utep.questionpro.com/t/AO6lJZvkJW', 'http://catalog.utep.edu/policies-regulations/student-life/', 'https://www.utep.edu/titleix/', 'https://www.utep.edu/engineering/eec/advisors/index.html', 'student-resources-studentlife-deans-list.html', '../eec/honors/index.html', 'student-resources-preprofessional-experiences.html', 'feedback.html', 'student-resources-studentlife.html', 'Student-Opportunities.html', 'http://etc.utep.edu', 'https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html', 'student-resources-women-in-engineering.html', '../e-newsletter/index.html', 'https://www.utep.edu/engineering/miningyourpathtosuccess/index.html', 'https://www.utep.edu/student-affairs/admissions/', 'http://catalog.utep.edu/undergrad/', 'http://www.utep.edu/graduate/apply-now/apply-now.html', 'http://catalog.utep.edu/grad/', '../business-center/business-center.html', 'http://etc.utep.edu', 'https://events.utep.edu/calendar/upcoming?event_types[]=126310', 'https://www.utep.edu/engineering/student-resources/feedback.html?helpfullinks', 'https://www.facebook.com/utepengineering', 'https://twitter.com/utep', 'https://www.youtube.com/user/UTEPengineering', 'https://www.instagram.com/engineeringutep/', 'https://www.utep.edu/utepcares/cares-act ...
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://utep.edu/engineering/about-us/administration.html
# Link is working fine: https://utep.edu/engineering/fact-sheet/fact-sheet.html
# Link is working fine: https://utep.edu/engineering/about-us/accreditation.html
# Link is working fine: https://www.utep.edu/engineering/Alumni/index.html
# Link is working fine: https://utep.edu/engineering/academic-programs/degrees-and-programs.html
# Link is working fine: https://utep.edu/engineering/academic-programs/undergraduate-programs/undergraduate.html
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: https://utep.edu/engineering/academic-programs/graduate-programs/graduate-programs.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://utep.edu/engineering/mechanical/index.html
# Link is working fine: https://utep.edu/engineering/civil/index.html
# Link is working fine: https://www.utep.edu/cs/
# Link is working fine: https://utep.edu/engineering/ece/index.html
# Link is working fine: https://utep.edu/engineering/eel/index.html
# Link is working fine: https://utep.edu/engineering/imse/index.html
# Link is working fine: https://utep.edu/engineering/mmbme/index.html
# Link is working fine: https://utep.edu/engineering/eec/index.html
# Link is working fine: https://utep.edu/engineering/research/index.html
# Link is working fine: https://utep.edu/engineering/research/awards-and-recognition.html
# Link is working fine: https://utep.edu/engineering/research/research-and-support.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: https://utep.edu/engineering/research/newsfeed.html
# Link is working fine: https://www.utep.edu/engineering/eec/advisors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Link is working fine: https://utep.edu/engineering/eec/honors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://utep.edu/engineering/student-resources/feedback.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/engineering/k12/
# Link is working fine: https://utep.edu/engineering/k12/aspirations/index.html
# Link is working fine: https://utep.edu/engineering/k12/discover-e/index.html
# Link is working fine: https://utep.edu/engineering/k12/e-week/index.html
# Link is working fine: https://utep.edu/engineering/k12/excites/index.html
# Link is working fine: https://utep.edu/engineering/k12/robotics/index.html
# Link is working fine: https://utep.edu/engineering/eweek/index.html
# Link is working fine: https://www.utep.edu/engineering/homecoming/
# Link is working fine: https://utep.edu/engineering/graduateceremony/index.html
# Link is working fine: https://utep.edu/engineering/orderoftheengineer/index.html
# Link is working fine: https://utep.edu/engineering/tcm/index.html
# Link is working fine: https://givingto.utep.edu/coeng
# Link is working fine: https://my.utep.edu/My
# Link is working fine: https://utep.edu/resources/students.html
# Link is working fine: https://utep.edu/resources/faculty-and-staff.html
# Link is working fine: https://alumni.utep.edu/
# Link is working fine: https://utep.edu/resources/parents.html
# Link is working fine: https://www.utep.edu/library/
# Link is working fine: https://www.utep.edu/parking-and-transportation/
# Link is working fine: https://www.utep.edu/newsfeed/
# Link is working fine: https://minetracker.utep.edu/events
# Link is working fine: https://www.utep.edu/student-affairs/
# Link is working fine: https://www.utep.edu/vpba/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.bkstr.com/texaselpasostore/home
# Link is working fine: https://www.utep.edu/technologysupport/
# Link is working fine: https://www.utep.edu/engineering/
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/
# /engineering/student-resources
# <a href="http://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html">            Tutoring
#     </a>
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html' in 'Navigation' section: https://www.utep.edu/engineering/student-resources/
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/
# /engineering/student-resources
# <a href="http://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html">            Tutoring
#     </a>
# Duplicate broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/engineering/student-resources/
# Link is working fine: https://utep.questionpro.com/a/TakeSurvey?tt=tPyVABFtWSsECHrPeIW9eQ%3D%3D
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# <a href="https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html" rel="noopener" target="_blank">Office of Student Life Web page</a>
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html' in 'Main Content' section: https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Link is working fine: https://www.utep.edu/student-affairs/dean-of-students-office/resources/grade-grievance.html
# Link is working fine: https://utep.questionpro.com/a/TakeSurvey?tt=eB7GJW%2BsGVQECHrPeIW9eQ%3D%3D
# Link is working fine: http://catalog.utep.edu/policies-regulations/student-life/
# Link is working fine: https://www.utep.edu/titleix/
# Link is working fine: https://www.utep.edu/engineering/eec/advisors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Link is working fine: https://utep.edu/engineering/eec/honors/index.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://utep.edu/engineering/student-resources/feedback.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-studentlife.html
# Link is working fine: https://utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Link is working fine: https://utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/student-affairs/admissions/
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: https://www.utep.edu/graduate/apply-now/apply-now.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://utep.edu/engineering/business-center/business-center.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://minetracker.utep.edu/events
# Link is working fine: https://www.utep.edu/engineering/student-resources/feedback.html?helpfullinks
# Link is working fine: https://www.facebook.com/utepengineering
# Link is working fine: https://twitter.com/utep
# Link is working fine: https://www.youtube.com/user/UTEPengineering
# Link is working fine: https://www.instagram.com/engineeringutep/
# Link is working fine: https://www.utep.edu/utepcares/cares-act-compliance/
# Link is working fine: https://www.utep.edu/police/annual-security-and-fire-safety-report/
# Link is working fine: https://www.utep.edu/emergency/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.utep.edu/student-affairs/resources/Mental-Health-Resources-for-UTEP-Students.html
# Link is working fine: https://www.utep.edu/resources/public-course-information.html
# Invalid URL: http://sao.fraud.state.tx.us/
# Link is working fine: https://www.utep.edu/required-links/
# Link is working fine: https://www.utep.edu/vpba/state-reports/
# Link is working fine: https://veterans.portal.texas.gov/
# Link is working fine: https://www.utep.edu/titleix/Filing-a-Complaint.html
# Link is working fine: https://www.utep.edu/hoop/section-6/ch-3.html
# Link is working fine: https://www.utsystem.edu/
# Link is working fine: https://www.utep.edu/eoaa/policies/accessibility-policy.html
# Link is working fine: https://www.utep.edu/information-resources/iso/policies/web-privacy-policies.html
# Link is working fine: https://adminapps.utep.edu/feedback
# Checking page: https://www.utep.edu/engineering/student-resources/student-resources.html
# Links extracted from page: ['https://www.utep.edu/', '../about-us/administration.html', '../fact-sheet/fact-sheet.html', '../about-us/accreditation.html', '../academic-programs/degrees-and-programs.html', '../academic-programs/undergraduate-programs/undergraduate.html', 'http://catalog.utep.edu/undergrad/', '../academic-programs/graduate-programs/graduate-programs.html', 'http://catalog.utep.edu/grad/', '../civil/index.html', 'http://www.cs.utep.edu/', '../ece/index.html', '../eel/index.html', '../imse/index.html', '../mechanical/index.html', '../mmbme/index.html', '../eec/index.html', '../research/research-centers.html', '../research/awards-and-recognition.html', '../research/research-and-support.html', 'Student-Opportunities.html', 'student-resources-advising.html', 'student-resources-studentlife-deans-list.html', 'student-resources-preprofessional-experiences.html', 'student-resources-studentlife.html', 'Student-Opportunities.html', 'http://etc.utep.edu', 'http://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html', 'student-resources-women-in-engineering.html', '../e-newsletter/index.html', 'https://www.utep.edu/engineering/miningyourpathtosuccess/index.html', '../academic-programs/k12-outreach/k12-outreach.html', '../academic-programs/k12-outreach/ambassadors.html', '../academic-programs/k12-outreach/aspiration-in-computing.html', '../academic-programs/k12-outreach/e-week.html', '../academic-programs/k12-outreach/excites.html', '../academic-programs/k12-outreach/more-outreach.html', '../academic-programs/k12-outreach/nexus.html', '../academic-programs/k12-outreach/robotics.html', '../alumni/index.html', '../alumni/membership-levels.html', '../alumni/distinguished-alumni.html', '../alumni/Gold-Nuggets.html', '../alumni/Alumni-Spotlight.html', 'https://givingto.utep.edu/coeng', 'http://my.utep.edu', '/resources/students.html', '/resources/faculty-and-staff.html', 'http://alumni.utep.edu/', '/resources/parents.html', 'https://www.utep.edu/library/', 'https://www.utep.edu/vpba/parking-and-transportation/', 'https://www.utep.edu/newsfeed/', 'https://events.utep.edu/', 'https://www.utep.edu/student-affairs/', 'https://www.utep.edu/vpba/', 'https://www.utep.edu/human-resources/services/employment/index.html', 'http://www.utepbookstore.com', 'https://www.utep.edu/technologysupport/', '/engineering', 'https://www.utep.edu', '/engineering', '/engineering/student-resources', 'https://www.utep.edu', '/engineering', '/engineering/student-resources', '../_Files/docs/student-resources/2016 SHP Cyber Student Volunteer Initiative_Flyer.pdf', 'http://www.ll.mit.edu/', 'http://www.ll.mit.edu/college/summerprogram.html.', 'http://www.colorado.edu/law/academics/degrees/msl-degree-program', 'http://youtu.be/eusBjFrWAIg', 'http://sa.utep.edu/careers/employers-on-campus', 'http://www.pathwaystoscience.org/engineering.aspx', 'http://youtu.be/5gb1LNP0u1E', '../_Files/images/student-resources/ucslogo.png', 'http://www.utsystem.edu/seekut/Terms.htm', '../_Files/docs/student-resources/Career Development.pdf', 'http://mashable.com/2009/07/27/linkedin-personal-brand/#ecmNz.vC3Zqc', 'http://sa.utep.edu/careers/students/sample-documents', '/engineering/student-resources/student-employment', 'http://engineering.utep.edu/plaza/flyers/UnCoRe_flyer.pdf', 'http://engineeringinpractice.utep.edu/howtojointheprogram.html', 'http://science.utep.edu/nsf-prem/', 'http://couri.utep.edu/index.php/opportunities', 'http://engineering.utep.edu/graduate-researchopp.htm', 'http://engineering.utep.edu/plaza/circles/degree.htm', '../_Files/images/student-resources/e_resume.jpg', 'http://etc.utep.edu/index.htm', 'http://studentaffairs.utep.edu/Default.aspx?tabid=73328', 'http://engineering.utep.edu/plaza/tutoring/aces.htm', 'student-resources-advising.html', 'student-resources-studentlife-deans-list.html', 'student-resources-advising-orientation.html', 'student-resources-ug-admissions-faqs.html', 'student-resources-ug-admissions-advisors.html', 's ...
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/about-us/administration.html
# Link is working fine: https://www.utep.edu/engineering/fact-sheet/fact-sheet.html
# Link is working fine: https://www.utep.edu/engineering/about-us/accreditation.html
# Link is working fine: https://www.utep.edu/engineering/academic-programs/degrees-and-programs.html
# Link is working fine: https://www.utep.edu/engineering/academic-programs/undergraduate-programs/undergraduate.html
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: https://www.utep.edu/engineering/academic-programs/graduate-programs/graduate-programs.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://www.utep.edu/engineering/civil/index.html
# Link is working fine: http://www.cs.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/ece/index.html
# Link is working fine: https://www.utep.edu/engineering/eel/index.html
# Link is working fine: https://www.utep.edu/engineering/imse/index.html
# Link is working fine: https://www.utep.edu/engineering/mechanical/index.html
# Link is working fine: https://www.utep.edu/engineering/mmbme/index.html
# Link is working fine: https://www.utep.edu/engineering/eec/index.html
# ../research/research-centers.html
# <a href="../research/research-centers.html">            Research Centers and Facilities
#     </a>
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/research/research-centers.html
# Link is working fine: https://www.utep.edu/engineering/research/awards-and-recognition.html
# Link is working fine: https://www.utep.edu/engineering/research/research-and-support.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/Student-Opportunities.html
# student-resources-advising.html
# <a href="student-resources-advising.html">            Advising
#     </a>
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/student-resources/student-resources-advising.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-studentlife.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/Student-Opportunities.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://www.utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# ../academic-programs/k12-outreach/k12-outreach.html
# <a href="../academic-programs/k12-outreach/k12-outreach.html">            K12 Outreach
#     </a>
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/k12-outreach.html
# ../academic-programs/k12-outreach/ambassadors.html
# <a href="../academic-programs/k12-outreach/ambassadors.html">            Ambassadors
#     </a>
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/ambassadors.html
# ../academic-programs/k12-outreach/aspiration-in-computing.html
# <a href="../academic-programs/k12-outreach/aspiration-in-computing.html">            Aspirations in Computing
#     </a>
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/aspiration-in-computing.html
# ../academic-programs/k12-outreach/e-week.html
# <a href="../academic-programs/k12-outreach/e-week.html">            E-Week
#     </a>
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/e-week.html
# ../academic-programs/k12-outreach/excites.html
# <a href="../academic-programs/k12-outreach/excites.html">            ExciTES
#     </a>
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/excites.html
# ../academic-programs/k12-outreach/more-outreach.html
# <a href="../academic-programs/k12-outreach/more-outreach.html">            More Outreach
#     </a>
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/more-outreach.html
# ../academic-programs/k12-outreach/nexus.html
# <a href="../academic-programs/k12-outreach/nexus.html">            Nexus
#     </a>
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/nexus.html
# ../academic-programs/k12-outreach/robotics.html
# <a href="../academic-programs/k12-outreach/robotics.html">            Robotics
#     </a>
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/robotics.html
# Link is working fine: https://www.utep.edu/engineering/alumni/index.html
# ../alumni/membership-levels.html
# <a href="../alumni/membership-levels.html">            Membership Levels
#     </a>
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/alumni/membership-levels.html
# Link is working fine: https://www.utep.edu/engineering/alumni/distinguished-alumni.html
# Link is working fine: https://www.utep.edu/engineering/alumni/Gold-Nuggets.html
# Link is working fine: https://www.utep.edu/engineering/alumni/Alumni-Spotlight.html
# Link is working fine: https://givingto.utep.edu/coeng
# Link is working fine: https://my.utep.edu/My
# Link is working fine: https://www.utep.edu/resources/students.html
# Link is working fine: https://www.utep.edu/resources/faculty-and-staff.html
# Link is working fine: https://alumni.utep.edu/
# Link is working fine: https://www.utep.edu/resources/parents.html
# Link is working fine: https://www.utep.edu/library/
# Link is working fine: https://www.utep.edu/parking-and-transportation/
# Link is working fine: https://www.utep.edu/newsfeed/
# Link is working fine: https://minetracker.utep.edu/events
# Link is working fine: https://www.utep.edu/student-affairs/
# Link is working fine: https://www.utep.edu/vpba/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.bkstr.com/texaselpasostore/home
# Link is working fine: https://www.utep.edu/technologysupport/
# Link is working fine: https://www.utep.edu/engineering/
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/
# /engineering/student-resources
# <a href="http://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html">            Tutoring
#     </a>
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/student-resources/
# Link is working fine: https://www.utep.edu/
# Link is working fine: https://www.utep.edu/engineering/
# /engineering/student-resources
# <a href="http://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html">            Tutoring
#     </a>
# Duplicate broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html': https://www.utep.edu/engineering/student-resources/
# Link is working fine: https://www.utep.edu/engineering/_Files/docs/student-resources/2016%20SHP%20Cyber%20Student%20Volunteer%20Initiative_Flyer.pdf
# Link is working fine: https://www.ll.mit.edu/
# http://www.ll.mit.edu/college/summerprogram.html.
# <a href="http://www.ll.mit.edu/college/summerprogram.html." rel="noopener noreferrer" target="_blank">here</a>
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: http://www.ll.mit.edu/college/summerprogram.html.
# Link is working fine: https://www.colorado.edu/law/academics/degrees/msl-ethics-and-compliance
# Link is working fine: https://www.youtube.com/watch?v=eusBjFrWAIg&feature=youtu.be
# http://sa.utep.edu/careers/employers-on-campus
# <a href="http://sa.utep.edu/careers/employers-on-campus" rel="noopener noreferrer" target="_blank">Spring 2017 Employer Recruitment Calendar:</a>
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: http://sa.utep.edu/careers/employers-on-campus
# Link is working fine: https://www.pathwaystoscience.org/engineering.aspx
# Link is working fine: https://www.youtube.com/watch?v=5gb1LNP0u1E&feature=youtu.be
# Link is working fine: https://www.utep.edu/engineering/_Files/images/student-resources/ucslogo.png
# http://www.utsystem.edu/seekut/Terms.htm
# <a href="http://www.utsystem.edu/seekut/Terms.htm" rel="noopener noreferrer" target="_blank">Future Salary as a UTEP Grad!</a>
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: https://www.utsystem.edu/seekut/Terms.htm
# Link is working fine: https://www.utep.edu/engineering/_Files/docs/student-resources/Career%20Development.pdf
# Link is working fine: https://mashable.com/archive/linkedin-personal-brand#ecmNz.vC3Zqc
# http://sa.utep.edu/careers/students/sample-documents
# <a href="http://sa.utep.edu/careers/students/sample-documents" rel="noopener noreferrer" target="_blank">Use these guidelines, sample documents (resume, cover letter), interview strategies, and more, to help in your future career preparation.</a>
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: http://sa.utep.edu/careers/students/sample-documents
# /engineering/student-resources/student-employment
# <a href="/engineering/student-resources/student-employment">Click here for more job opportunities!</a>
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: https://www.utep.edu/engineering/student-resources/student-employment
# Link is working fine: http://engineering.utep.edu/plaza/flyers/UnCoRe_flyer.pdf
# Link is working fine: http://engineeringinpractice.utep.edu/howtojointheprogram.html
# Invalid URL: http://science.utep.edu/nsf-prem/
# Link is working fine: https://www.utep.edu/couri/
# Link is working fine: http://engineering.utep.edu/graduate-researchopp.htm
# Link is working fine: http://engineering.utep.edu/plaza/circles/degree.htm
# Link is working fine: https://www.utep.edu/engineering/_Files/images/student-resources/e_resume.jpg
# http://etc.utep.edu/index.htm
# <a href="http://etc.utep.edu/index.htm" rel="noopener noreferrer" target="_blank">GET the Software You Need at ETC</a>
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: http://etc.utep.edu/index.htm
# Link is working fine: https://www.utep.edu/student-affairs/
# Link is working fine: http://engineering.utep.edu/plaza/tutoring/aces.htm
# student-resources-advising.html
# <a href="student-resources-advising.html">            Advising
#     </a>
# Duplicate broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html': https://www.utep.edu/engineering/student-resources/student-resources-advising.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-studentlife-deans-list.html
# student-resources-advising-orientation.html
# <a href="student-resources-advising-orientation.html">            - Orientation
#     </a>
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/student-resources/student-resources-advising-orientation.html
# student-resources-ug-admissions-faqs.html
# <a href="student-resources-ug-admissions-faqs.html">            - FAQ's
#     </a>
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/student-resources/student-resources-ug-admissions-faqs.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-ug-admissions-advisors.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-studentlife.html
# student-resources-tutoring.html
# <a href="student-resources-tutoring.html">            Tutoring
#     </a>
# Broken link found on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/student-resources/student-resources-tutoring.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-women-in-engineering.html
# Link is working fine: https://www.utep.edu/engineering/student-resources/student-resources-preprofessional-experiences.html
# Link is working fine: https://www.utep.edu/engineering/e-newsletter/index.html
# Link is working fine: https://www.utep.edu/engineering/miningyourpathtosuccess/index.html
# Link is working fine: https://www.utep.edu/student-affairs/admissions/
# Link is working fine: http://catalog.utep.edu/undergrad/
# Link is working fine: https://www.utep.edu/graduate/apply-now/apply-now.html
# Link is working fine: http://catalog.utep.edu/grad/
# Link is working fine: https://www.utep.edu/engineering/business-center/business-center.html
# Link is working fine: http://etc.utep.edu/
# Link is working fine: https://minetracker.utep.edu/events
# Link is working fine: https://www.facebook.com/utepengineering
# Link is working fine: https://twitter.com/engineeringutep
# Link is working fine: https://www.youtube.com/user/UTEPengineering
# Link is working fine: https://www.instagram.com/engineeringutep/
# Link is working fine: https://www.utep.edu/utepcares/cares-act-compliance/
# Link is working fine: https://www.utep.edu/police/annual-security-and-fire-safety-report/
# Link is working fine: https://www.utep.edu/emergency/
# Link is working fine: https://www.utep.edu/human-resources/services/employment/index.html
# Link is working fine: https://www.utep.edu/student-affairs/resources/Mental-Health-Resources-for-UTEP-Students.html
# Link is working fine: https://www.utep.edu/resources/public-course-information.html
# Invalid URL: http://sao.fraud.state.tx.us/
# Link is working fine: https://www.utep.edu/required-links/
# Link is working fine: https://www.utep.edu/vpba/state-reports/
# Link is working fine: https://veterans.portal.texas.gov/
# Link is working fine: https://www.utep.edu/titleix/Filing-a-Complaint.html
# Link is working fine: https://www.utep.edu/hoop/section-6/ch-3.html
# Link is working fine: https://www.utsystem.edu/
# Link is working fine: https://www.utep.edu/eoaa/policies/accessibility-policy.html
# Link is working fine: https://www.utep.edu/information-resources/iso/policies/web-privacy-policies.html
# Link is working fine: https://adminapps.utep.edu/feedback
# Total pages checked: 2
# Total broken links found: 23
# Total invalid links found: 3
# Broken Links Report:
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html' in 'Navigation' section: https://www.utep.edu/engineering/student-resources/, relative: /engineering/student-resources
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html' in 'Main Content' section: https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html, relative: https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/research/research-centers.html, relative: ../research/research-centers.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/student-resources/student-resources-advising.html, relative: student-resources-advising.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/k12-outreach.html, relative: ../academic-programs/k12-outreach/k12-outreach.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/ambassadors.html, relative: ../academic-programs/k12-outreach/ambassadors.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/aspiration-in-computing.html, relative: ../academic-programs/k12-outreach/aspiration-in-computing.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/e-week.html, relative: ../academic-programs/k12-outreach/e-week.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/excites.html, relative: ../academic-programs/k12-outreach/excites.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/more-outreach.html, relative: ../academic-programs/k12-outreach/more-outreach.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/nexus.html, relative: ../academic-programs/k12-outreach/nexus.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/robotics.html, relative: ../academic-programs/k12-outreach/robotics.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/alumni/membership-levels.html, relative: ../alumni/membership-levels.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/student-resources/, relative: /engineering/student-resources
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: http://www.ll.mit.edu/college/summerprogram.html., relative: http://www.ll.mit.edu/college/summerprogram.html.
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: http://sa.utep.edu/careers/employers-on-campus, relative: http://sa.utep.edu/careers/employers-on-campus
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: https://www.utsystem.edu/seekut/Terms.htm, relative: http://www.utsystem.edu/seekut/Terms.htm
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: http://sa.utep.edu/careers/students/sample-documents, relative: http://sa.utep.edu/careers/students/sample-documents
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: https://www.utep.edu/engineering/student-resources/student-employment, relative: /engineering/student-resources/student-employment
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: http://etc.utep.edu/index.htm, relative: http://etc.utep.edu/index.htm
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/student-resources/student-resources-advising-orientation.html, relative: student-resources-advising-orientation.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/student-resources/student-resources-ug-admissions-faqs.html, relative: student-resources-ug-admissions-faqs.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/student-resources/student-resources-tutoring.html, relative: student-resources-tutoring.html
# Broken links report saved to 'broken_links_report.csv'
# Invalid Links Report:
# Invalid Link on page 'https://utep.edu/engineering/student-resources/feedback.html': http://sao.fraud.state.tx.us/
# Invalid Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html': http://science.utep.edu/nsf-prem/
# Invalid Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html': http://sao.fraud.state.tx.us/
# Invalid links report saved to 'invalid_links_report.csv'

# %%
import openpyxl
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, unquote
import csv
from tqdm.notebook import tqdm


def get_final_url(url):
    try:
        response = requests.get(url, allow_redirects=True)
        return response.url
    except requests.exceptions.RequestException:
        return None

def clean_link(link):
    if link and not link.startswith("mailto:") and not link.startswith("#"):
        link = unquote(link).strip()
        if link.endswith("%20"):
            link = link[:-3]  # Remove trailing %20 if it exists
        return link
    return None

def get_links_from_page(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            links = [a.get('href') for a in soup.find_all('a', href=True)]
            absolute_links = [urljoin(url, link) for link in links if link]
            return absolute_links, len(absolute_links)
        else:
            return [], 0
    except requests.exceptions.RequestException:
        return [], 0

def identify_section(link, page_link):
    try:
        absolute_page_link = urljoin(link, page_link)
        response = requests.get(link)
        print(page_link)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            # Search for partial matches of the href attribute with page_link
            element = soup.find('a', href=lambda href: page_link in href)
            print(element)
            if element:
                # Search for the outer elements to determine the section
                nav_element = element.find_parent('nav')
                if nav_element:
                    return "Navigation"
                
                footer_element = element.find_parent('footer')
                if footer_element:
                    return "Footer"
                
                sidr_container_element = element.find_parent('div', id='sidr-container')
                if sidr_container_element:
                    return "Main Content"
            return "Unknown"  # If the element is not found in any of the relevant outer elements
        else:
            return "Unknown"  # If there was an issue fetching the page
    except requests.exceptions.RequestException:
        return "Unknown"  # If there was a connection error or other issues


def check_broken_links(excel_file):
    try:
        print(f"Opening file: {excel_file}...")
        wb = openpyxl.load_workbook(excel_file)
        sheet = wb.active
        column_with_links = 'A'

        broken_links_report = []
        invalid_links_report = []
        total_links_checked = 0
        total_links = 0

        for cell in sheet[column_with_links]:
            if cell.value:
                total_links += 1

        print(f"Checking {total_links} links inside {excel_file}...")
        for cell in tqdm(sheet[column_with_links], total=total_links, desc="Progress"):
            if cell.value:
                link = cell.value
                total_links_checked += 1
                page_links, total_page_links = get_links_from_page(link)

                # Page progress bar starts here
                page_progress_desc = f"Page Progress ({total_links_checked}/{total_links})"
                for page_link_idx, page_link in enumerate(tqdm(page_links, total=total_page_links, desc=page_progress_desc, leave=False), 1):
                    if is_valid_link(page_link):
                        absolute_link = urljoin(link, page_link)
                        final_url = get_final_url(absolute_link)
                        if final_url is not None:
                            try:
                                response = requests.get(final_url)
                                if response.status_code != 200:
                                    section = identify_section(link, page_link)
                                    if (link, final_url, section, page_link) not in broken_links_report:
                                        broken_links_report.append((link, final_url, section, page_link))
                                        tqdm.write(f"Broken link found in '{section}' section: {final_url}", end='\r')
                                    else:
                                        tqdm.write(f"Duplicate broken link found: {final_url}", end='\r')
                                else:
                                    pass  # No need for this message
                            except requests.exceptions.RequestException:
                                section = identify_section(link, page_link)
                                if (link, final_url, section, page_link) not in broken_links_report:
                                    broken_links_report.append((link, final_url, section, page_link))
                                    tqdm.write(f"Connection error occurred in '{section}' section: {final_url}", end='\r')
                                else:
                                    tqdm.write(f"Duplicate connection error occurred: {final_url}", end='\r')
                        else:
                            invalid_links_report.append((link, absolute_link))
                            tqdm.write(f"Invalid URL: {absolute_link}", end='\r')

        print(f"\nTotal pages checked: {total_links_checked}")
        print(f"Total broken links found: {len(broken_links_report)}")
        print(f"Total invalid links found: {len(invalid_links_report)}")
        return broken_links_report, invalid_links_report
    except openpyxl.utils.exceptions.InvalidFileException:
        print(f"Error: Unable to open the file '{excel_file}'. Please check if it's a valid Excel file.")
        return [], []
    except Exception as e:
        print(f"Error: An unexpected error occurred while processing the file '{excel_file}': {e}")
        return [], []





def save_to_csv(file_path, data, header):
    with open(file_path, 'w', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(header)
        csv_writer.writerows(data)

if __name__ == "__main__":
    excel_file_path = "example.xlsx"
    broken_links_report = check_broken_links(excel_file_path)

    if broken_links_report:
        print("Broken Links Report:")
        for link, page_link, section, relative in broken_links_report:
            print(f"Broken Link on page '{link}' in '{section}' section: {page_link}, relative: {relative}")

        # Save broken links report to CSV
        csv_file_path = "broken_links_report.csv"
        header = ["Page", "Broken Link", "Section"]
        save_to_csv(csv_file_path, broken_links_report, header)
        print(f"Broken links report saved to '{csv_file_path}'")
    else:
        print("No broken links or invalid URLs found.")
# Out:
# Opening file: example.xlsx...
# Checking 2 links inside example.xlsx...
# Progress:   0%|          | 0/2 [00:00<?, ?it/s]
# Page Progress (1/2):   0%|          | 0/129 [00:00<?, ?it/s]
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [07:56<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [03:01<01:00,  1.67it/s]
# https://www.utep.edu/vpba/parking-and-transportation/
# <a href="https://www.utep.edu/vpba/parking-and-transportation/ ">Parking &amp; Maps</a>
# Broken link found in 'Navigation' section: https://www.utep.edu/vpba/parking-and-transportation/%20
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [08:03<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [03:07<01:00,  1.67it/s]
# https://utep.edu/engineering
# None
# Broken link found in 'Unknown' section: https://utep.edu/engineering%20
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [08:04<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [03:09<01:00,  1.67it/s]
# https://utep.edu/engineering
# None
# Broken link found in 'Unknown' section: https://utep.edu/engineering%20%20%20%20%20
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [08:05<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [03:09<01:00,  1.67it/s]
# https://utep.edu/engineering/student-resources
# None
# Broken link found in 'Unknown' section: https://utep.edu/engineering/student-resources%20%20%20%20%20
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [08:07<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [03:11<01:00,  1.67it/s]
# https://utep.edu/engineering
# None
# Duplicate broken link found: https://utep.edu/engineering%20%20%20%20%20
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [08:08<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [03:12<01:00,  1.67it/s]
# https://utep.edu/engineering/student-resources
# None
# Duplicate broken link found: https://utep.edu/engineering/student-resources%20%20%20%20%20
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [08:10<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [03:15<01:00,  1.67it/s]
# https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# <a href="https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html" rel="noopener" target="_blank">Office of Student Life Web page</a>
# Broken link found in 'Main Content' section: https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [08:28<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [03:32<01:00,  1.67it/s]
# https://www.youtube.com/user/UTEPengineering
# <a class="youtube" href="https://www.youtube.com/user/UTEPengineering " target="_blank"><img alt="youtube" src="../../_colleges-cascade-files/images/youTube.png" title="youtube"/></a>
# Broken link found in 'Main Content' section: https://www.youtube.com/user/UTEPengineering%20
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [08:29<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [03:33<01:00,  1.67it/s]
# https://www.instagram.com/engineeringutep/
# <a class="instagram" href="https://www.instagram.com/engineeringutep/ " target="_blank"><img alt="instagram" src="../../_colleges-cascade-files/images/instagram.png" title="instagram"/></a>
# Broken link found in 'Main Content' section: https://www.instagram.com/engineeringutep/%20
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [08:35<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [03:40<01:00,  1.67it/s]
# Invalid URL: http://sao.fraud.state.tx.us/
# Page Progress (2/2):   0%|          | 0/142 [00:00<?, ?it/s]
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [08:57<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [04:01<01:00,  1.67it/s]
# https://www.utep.edu/engineering/research/research-centers.html
# None
# Broken link found in 'Unknown' section: https://www.utep.edu/engineering/research/research-centers.html
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [09:01<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [04:05<01:00,  1.67it/s]
# https://www.utep.edu/engineering/student-resources/student-resources-advising.html
# None
# Broken link found in 'Unknown' section: https://www.utep.edu/engineering/student-resources/student-resources-advising.html
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [09:08<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [04:12<01:00,  1.67it/s]
# https://www.utep.edu/engineering/academic-programs/k12-outreach/k12-outreach.html
# None
# Broken link found in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/k12-outreach.html
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [09:09<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [04:13<01:00,  1.67it/s]
# https://www.utep.edu/engineering/academic-programs/k12-outreach/ambassadors.html
# None
# Broken link found in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/ambassadors.html
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [09:10<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [04:14<01:00,  1.67it/s]
# https://www.utep.edu/engineering/academic-programs/k12-outreach/aspiration-in-computing.html
# None
# Broken link found in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/aspiration-in-computing.html
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [09:11<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [04:15<01:00,  1.67it/s]
# https://www.utep.edu/engineering/academic-programs/k12-outreach/e-week.html
# None
# Broken link found in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/e-week.html
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [09:12<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [04:16<01:00,  1.67it/s]
# https://www.utep.edu/engineering/academic-programs/k12-outreach/excites.html
# None
# Broken link found in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/excites.html
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [09:13<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [04:17<01:00,  1.67it/s]
# https://www.utep.edu/engineering/academic-programs/k12-outreach/more-outreach.html
# None
# Broken link found in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/more-outreach.html
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [09:14<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [04:18<01:00,  1.67it/s]
# https://www.utep.edu/engineering/academic-programs/k12-outreach/nexus.html
# None
# Broken link found in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/nexus.html
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [09:15<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [04:19<01:00,  1.67it/s]
# https://www.utep.edu/engineering/academic-programs/k12-outreach/robotics.html
# None
# Broken link found in 'Unknown' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/robotics.html
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [09:17<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [04:21<01:00,  1.67it/s]
# https://www.utep.edu/engineering/alumni/membership-levels.html
# None
# Broken link found in 'Unknown' section: https://www.utep.edu/engineering/alumni/membership-levels.html
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [09:29<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [04:33<01:00,  1.67it/s]
# https://www.utep.edu/vpba/parking-and-transportation/
# <a href="https://www.utep.edu/vpba/parking-and-transportation/ ">Parking &amp; Maps</a>
# Broken link found in 'Navigation' section: https://www.utep.edu/vpba/parking-and-transportation/%20
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [09:35<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [04:39<01:00,  1.67it/s]
# https://www.utep.edu/engineering
# None
# Broken link found in 'Unknown' section: https://www.utep.edu/engineering%20
#
#
#
# Page Progress (1/2):  44%|██████████████████▏                      | 51/115 [09:36<01:09,  1.09s/it]
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [04:41<01:00,  1.67it/s]
# https://www.utep.edu/engineering
# None
# Broken link found in 'Unknown' section: https://www.utep.edu/engineering%20%20%20%20%20
#
#
#
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [04:42<01:00,  1.67it/s]
# https://www.utep.edu/engineering/student-resources
# None
# Broken link found in 'Unknown' section: https://www.utep.edu/engineering/student-resources%20%20%20%20%20
#
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [04:44<01:00,  1.67it/s]
# https://www.utep.edu/engineering
# None
# Duplicate broken link found: https://www.utep.edu/engineering%20%20%20%20%20
#
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [04:44<01:00,  1.67it/s]
# https://www.utep.edu/engineering/student-resources
# None
# Duplicate broken link found: https://www.utep.edu/engineering/student-resources%20%20%20%20%20
#
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [04:47<01:00,  1.67it/s]
# http://www.ll.mit.edu/college/summerprogram.html.
# <a href="http://www.ll.mit.edu/college/summerprogram.html." rel="noopener noreferrer" target="_blank">here</a>
# Broken link found in 'Main Content' section: http://www.ll.mit.edu/college/summerprogram.html.
#
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [04:51<01:00,  1.67it/s]
# http://sa.utep.edu/careers/employers-on-campus
# <a href="http://sa.utep.edu/careers/employers-on-campus" rel="noopener noreferrer" target="_blank">Spring 2017 Employer Recruitment Calendar:</a>
# Broken link found in 'Main Content' section: http://sa.utep.edu/careers/employers-on-campus
#
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [04:54<01:00,  1.67it/s]
# http://www.utsystem.edu/seekut/Terms.htm
# <a href="http://www.utsystem.edu/seekut/Terms.htm" rel="noopener noreferrer" target="_blank">Future Salary as a UTEP Grad!</a>
# Broken link found in 'Main Content' section: https://www.utsystem.edu/seekut/Terms.htm
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[91], line 142
#     140 if __name__ == "__main__":
#     141     excel_file_path = "example.xlsx"
# --> 142     broken_links_report = check_broken_links(excel_file_path)
#     144     if broken_links_report:
#     145         print("Broken Links Report:")
#
# Cell In[91], line 95, in check_broken_links(excel_file)
#      93 if is_valid_link(page_link):
#      94     absolute_link = urljoin(link, page_link)
# ---> 95     final_url = get_final_url(absolute_link)
#      96     if final_url is not None:
#      97         try:
#
# Cell In[91], line 11, in get_final_url(url)
#       9 def get_final_url(url):
#      10     try:
# ---> 11         response = requests.get(url, allow_redirects=True)
#      12         return response.url
#      13     except requests.exceptions.RequestException:
#
# File ~\anaconda3\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:723, in Session.send(self, request, **kwargs)
#     720 if allow_redirects:
#     721     # Redirect resolving generator.
#     722     gen = self.resolve_redirects(r, request, **kwargs)
# --> 723     history = [resp for resp in gen]
#     724 else:
#     725     history = []
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:723, in <listcomp>(.0)
#     720 if allow_redirects:
#     721     # Redirect resolving generator.
#     722     gen = self.resolve_redirects(r, request, **kwargs)
# --> 723     history = [resp for resp in gen]
#     724 else:
#     725     history = []
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:266, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 266     resp = self.send(
#     267         req,
#     268         stream=stream,
#     269         timeout=timeout,
#     270         verify=verify,
#     271         cert=cert,
#     272         proxies=proxies,
#     273         allow_redirects=False,
#     274         **adapter_kwargs,
#     275     )
#     277     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     279     # extract redirect url, if any, for the next loop
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\anaconda3\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~\anaconda3\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~\anaconda3\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\anaconda3\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\anaconda3\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~\anaconda3\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import openpyxl
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, unquote
from tqdm.notebook import tqdm
import csv

def get_final_url(url):
    try:
        response = requests.get(url, allow_redirects=True)
        return response.url
    except requests.exceptions.RequestException:
        return None

def clean_link(link):
    if link and not link.startswith("mailto:") and not link.startswith("#"):
        link = unquote(link).strip()
        if link.endswith("%20"):
            link = link[:-3]  # Remove trailing %20 if it exists
        return link
    return None

def get_links_from_page(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            links = [clean_link(link.get('href')) for link in soup.find_all('a', href=True)]
            return [link for link in links if link is not None]  # Filter out None values
        else:
            return []
    except requests.exceptions.RequestException:
        return []

def identify_section(link, page_link):
    try:
        absolute_page_link = urljoin(link, page_link)
        response = requests.get(link)
        print(page_link)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            # Search for partial matches of the href attribute with page_link
            element = soup.find('a', href=lambda href: page_link in href)
            print(element)
            if element:
                # Search for the outer elements to determine the section
                nav_element = element.find_parent('nav')
                if nav_element:
                    return "Navigation"
                
                footer_element = element.find_parent('footer')
                if footer_element:
                    return "Footer"
                
                sidr_container_element = element.find_parent('div', id='sidr-container')
                if sidr_container_element:
                    return "Main Content"
            return "Unknown"  # If the element is not found in any of the relevant outer elements
        else:
            return "Unknown"  # If there was an issue fetching the page
    except requests.exceptions.RequestException:
        return "Unknown"  # If there was a connection error or other issues



def check_broken_links(excel_file):
    try:
        print(f"Opening file: {excel_file}...")
        wb = openpyxl.load_workbook(excel_file)
        sheet = wb.active
        column_with_links = 'A'

        broken_links_report = []
        invalid_links_report = []
        total_links_checked = 0
        total_links = 0

        for cell in sheet[column_with_links]:
            if cell.value:
                total_links += 1

        print(f"Checking {total_links} links inside {excel_file}...")
        for cell in tqdm(sheet[column_with_links], total=total_links, desc="Progress"):
            if cell.value:
                link = cell.value
                total_links_checked += 1
                page_links = get_links_from_page(link)

                # Page progress bar starts here
                page_progress_desc = f"Page Progress ({total_links_checked}/{total_links})"
                with tqdm(total=len(page_links), desc=page_progress_desc, leave=False) as page_progress:
                    for page_link in page_links:
                        if is_valid_link(page_link):
                            absolute_link = urljoin(link, page_link)
                            final_url = get_final_url(absolute_link)
                            if final_url is not None:
                                try:
                                    response = requests.get(final_url)
                                    if response.status_code != 200:
                                        section = identify_section(link, page_link)  # Pass both link and page_link
                                        if (link, final_url, section, page_link) not in broken_links_report:  # Check for duplicates
                                            broken_links_report.append((link, final_url, section, page_link))
                                            tqdm.write(f"Broken link found on page '{link}' in '{section}' section: {final_url}", end='\r')
                                        else:
                                            tqdm.write(f"Duplicate broken link found on page '{link}': {final_url}", end='\r')
                                    else:
                                        pass  # No need for this message
                                except requests.exceptions.RequestException:
                                    section = identify_section(link, page_link)  # Pass both link and page_link
                                    if (link, final_url, section, page_link) not in broken_links_report:  # Check for duplicates
                                        broken_links_report.append((link, final_url, section, page_link))
                                        tqdm.write(f"Connection error occurred for link on page '{link}' in '{section}' section: {final_url}", end='\r')
                                    else:
                                        tqdm.write(f"Duplicate connection error occurred for link on page '{link}': {final_url}", end='\r')
                            else:
                                invalid_links_report.append((link, absolute_link))
                                tqdm.write(f"Invalid URL: {absolute_link}", end='\r')
                            page_progress.update(1)

        print(f"\nTotal pages checked: {total_links_checked}")
        print(f"Total broken links found: {len(broken_links_report)}")
        print(f"Total invalid links found: {len(invalid_links_report)}")
        return broken_links_report, invalid_links_report
    except openpyxl.utils.exceptions.InvalidFileException:
        print(f"Error: Unable to open the file '{excel_file}'. Please check if it's a valid Excel file.")
        return [], []
    except Exception as e:
        print(f"Error: An unexpected error occurred while processing the file '{excel_file}': {e}")
        return [], []


def save_to_csv(file_path, data, header):
    with open(file_path, 'w', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(header)
        csv_writer.writerows(data)

if __name__ == "__main__":
    excel_file_path = "example.xlsx"
    broken_links_report, invalid_links_report = check_broken_links(excel_file_path)

    if broken_links_report:
        print("Broken Links Report:")
        for link, page_link, section, relative in broken_links_report:
            print(f"Broken Link on page '{link}' in '{section}' section: {page_link}, relative: {relative}")

        # Save broken links report to CSV
        csv_file_path = "broken_links_report.csv"
        header = ["Page", "Broken Link", "Section"]
        save_to_csv(csv_file_path, broken_links_report, header)
        print(f"Broken links report saved to '{csv_file_path}'")
    else:
        print("No broken links found.")

    if invalid_links_report:
        print("Invalid Links Report:")
        for link, page_link in invalid_links_report:
            print(f"Invalid Link on page '{link}': {page_link}")

        # Save invalid links report to CSV
        csv_file_path = "invalid_links_report.csv"
        header = ["Page", "Invalid Link"]
        save_to_csv(csv_file_path, invalid_links_report, header)
        print(f"Invalid links report saved to '{csv_file_path}'")
    else:
        print("No invalid links found.")
# Out:
# Opening file: example.xlsx...
# Checking 2 links inside example.xlsx...
# Progress:   0%|          | 0/2 [00:00<?, ?it/s]
# Page Progress (1/2):   0%|          | 0/115 [00:00<?, ?it/s]
#
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [10:33<01:00,  1.67it/s]
# /engineering/student-resources
# <a href="http://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html">            Tutoring
#     </a>
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html' in 'Navigation' section: https://www.utep.edu/engineering/student-resources/
#
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [10:36<01:00,  1.67it/s]
# /engineering/student-resources
# <a href="http://www.utep.edu/engineering/student-resources/student-resources-aces-tutoring.html">            Tutoring
#     </a>
# Duplicate broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html': https://www.utep.edu/engineering/student-resources/
#
#
# Page Progress (1/2):  12%|████▉                                    | 14/115 [10:38<01:00,  1.67it/s]
# https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# <a href="https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html" rel="noopener" target="_blank">Office of Student Life Web page</a>
# Broken link found on page 'https://utep.edu/engineering/student-resources/feedback.html' in 'Main Content' section: https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[93], line 140
#     138 if __name__ == "__main__":
#     139     excel_file_path = "example.xlsx"
# --> 140     broken_links_report, invalid_links_report = check_broken_links(excel_file_path)
#     142     if broken_links_report:
#     143         print("Broken Links Report:")
#
# Cell In[93], line 95, in check_broken_links(excel_file)
#      93 if is_valid_link(page_link):
#      94     absolute_link = urljoin(link, page_link)
# ---> 95     final_url = get_final_url(absolute_link)
#      96     if final_url is not None:
#      97         try:
#
# Cell In[93], line 10, in get_final_url(url)
#       8 def get_final_url(url):
#       9     try:
# ---> 10         response = requests.get(url, allow_redirects=True)
#      11         return response.url
#      12     except requests.exceptions.RequestException:
#
# File ~\anaconda3\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\anaconda3\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\anaconda3\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~\anaconda3\lib\site-packages\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File ~\anaconda3\lib\site-packages\urllib3\connection.py:414, in HTTPSConnection.connect(self)
#     405 if (
#     406     not self.ca_certs
#     407     and not self.ca_cert_dir
#    (...)
#     410     and hasattr(context, "load_default_certs")
#     411 ):
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#     430 if (
#     431     default_ssl_context
#     432     and self.ssl_version is None
#     433     and hasattr(self.sock, "version")
#     434     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     435 ):
#
# File ~\anaconda3\lib\site-packages\urllib3\util\ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File ~\anaconda3\lib\site-packages\urllib3\util\ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File ~\anaconda3\lib\ssl.py:513, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     507 def wrap_socket(self, sock, server_side=False,
#     508                 do_handshake_on_connect=True,
#     509                 suppress_ragged_eofs=True,
#     510                 server_hostname=None, session=None):
#     511     # SSLSocket class handles server_hostname encoding before it calls
#     512     # ctx._wrap_socket()
# --> 513     return self.sslsocket_class._create(
#     514         sock=sock,
#     515         server_side=server_side,
#     516         do_handshake_on_connect=do_handshake_on_connect,
#     517         suppress_ragged_eofs=suppress_ragged_eofs,
#     518         server_hostname=server_hostname,
#     519         context=self,
#     520         session=session
#     521     )
#
# File ~\anaconda3\lib\ssl.py:1071, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1068         if timeout == 0.0:
#    1069             # non-blocking
#    1070             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1071         self.do_handshake()
#    1072 except (OSError, ValueError):
#    1073     self.close()
#
# File ~\anaconda3\lib\ssl.py:1342, in SSLSocket.do_handshake(self, block)
#    1340     if timeout == 0.0 and block:
#    1341         self.settimeout(None)
# -> 1342     self._sslobj.do_handshake()
#    1343 finally:
#    1344     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
import openpyxl
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, unquote
from tqdm.notebook import tqdm
import csv

def get_final_url(url):
    try:
        response = requests.get(url, allow_redirects=True)
        return response.url
    except requests.exceptions.RequestException:
        return None

def clean_link(link):
    if link and not link.startswith("mailto:") and not link.startswith("#"):
        link = unquote(link).strip()
        if link.endswith("%20"):
            link = link[:-3]  # Remove trailing %20 if it exists
        return link
    return None

def get_links_from_page(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            links = [clean_link(link.get('href')) for link in soup.find_all('a', href=True)]
            return [link for link in links if link is not None]  # Filter out None values
        else:
            return []
    except requests.exceptions.RequestException:
        return []

def identify_section(link, page_link):
    try:
        absolute_page_link = urljoin(link, page_link)
        response = requests.get(link)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            # Search for partial matches of the href attribute with page_link
            element = soup.find('a', href=lambda href: page_link in href)
            if element:
                # Search for the outer elements to determine the section
                nav_element = element.find_parent('nav')
                if nav_element:
                    return "Navigation"
                
                footer_element = element.find_parent('footer')
                if footer_element:
                    return "Footer"
                
                sidr_container_element = element.find_parent('div', id='sidr-container')
                if sidr_container_element:
                    return "Main Content"
            return "Unknown"  # If the element is not found in any of the relevant outer elements
        else:
            return "Unknown"  # If there was an issue fetching the page
    except requests.exceptions.RequestException:
        return "Unknown"  # If there was a connection error or other issues

def check_broken_links(excel_file):
    try:
        print(f"Opening file: {excel_file}...")
        wb = openpyxl.load_workbook(excel_file)
        sheet = wb.active
        column_with_links = 'A'

        broken_links_report = []
        total_links_checked = 0
        total_links = 0

        for cell in sheet[column_with_links]:
            if cell.value:
                total_links += 1

        print(f"Checking {total_links} links inside {excel_file}...")
        for cell in tqdm(sheet[column_with_links], total=total_links, desc="Progress"):
            if cell.value:
                link = cell.value
                total_links_checked += 1
                page_links = get_links_from_page(link)

                # Page progress bar starts here
                page_progress_desc = f"Page Progress ({total_links_checked}/{total_links})"
                with tqdm(total=len(page_links), desc=page_progress_desc, leave=False) as page_progress:
                    for page_link in page_links:
                        if is_valid_link(page_link):
                            absolute_link = urljoin(link, page_link)
                            final_url = get_final_url(absolute_link)
                            if final_url is not None:
                                try:
                                    response = requests.get(final_url)
                                    if response.status_code != 200:
                                        section = identify_section(link, page_link)  # Pass both link and page_link
                                        if (link, final_url, section) not in broken_links_report:  # Check for duplicates
                                            broken_links_report.append((link, final_url, section))
                                            tqdm.write(f"Broken link found on page '{link}' in '{section}' section: {final_url}", end='\r')
                                        else:
                                            tqdm.write(f"Duplicate broken link found on page '{link}': {final_url}", end='\r')
                                    else:
                                        pass  # No need for this message
                                except requests.exceptions.RequestException:
                                    section = identify_section(link, page_link)  # Pass both link and page_link
                                    if (link, final_url, section) not in broken_links_report:  # Check for duplicates
                                        broken_links_report.append((link, final_url, section))
                                        tqdm.write(f"Connection error occurred for link on page '{link}' in '{section}' section: {final_url}", end='\r')
                                    else:
                                        tqdm.write(f"Duplicate connection error occurred for link on page '{link}': {final_url}", end='\r')
                            else:
                                broken_links_report.append((link, page_link, "Invalid URL"))
                                tqdm.write(f"Invalid URL: {absolute_link}", end='\r')
                            page_progress.update(1)

        print(f"\nTotal pages checked: {total_links_checked}")
        print(f"Total broken links found: {len(broken_links_report)}")
        return broken_links_report
    except openpyxl.utils.exceptions.InvalidFileException:
        print(f"Error: Unable to open the file '{excel_file}'. Please check if it's a valid Excel file.")
        return []
    except Exception as e:
        print(f"Error: An unexpected error occurred while processing the file '{excel_file}': {e}")
        return []

# %%
import openpyxl
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, unquote
from tqdm.notebook import tqdm
import csv

def get_final_url(url):
    try:
        response = requests.get(url, allow_redirects=True)
        return response.url
    except requests.exceptions.RequestException:
        return None

def clean_link(link):
    if link and not link.startswith("mailto:") and not link.startswith("#"):
        link = unquote(link).strip()
        if link.endswith("%20"):
            link = link[:-3]  # Remove trailing %20 if it exists
        return link
    return None

def get_links_from_page(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            links = [clean_link(link.get('href')) for link in soup.find_all('a', href=True)]
            return [link for link in links if link is not None]  # Filter out None values
        else:
            return []
    except requests.exceptions.RequestException:
        return []

def identify_section(link, page_link):
    try:
        absolute_page_link = urljoin(link, page_link)
        response = requests.get(link)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            # Search for partial matches of the href attribute with page_link
            element = soup.find('a', href=lambda href: page_link in href)
            if element:
                # Search for the outer elements to determine the section
                nav_element = element.find_parent('nav')
                if nav_element:
                    return "Navigation"
                
                footer_element = element.find_parent('footer')
                if footer_element:
                    return "Footer"
                
                sidr_container_element = element.find_parent('div', id='sidr-container')
                if sidr_container_element:
                    return "Main Content"
            return "Unknown"  # If the element is not found in any of the relevant outer elements
        else:
            return "Unknown"  # If there was an issue fetching the page
    except requests.exceptions.RequestException:
        return "Unknown"  # If there was a connection error or other issues



def check_broken_links(excel_file):
    try:
        print(f"Opening file: {excel_file}...")
        wb = openpyxl.load_workbook(excel_file)
        sheet = wb.active
        column_with_links = 'A'

        broken_links_report = []
        total_links_checked = 0
        total_links = 0

        for cell in sheet[column_with_links]:
            if cell.value:
                total_links += 1

        print(f"Checking {total_links} links inside {excel_file}...")
        for cell in tqdm(sheet[column_with_links], total=total_links, desc="Progress"):
            if cell.value:
                link = cell.value
                total_links_checked += 1
                page_links = get_links_from_page(link)

                # Page progress bar starts here
                page_progress_desc = f"Page Progress ({total_links_checked}/{total_links})"
                with tqdm(total=len(page_links), desc=page_progress_desc, leave=False) as page_progress:
                    for page_link in page_links:
                        absolute_link = urljoin(link, page_link)
                        final_url = get_final_url(absolute_link)
                        section = identify_section(link, page_link)  # Pass both link and page_link
                        if final_url is not None:
                            try:
                                response = requests.get(final_url)
                                if response.status_code != 200:
                                    if (link, final_url, section, page_link) not in broken_links_report:  # Check for duplicates
                                        broken_links_report.append((link, final_url, section, page_link))
                                        tqdm.write(f"Broken link found on page '{link}' in '{section}' section: {final_url}", end='\r')
                                    else:
                                        tqdm.write(f"Duplicate broken link found on page '{link}': {final_url}", end='\r')
                                else:
                                    pass  # No need for this message
                            except requests.exceptions.RequestException:
                                if (link, final_url, section, page_link) not in broken_links_report:  # Check for duplicates
                                    broken_links_report.append((link, final_url, section, page_link))
                                    tqdm.write(f"Connection error occurred for link on page '{link}' in '{section}' section: {final_url}", end='\r')
                                else:
                                    tqdm.write(f"Duplicate connection error occurred for link on page '{link}': {final_url}", end='\r')
                        else:
                            # Include invalid links in the broken links report
                            broken_links_report.append((link, page_link, section, "Invalid URL"))
                            tqdm.write(f"Invalid URL: {absolute_link}", end='\r')
                        page_progress.update(1)

        print(f"\nTotal pages checked: {total_links_checked}")
        print(f"Total broken links found: {len(broken_links_report)}")
        return broken_links_report
    except openpyxl.utils.exceptions.InvalidFileException:
        print(f"Error: Unable to open the file '{excel_file}'. Please check if it's a valid Excel file.")
        return []
    except Exception as e:
        print(f"Error: An unexpected error occurred while processing the file '{excel_file}': {e}")
        return []


def save_to_csv(file_path, data, header):
    with open(file_path, 'w', newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(header)
        csv_writer.writerows(data)

if __name__ == "__main__":
    excel_file_path = "example.xlsx"
    broken_links_report = check_broken_links(excel_file_path)

    if broken_links_report:
        print("Broken Links Report:")
        for link, page_link, section, relative in broken_links_report:
            print(f"Broken Link on page '{link}' in '{section}' section: {page_link}, relative: {relative}")

        # Save broken links report to CSV
        csv_file_path = "broken_links_report.csv"
        header = ["Page", "Broken Link", "Section"]
        save_to_csv(csv_file_path, broken_links_report, header)
        print(f"Broken links report saved to '{csv_file_path}'")
    else:
        print("No broken links found.")
# Out:
# Opening file: example.xlsx...
# Checking 2 links inside example.xlsx...
# Progress:   0%|          | 0/2 [00:00<?, ?it/s]
# Page Progress (1/2):   0%|          | 0/115 [00:00<?, ?it/s]
# Invalid URL: http://sao.fraud.state.tx.us/u/engineering/student-resources/feedback.html' in 'Main Content' section: https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Page Progress (2/2):   0%|          | 0/128 [00:00<?, ?it/s]
# Invalid URL: http://sao.fraud.state.tx.us/p.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/student-resources/student-resources-tutoring.html-faqs.htmlml
# Total pages checked: 2
# Total broken links found: 26
# Broken Links Report:
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html' in 'Navigation' section: https://www.utep.edu/engineering/student-resources/, relative: /engineering/student-resources
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html' in 'Main Content' section: https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html, relative: https://www.utep.edu/student-affairs/dean-of-students-office/academic-support/grade-grievance.html
# Broken Link on page 'https://utep.edu/engineering/student-resources/feedback.html' in 'Footer' section: http://sao.fraud.state.tx.us/, relative: Invalid URL
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/research/research-centers.html, relative: ../research/research-centers.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/student-resources/student-resources-advising.html, relative: student-resources-advising.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/k12-outreach.html, relative: ../academic-programs/k12-outreach/k12-outreach.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/ambassadors.html, relative: ../academic-programs/k12-outreach/ambassadors.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/aspiration-in-computing.html, relative: ../academic-programs/k12-outreach/aspiration-in-computing.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/e-week.html, relative: ../academic-programs/k12-outreach/e-week.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/excites.html, relative: ../academic-programs/k12-outreach/excites.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/more-outreach.html, relative: ../academic-programs/k12-outreach/more-outreach.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/nexus.html, relative: ../academic-programs/k12-outreach/nexus.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/academic-programs/k12-outreach/robotics.html, relative: ../academic-programs/k12-outreach/robotics.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/alumni/membership-levels.html, relative: ../alumni/membership-levels.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/student-resources/, relative: /engineering/student-resources
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: http://www.ll.mit.edu/college/summerprogram.html., relative: http://www.ll.mit.edu/college/summerprogram.html.
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: http://sa.utep.edu/careers/employers-on-campus, relative: http://sa.utep.edu/careers/employers-on-campus
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: https://www.utsystem.edu/seekut/Terms.htm, relative: http://www.utsystem.edu/seekut/Terms.htm
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: http://sa.utep.edu/careers/students/sample-documents, relative: http://sa.utep.edu/careers/students/sample-documents
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: https://www.utep.edu/engineering/student-resources/student-employment, relative: /engineering/student-resources/student-employment
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: http://science.utep.edu/nsf-prem/, relative: Invalid URL
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Main Content' section: http://etc.utep.edu/index.htm, relative: http://etc.utep.edu/index.htm
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/student-resources/student-resources-advising-orientation.html, relative: student-resources-advising-orientation.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/student-resources/student-resources-ug-admissions-faqs.html, relative: student-resources-ug-admissions-faqs.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Navigation' section: https://www.utep.edu/engineering/student-resources/student-resources-tutoring.html, relative: student-resources-tutoring.html
# Broken Link on page 'https://www.utep.edu/engineering/student-resources/student-resources.html' in 'Footer' section: http://sao.fraud.state.tx.us/, relative: Invalid URL
# Broken links report saved to 'broken_links_report.csv'

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import time
from selenium_stealth import stealth

start_time = time.time()

options = webdriver.ChromeOptions()
options.add_argument("start-maximized")
options.add_argument("--headless")
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)

# Specify the path to the ChromeDriver executable
chrome_driver_path = "C:\\Users\\Ricar\\Desktop\\chromedriver\\chromedriver.exe"


# Create a Service instance
service = Service(chrome_driver_path)

# Create a Chrome WebDriver instance with the provided Service instance
driver = webdriver.Chrome(options=options, service=service)

stealth(driver,
        languages=["en-US", "en"],
        vendor="Google Inc.",
        platform="Win32",
        webgl_vendor="Intel Inc.",
        renderer="Intel Iris OpenGL Engine",
        fix_hairline=True,
        )

url = "https://learnwithhasan.com"  # change the url

driver.get(url)

driver.save_screenshot("test3.png")  # change image name

elapsed = "%s seconds" % (time.time() - start_time)

print("Done in " + elapsed)
# Out:
# Done in 5.616404294967651 seconds

# %%
##WORKIIIIIIIIIIIING

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from PIL import Image
import io
import base64
import time

# Initialize WebDriver and navigate to the webpage
driver = webdriver.Chrome()
driver.get("https://en.wikipedia.org/wiki/Python_(programming_language)")

# Search for the word within the page
search_word = "Godot"

# Define a variable to keep track of previous scroll height
prev_scroll_height = 0

# Scroll loop
while True:
    try:
        element = driver.find_element(By.XPATH, f"//*[contains(text(), '{search_word}')]")
        
        # Scroll the element into view using JavaScript
        driver.execute_script("arguments[0].scrollIntoView();", element)
        
        # Give some time for the page to adjust after scrolling
        time.sleep(1)
        
        # Scroll a bit more to ensure proper visibility
        driver.execute_script("window.scrollBy(0, -100);")
        
        # Take a screenshot of the entire page
        screenshot_base64 = driver.get_screenshot_as_base64()
        
        # Convert the base64-encoded screenshot to a PIL Image
        screenshot_bytes = base64.b64decode(screenshot_base64)
        pil_image = Image.open(io.BytesIO(screenshot_bytes))
        
        # Save the screenshot
        pil_image.save("element_screenshot.png")
        
        print("Element found and screenshot captured.")
        break
    except NoSuchElementException:
        print("Element not found. Scrolling...")
        
    # Get the current scroll height
    scroll_height = driver.execute_script("return document.body.scrollHeight")
    
    # Scroll down
    driver.find_element(By.TAG_NAME, "body").send_keys(Keys.END)
    
    # Give some time for content to load (you may need to adjust this)
    time.sleep(2)
    
    # Check if you've reached the end
    if scroll_height == prev_scroll_height:
        print("Reached the end of the page.")
        break
    
    # Update the previous scroll height
    prev_scroll_height = scroll_height

# Close the WebDriver
driver.quit()
# Out:
# Element found and screenshot captured.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from PIL import Image
import time

# Initialize WebDriver and navigate to the webpage
driver = webdriver.Chrome()
driver.get("https://www.utep.edu/engineering/student-resources/student-resources.html")

# Search for the sequence of tabs/dropdowns
search_sequence = "About/Administration"

# Split the sequence into individual steps
clicks = search_sequence.split('/')
search_word = clicks[-1]  # The last element in the sequence
time.sleep(2)
# Loop through the clicks
while clicks:
    
    click = clicks.pop(0)  # Get the next click from the list
    try:
        # Find and click on the tab or dropdown element
        click_element = driver.find_element(By.XPATH, f"//*[contains(text(), '{click}')]")
        click_element.click()
        time.sleep(2)  # Give time for the content to load
    except NoSuchElementException:
        print(f"Element '{click}' not found. Moving to the next step.")

# Define a variable to keep track of previous scroll height
prev_scroll_height = 0

# Scroll loop
while True:
    try:
        
        element = driver.find_element(By.XPATH, f"//*[contains(text(), '{search_word}')]")
        
        # Scroll the element into view using JavaScript
        driver.execute_script("arguments[0].scrollIntoView();", element)
        
        # Give some time for the page to adjust after scrolling
        time.sleep(1)
        
        # Scroll a bit more to ensure proper visibility
        driver.execute_script("window.scrollBy(0, -100);")
        
        # Take a screenshot of the element
        screenshot = element.screenshot_as_png
        
        # Convert the screenshot to a PIL Image
        pil_image = Image.open(io.BytesIO(screenshot))
        
        # Save the screenshot
        pil_image.save("element_screenshot.png")
        
        print("Element found and screenshot captured.")
        break
    except NoSuchElementException:
        print("Element not found. Scrolling...")
        
    # Get the current scroll height
    scroll_height = driver.execute_script("return document.body.scrollHeight")
    
    # Scroll down
    driver.find_element(By.TAG_NAME, "body").send_keys(Keys.END)
    
    # Give some time for content to load (you may need to adjust this)
    time.sleep(2)
    
    # Check if you've reached the end
    if scroll_height == prev_scroll_height:
        print("Reached the end of the page.")
        break
    
    # Update the previous scroll height
    prev_scroll_height = scroll_height

# Close the WebDriver
driver.quit()
# Out:
# Element found and screenshot captured.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from PIL import Image
import time

# Initialize WebDriver and navigate to the webpage
driver = webdriver.Chrome()
driver.get("https://www.utep.edu/engineering/student-resources/student-resources.html")

# Search for the sequence of tabs/dropdowns
search_sequence = "About/Administration"

# Split the sequence into individual steps
clicks = search_sequence.split('/')
search_word = clicks[-1]  # The last element in the sequence
time.sleep(2)
           
# Loop through the clicks, excluding the last one
while len(clicks) > 1:  # Exclude the last element
    click = clicks.pop(0)  # Get the next click from the list
    try:
        # Find and click on the tab or dropdown element
        click_element = driver.find_element(By.XPATH, f"//*[contains(text(), '{click}')]")
        click_element.click()
        time.sleep(3)  # Give time for the content to load
    except NoSuchElementException:
        print(f"Element '{click}' not found. Moving to the next step.")

# Define a variable to keep track of previous scroll height
prev_scroll_height = 0

# Scroll loop
while True:
    try:
        print(search_word)
        time.sleep(2)
        
        element = driver.find_element(By.XPATH, f"//*[contains(text(), '{search_word}')]")
        
        print(element)
        
        # Take a screenshot of the element
        screenshot = element.screenshot_as_png
        
        # Convert the screenshot to a PIL Image
        pil_image = Image.open(io.BytesIO(screenshot))
        
        # Save the screenshot
        pil_image.save("element_screenshot.png")
        
        print("Element found and screenshot captured.")
        break
    except NoSuchElementException:
        
        # Scroll the element into view using JavaScript
        driver.execute_script("arguments[0].scrollIntoView();", element)
        
        # Give some time for the page to adjust after scrolling
        time.sleep(1)
        
        # Scroll a bit more to ensure proper visibility
        driver.execute_script("window.scrollBy(0, -100);")
        
        print("Element not found. Scrolling...")
        
    # Get the current scroll height
    scroll_height = driver.execute_script("return document.body.scrollHeight")
    
    # Scroll down
    driver.find_element(By.TAG_NAME, "body").send_keys(Keys.END)
    
    # Give some time for content to load (you may need to adjust this)
    time.sleep(2)
    
    # Check if you've reached the end
    if scroll_height == prev_scroll_height:
        print("Reached the end of the page.")
        break
    
    # Update the previous scroll height
    prev_scroll_height = scroll_height

# Close the WebDriver
driver.quit()
# Out:
# Administration
# <selenium.webdriver.remote.webelement.WebElement (session="477cb5caad6d45ce66adc2dea434b789", element="E5C6623DF232BC57458C28042C987BC7_element_133")>
# Element found and screenshot captured.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from PIL import Image
import time

# Initialize WebDriver and navigate to the webpage
driver = webdriver.Chrome()
driver.maximize_window()  # Open the WebDriver in full screen mode

driver.get("https://www.utep.edu/engineering/student-resources/student-resources.html")



# Search for the sequence of tabs/dropdowns
search_sequence = "About/Administration"

# Split the sequence into individual steps
clicks = search_sequence.split('/')
search_word = clicks[-1]  # The last element in the sequence

           
# Loop through the clicks, excluding the last one
while len(clicks) > 1:  # Exclude the last element
    click = clicks.pop(0)  # Get the next click from the list
    try:
        # Find and click on the tab or dropdown element
        click_element = driver.find_element(By.XPATH, f"//*[contains(text(), '{click}')]")
        click_element.click()
        time.sleep(1)  # Give time for the content to load
    except NoSuchElementException:
        print(f"Element '{click}' not found. Moving to the next step.")

# Define a variable to keep track of previous scroll height
prev_scroll_height = 0

# Scroll loop
while True:
    try:
        
        element = driver.find_element(By.XPATH, f"//*[contains(text(), '{search_word}')]")
        
        # Scroll the element into view using JavaScript
        driver.execute_script("arguments[0].scrollIntoView();", element)
        
        # Give some time for the page to adjust after scrolling
        time.sleep(1)
        
        # Scroll a bit more to ensure proper visibility
        driver.execute_script("window.scrollBy(0, -100);")
        
        # Take a screenshot of the entire page
        screenshot_base64 = driver.get_screenshot_as_base64()
        
        # Convert the base64-encoded screenshot to a PIL Image
        screenshot_bytes = base64.b64decode(screenshot_base64)
        pil_image = Image.open(io.BytesIO(screenshot_bytes))
        
        # Save the screenshot
        pil_image.save("element_screenshot.png")
        
        print("Screenshot of the entire page captured.")
        break
    except NoSuchElementException:

        
        print("Element not found. Scrolling...")
        
    # Get the current scroll height
    scroll_height = driver.execute_script("return document.body.scrollHeight")
    
    # Scroll down
    driver.find_element(By.TAG_NAME, "body").send_keys(Keys.END)
    
    # Give some time for content to load (you may need to adjust this)
    time.sleep(1)
    
    # Check if you've reached the end
    if scroll_height == prev_scroll_height:
        print("Reached the end of the page.")
        break
    
    # Update the previous scroll height
    prev_scroll_height = scroll_height

# Close the WebDriver
driver.quit()
# Out:
# Screenshot of the entire page captured.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from PIL import Image
import io
import base64
import time

# Initialize WebDriver and navigate to the webpage
driver = webdriver.Chrome()
driver.maximize_window()  # Open the WebDriver in full screen mode

driver.get("https://www.utep.edu/engineering/student-resources/student-resources.html")



# Search for the sequence of tabs/dropdowns
search_sequence = "About/Administration"

# Split the sequence into individual steps
clicks = search_sequence.split('/')
search_word = clicks[-1]  # The last element in the sequence

           
# Loop through the clicks, excluding the last one
while len(clicks) > 1:  # Exclude the last element
    click = clicks.pop(0)  # Get the next click from the list
    try:
        # Find and click on the tab or dropdown element
        click_element = driver.find_element(By.XPATH, f"//*[contains(text(), '{click}')]")
        click_element.click()
        time.sleep(1)  # Give time for the content to load
    except NoSuchElementException:
        print(f"Element '{click}' not found. Moving to the next step.")

# Define a variable to keep track of previous scroll height
prev_scroll_height = 0

# Scroll loop
while True:
    try:
        
        element = driver.find_element(By.XPATH, f"//*[contains(text(), '{search_word}')]")
        
        # Scroll the element into view using JavaScript
        driver.execute_script("arguments[0].scrollIntoView();", element)
        
        # Give some time for the page to adjust after scrolling
        time.sleep(2)
        
        # Scroll a bit more to ensure proper visibility
        driver.execute_script("window.scrollBy(0, -50);")
        
        
         # Get location and size of element
        location = element.location
        size = element.size
        print(location)
        print(size)
        # Define screenshot area around element
        x = location['x'] - 100
        y = location['y'] - 100
        w = size['width'] + 300
        h = size['height'] + 300
        
        # Take a screenshot of the entire page
        screenshot_base64 = driver.get_screenshot_as_base64()
        
        
        # Convert the base64-encoded screenshot to a PIL Image
        screenshot_bytes = base64.b64decode(screenshot_base64)
        pil_image = Image.open(io.BytesIO(screenshot_bytes))
        
        print(pil_image.size)
        
        pil_image.save('element_non_cropped3.png')
        cropped_image = pil_image.crop((x, y, x+w, y+h))
        
        print(cropped_image)
        
        cropped_image.save("element_screenshot3.png")
        
        # Save the screenshot
        pil_image.save("element_screenshot_pil_3.png")
        
        print("Screenshot of the entire page captured.")
        break
    except NoSuchElementException:

        
        print("Element not found. Scrolling...")
        
    # Get the current scroll height
    scroll_height = driver.execute_script("return document.body.scrollHeight")
    
    # Scroll down
    driver.find_element(By.TAG_NAME, "body").send_keys(Keys.END)
    
    # Give some time for content to load (you may need to adjust this)
    time.sleep(1)
    
    # Check if you've reached the end
    if scroll_height == prev_scroll_height:
        print("Reached the end of the page.")
        break
    
    # Update the previous scroll height
    prev_scroll_height = scroll_height

# Close the WebDriver
driver.quit()
# Out:
# {'x': 251, 'y': 139}
# {'height': 26, 'width': 160}
# (1920, 878)
# <PIL.Image.Image image mode=RGBA size=460x326 at 0x1F4A8366410>
# Screenshot of the entire page captured.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from PIL import Image
import io
import base64
import time

# Initialize WebDriver and navigate to the webpage
driver = webdriver.Chrome()
driver.maximize_window()  # Open the WebDriver in full screen mode

driver.get("https://www.utep.edu/engineering/student-resources/student-resources.html")

# Search for the sequence of tabs/dropdowns
search_sequence = "About/Administration"

# Define a variable to keep track of previous scroll height
prev_scroll_height = 0

# Split the sequence into individual steps
clicks = search_sequence.split('/')
search_word = clicks[-1]  # The last element in the sequence

# Loop through the clicks, excluding the last one
while len(clicks) > 1:  # Exclude the last element
    click = clicks.pop(0)  # Get the next click from the list
    try:
        # Find and click on the tab or dropdown element
        click_element = driver.find_element(By.XPATH, f"//*[contains(text(), '{click}')]")
        click_element.click()
        
        # Give some time for the page to adjust after scrolling
        time.sleep(1)
        
        # Scroll a bit more to ensure proper visibility
        driver.execute_script("window.scrollBy(0, -100);")
    except NoSuchElementException:
        print(f"Element '{click}' not found. Moving to the next step.")
        
    # Get the current scroll height
    scroll_height = driver.execute_script("return document.body.scrollHeight")
    
    # Scroll down
    driver.find_element(By.TAG_NAME, "body").send_keys(Keys.END)
    
    # Give some time for content to load (you may need to adjust this)
    time.sleep(2)
    
    # Check if you've reached the end
    if scroll_height == prev_scroll_height:
        print("Reached the end of the page.")
        break
    
    # Update the previous scroll height
    prev_scroll_height = scroll_height

        
# Define a variable to keep track of previous scroll height
prev_scroll_height = 0

# Scroll loop
while True:
    try:
        element = driver.find_element(By.XPATH, f"//*[contains(text(), '{search_word}')]")
        
        # Scroll the element into view using JavaScript
        driver.execute_script("arguments[0].scrollIntoView();", element)
        
        # Give some time for the page to adjust after scrolling
        time.sleep(1)
        
        # Scroll a bit more to ensure proper visibility
        driver.execute_script("window.scrollBy(0, -100);")
        
        # Get location and size of element
        location = element.location
        size = element.size
        
        print(location)
        print(size)
        
        # Define screenshot area around element
        x = location['x'] - 100
        y = location['y'] - 100
        w = size['width'] + 300
        h = size['height'] + 300
        
        # Take a screenshot of the entire page
        screenshot_base64 = driver.get_screenshot_as_base64()
        
        
        # Convert the base64-encoded screenshot to a PIL Image
        screenshot_bytes = base64.b64decode(screenshot_base64)
        pil_image = Image.open(io.BytesIO(screenshot_bytes))
        
        print(pil_image.size)
        
        pil_image.save('element_non_cropped.png')
        cropped_image = pil_image.crop((x, y, x+w, y+h))
        
        print(cropped_image)
        
        cropped_image.save("element_screenshot.png")
        
        # Save the screenshot
        pil_image.save("element_screenshot_pil_.png")
        
        print("Screenshot of the entire page captured.")
        break
    except NoSuchElementException:
        print("Element not found. Scrolling...")
        
    # Get the current scroll height
    scroll_height = driver.execute_script("return document.body.scrollHeight")
    
    # Scroll down
    driver.find_element(By.TAG_NAME, "body").send_keys(Keys.END)
    
    # Give some time for content to load (you may need to adjust this)
    time.sleep(2)
    
    # Check if you've reached the end
    if scroll_height == prev_scroll_height:
        print("Reached the end of the page.")
        break
    
    # Update the previous scroll height
    prev_scroll_height = scroll_height
    
# Close the WebDriver
driver.quit()
# Out:
# (1920, 878)
# <PIL.Image.Image image mode=RGBA size=1229x340 at 0x1F4A92BE320>
# Screenshot of the entire page captured.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from PIL import Image
import io
import base64
import time

# Initialize WebDriver and navigate to the webpage
driver = webdriver.Chrome()
driver.maximize_window()  # Open the WebDriver in full screen mode

driver.get("https://www.utep.edu/engineering/student-resources/student-resources.html")



# Search for the sequence of tabs/dropdowns
search_sequence = "Areagra"

# Split the sequence into individual steps
clicks = search_sequence.split('/')
search_word = clicks[-1]  # The last element in the sequence



# Loop through the clicks, excluding the last one
while len(clicks) > 1:  # Exclude the last element
    click = clicks.pop(0)  # Get the next click from the list
    while True:
        try:
            # Find and click on the tab or dropdown element
            
            click_element = driver.find_element(By.XPATH, f"//*[contains(text(), '{click}')]")
            
             # Scroll the element into view using JavaScript
            driver.execute_script("arguments[0].scrollIntoView();", click_element)

            # Give some time for the page to adjust after scrolling
            time.sleep(1)

            # Scroll a bit more to ensure proper visibility
            driver.execute_script("window.scrollBy(0, -100);")
        
            click_element.click()
            
            break
        except NoSuchElementException:
            print(f"Element '{click}' not found. Moving to the next step.")
            # Get the current scroll height
        scroll_height = driver.execute_script("return document.body.scrollHeight")

        # Scroll down
        driver.find_element(By.TAG_NAME, "body").send_keys(Keys.END)

        # Give some time for content to load (you may need to adjust this)
        time.sleep(2)

        # Check if you've reached the end
        if scroll_height == prev_scroll_height:
            print("Reached the end of the page.")
            break

        # Update the previous scroll height
        prev_scroll_height = scroll_height


# Define a variable to keep track of previous scroll height
prev_scroll_height = 0

# Scroll loop
while True:
    try:
        element = driver.find_element(By.XPATH, f"//*[contains(text(), '{search_word}')]")
        
        # Scroll the element into view using JavaScript
        driver.execute_script("arguments[0].scrollIntoView();", element)
        
        # Give some time for the page to adjust after scrolling
        time.sleep(1)
        
        # Scroll a bit more to ensure proper visibility
        driver.execute_script("window.scrollBy(0, -100);")
        
        # Get location and size of element
        location = element.location
        size = element.size
        
        print(location)
        print(size)
        
        # Define screenshot area around element
        x = location['x'] - 100
        y = location['y'] - 100
        w = size['width'] + 300
        h = size['height'] + 300
        
        screenshot_base64 = driver.get_screenshot_as_base64()
        
        # Convert the base64-encoded screenshot to a PIL Image
        screenshot_bytes = base64.b64decode(screenshot_base64)
        pil_image = Image.open(io.BytesIO(screenshot_bytes))
        
        print(pil_image.size)
        
        pil_image.save('element_non_cropped.png')
        cropped_image = pil_image.crop((x, y, x+w, y+h))
        
        print(cropped_image)
        
        cropped_image.save("element_screenshot.png")
        
        # Save the screenshot
        pil_image.save("element_screenshot_pil.png")
        
        print("Screenshot of the entire page captured.")
        break
    except NoSuchElementException:
        print("Element not found. Scrolling...")
        
    # Get the current scroll height
    scroll_height = driver.execute_script("return document.body.scrollHeight")
    
    # Scroll down
    driver.find_element(By.TAG_NAME, "body").send_keys(Keys.END)
    
    # Give some time for content to load (you may need to adjust this)
    time.sleep(2)
    
    # Check if you've reached the end
    if scroll_height == prev_scroll_height:
        print("Reached the end of the page.")
        break
    
    # Update the previous scroll height
    prev_scroll_height = scroll_height

# Close the WebDriver
driver.quit()
# Out:
# Element not found. Scrolling...
# Element not found. Scrolling...
# Reached the end of the page.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from PIL import Image
import io
import base64
import time

# Initialize WebDriver and navigate to the webpage
driver = webdriver.Chrome()
driver.maximize_window()  # Open the WebDriver in full screen mode

driver.get("https://www.utep.edu/engineering/student-resources/student-resources.html")



# Search for the sequence of tabs/dropdowns
search_sequence = "FAQ's"

# Split the sequence into individual steps
clicks = search_sequence.split('/')
search_word = clicks[-1]  # The last element in the sequence

if "'" in search_word:
    search_word = search_word.split("'")[0]

# Clean up the search_word
search_word = search_word.lstrip(" -,.!?").strip()


# Loop through the clicks, excluding the last one
while len(clicks) > 1:  # Exclude the last element
    click = clicks.pop(0)  # Get the next click from the list
    while True:
        try:
            # Find and click on the tab or dropdown element
            if 'accordion' in click:
                click_element = driver.find_element(By.CSS_SELECTOR, f"a[href='#{click}']")
            else:
                click_element = driver.find_element(By.XPATH, f"//a[contains(text(), '{click}')]")

            #click_element = driver.find_element(By.CSS_SELECTOR, f"a[href='#{target_href}']")
            
            print(click_element)
             # Scroll the element into view using JavaScript
            driver.execute_script("arguments[0].scrollIntoView();", click_element)

            # Give some time for the page to adjust after scrolling
            time.sleep(1)

            # Scroll a bit more to ensure proper visibility
            driver.execute_script("window.scrollBy(0, -400);")
        
            click_element.click()
            
            break
        except NoSuchElementException:
            print(f"Element '{click}' not found. Moving to the next step.")
            # Get the current scroll height
            scroll_height = driver.execute_script("return document.body.scrollHeight")

            # Scroll down
            driver.find_element(By.TAG_NAME, "body").send_keys(Keys.END)

            # Give some time for content to load (you may need to adjust this)
            time.sleep(2)

            # Check if you've reached the end
            if scroll_height == prev_scroll_height:
                print("Reached the end of the page.")
                break

            # Update the previous scroll height
            prev_scroll_height = scroll_height


# Define a variable to keep track of previous scroll height
prev_scroll_height = 0

time.sleep(1)
# Scroll loop
while True:
    try:
        element = driver.find_element(By.XPATH, f"//*[contains(text(), '{search_word}')]")
        
        # Get location and size of element
        location = element.location
        size = element.size
        
        print(location)
        print(size)
        
        
        
        # Scroll a bit more to ensure proper visibility
        driver.execute_script(f"window.scrollBy(0, {location['y']-400});")
        
        # Give some time for the page to adjust after scrolling
        time.sleep(1)
        
        element = driver.find_element(By.XPATH, f"//*[contains(text(), '{search_word}')]")
        
        
        # Give some time for the page to adjust after scrolling
        time.sleep(1)
        
        # Get location and size of element
        location = element.location
        size = element.size
        
        print(location)
        print(size)
        
        # Define screenshot area around element
        y = 300
        h = 600
        
        screenshot_base64 = driver.get_screenshot_as_base64()
        
        # Convert the base64-encoded screenshot to a PIL Image
        screenshot_bytes = base64.b64decode(screenshot_base64)
        pil_image = Image.open(io.BytesIO(screenshot_bytes))
        
        
        pil_image.save('element_non_cropped.png')
        print(pil_image.width)
        cropped_image = pil_image.crop((0, y, pil_image.width, y + h))  # Crop only the specified height

        
        #print(cropped_image)
        
        cropped_image.save("element_screenshot1.png")
        
        # Save the screenshot
        #pil_image.save("element_screenshot_pil1.png")
        
        print("Screenshot of the entire page captured.")
        break
    except NoSuchElementException:
        print("Element not found. Scrolling...")
        
    # Get the current scroll height
    scroll_height = driver.execute_script("return document.body.scrollHeight")
    
    # Scroll down
    driver.find_element(By.TAG_NAME, "body").send_keys(Keys.END)
    
    # Give some time for content to load (you may need to adjust this)
    time.sleep(2)
    
    # Check if you've reached the end
    if scroll_height == prev_scroll_height:
        print("Reached the end of the page.")
        break
    
    # Update the previous scroll height
    prev_scroll_height = scroll_height

# Close the WebDriver
driver.quit()
# Out:
# {'x': 117, 'y': 284}
# {'height': 32, 'width': 261}
# {'x': 117, 'y': 284}
# {'height': 32, 'width': 261}
# 1920
# Screenshot of the entire page captured.

# %%
from docx.shared import RGBColor, Inches, Pt
from docx import Document 
import docx
from concurrent.futures import ThreadPoolExecutor
from docx.oxml.ns import nsdecls
from docx.oxml import parse_xml
from docx.oxml.shared import OxmlElement

# %%
from docx.shared import Pt, RGBColor
from docx import Document
from docx.oxml import OxmlElement

def add_hyperlink(paragraph, url, text):
    run = paragraph.add_run()
    
    hyperlink = OxmlElement('w:hyperlink')
    hyperlink.set('{http://www.w3.org/1999/xlink}href', url)
    
    run._r.append(hyperlink)
    
    new_run = run._r.get_or_add_rPr()

    u = OxmlElement('w:u')
    u.set(docx.oxml.ns.qn('w:val'), 'single')  # 'single' for single underline
    new_run.append(u)

    color = OxmlElement('w:color')
    color.set(docx.oxml.ns.qn('w:val'), '0000FF')  # Blue color as HEX value
    new_run.append(color)

    t = OxmlElement('w:t')
    t.text = text
    run._r.append(t)
    
    return hyperlink

document = Document()
p = document.add_paragraph()
add_hyperlink(p, 'http://www.google.com', 'Google')
document.save('demo.docx')

# %%
from docx import Document
from docx.oxml.ns import nsdecls
from docx.oxml import parse_xml

def add_hyperlink(paragraph, url, text):
    """
    A function that places a hyperlink within a paragraph object.
    :param paragraph: The paragraph we are adding the hyperlink to.
    :param url: A string containing the required url
    :param text: The text displayed for the url
    :return: The hyperlink object
    """
    
    # This gets access to the document.xml.rels file and gets a new relation id value
    part = paragraph.part
    r_id = part.relate_to(url, docx.opc.constants.RELATIONSHIP_TYPE.HYPERLINK, is_external=True)

    # Create the w:hyperlink tag and add needed values
    hyperlink = docx.oxml.shared.OxmlElement('w:hyperlink')
    hyperlink.set(docx.oxml.shared.qn('r:id'), r_id)

    # Create a new w:r element
    new_run = docx.oxml.shared.OxmlElement('w:r')

    # Create a new w:rPr element
    rPr = docx.oxml.shared.OxmlElement('w:rPr')
    
    u = docx.oxml.shared.OxmlElement('w:u')
    u.set(docx.oxml.ns.qn('w:val'), 'single')  # 'single' for single underline
    rPr.append(u)

    color = docx.oxml.shared.OxmlElement('w:color')
    color.set(docx.oxml.ns.qn('w:val'), '0000FF')  # Blue color as HEX value
    rPr.append(color)

    new_run.append(rPr)

    # Join all the xml elements together and add the required text to the w:r element
    t = docx.oxml.shared.OxmlElement('w:t')
    t.text = text
    new_run.append(t)

    hyperlink.append(new_run)

    # Append the hyperlink to the paragraph
    paragraph._p.append(hyperlink)

    return hyperlink

# Create a new document
document = Document()
p = document.add_paragraph()
add_hyperlink(p, 'http://www.google.com', 'Google')
document.save('demo.docx')

# %%
import os
import pandas as pd

# Define the path to the original Excel file
input_excel_path = 'Documents/Excel_Files/education.xlsx'

# Load the Excel file using pandas
df = pd.read_excel(input_excel_path, header=None, names=['Links'])

# Create a dictionary to store links based on folder names
link_dict = {}

# Iterate through each link in the DataFrame
for link in df['Links']:
    parts = link.split('/')
    folder_name = parts[2]  # Assuming the folder name is the third part of the link
    if folder_name not in link_dict:
        link_dict[folder_name] = []
    link_dict[folder_name].append(link)

# Create a new Excel file for each folder
output_folder = 'Documents/Excel_Files'
os.makedirs(output_folder, exist_ok=True)

for folder_name, links in link_dict.items():
    output_excel_path = os.path.join(output_folder, f'education-{folder_name}.xlsx')
    links_df = pd.DataFrame({'Links': links})
    links_df.to_excel(output_excel_path, index=False)

print("Separation completed.")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 16
#      14 for link in df['Links']:
#      15     parts = link.split('/')
# ---> 16     folder_name = parts[5]  # Assuming the folder name is the third part of the link
#      17     if folder_name not in link_dict:
#      18         link_dict[folder_name] = []
#
# IndexError: list index out of range

# %%
import os
import pandas as pd
import re

# List of colleges
colleges = ['education', 'engineering', 'chs', 'liberalarts', 'nursing', 'science', 'pharmacy', 'business', 'graduate', 'extendeduniversity']

# Regular expression pattern to extract folder name
folder_pattern = re.compile(r'https?://[^/]+/[^/]+/([^/]+)/')

# Iterate through each college
for college in colleges:
    input_excel_path = f'Documents/Excel_Files/{college}.xlsx'

    # Load the Excel file using pandas with column 'A' as index
    df = pd.read_excel(input_excel_path, index_col=0)

    # Create a dictionary to store links based on folder names
    link_dict = {}

    # Iterate through each link in column 'A'
    for link in df.index:
        match = folder_pattern.search(link)
        if match:
            folder_name = match.group(1)
            if folder_name not in link_dict:
                link_dict[folder_name] = []
            link_dict[folder_name].append(link)

    # Create a new Excel file for each folder
    output_folder = 'Documents/Excel_Files/'
    os.makedirs(output_folder, exist_ok=True)

    for folder_name, links in link_dict.items():
        output_excel_path = os.path.join(output_folder, f'{college}-{folder_name}.xlsx')
        links_df = pd.DataFrame({'Links': links, 'Template': ['No Carousel'] * len(links)})
        links_df.to_excel(output_excel_path, index=False)

    print(f"Separation completed for {college}.")
# Out:
# Separation completed for education.
# Separation completed for engineering.
# Separation completed for chs.
# Separation completed for liberalarts.
# Separation completed for nursing.
# Separation completed for science.
# Separation completed for pharmacy.
# Separation completed for business.
# Separation completed for graduate.
# Separation completed for extendeduniversity.
